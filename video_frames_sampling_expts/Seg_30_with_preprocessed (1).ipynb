# %%
import zipfile
import os
import cv2
import numpy as np
import pandas as pd
import random
import tensorflow as tf
from skimage.metrics import structural_similarity as ssim
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Nadam
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# %%
# Global Constants
NUM_FRAMES = 30 #20  # [60,50,40,30,20,10]             # Number of frames to sample per video
MIN_FRAMES = 120                  # Minimum frames required in a video
max_frames = 120                  # Maximum frames allowed in a video
IMAGE_HEIGHT, IMAGE_WIDTH = 224, 224  # Target frame dimensions
SSIM_THRESHOLD = 0.80 #0.94             # Max SSIM allowed between selected frames
NUM_SHUFFLES = 6#5 #6

# %%
# GOOGLE DRIVE SETUP
from google.colab import drive
drive.mount('drive')

zip_folder = 'drive/My Drive/Colab Notebooks_videoAnalytics/all_phs1_phs6lv1_lv38_vids.zip'
extract_path = ''

with zipfile.ZipFile(zip_folder, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extraction complete.")
# Out:
# Mounted at drive
# Extraction complete.

# %%
#checking the contents extracted from the zip file
# !ls all_phs1_phs6lv1_lv38_vids/
# Out:
# larvae_temp,24_4°C,15-10-2024,12-26-27PM.mp4
# larvae_temp,24_4°C,15-10-2024,12-27-37PM.mp4
# larvae_temp,24_4°C,15-10-2024,12-27-45PM.mp4
# larvae_temp,24_5°C,15-10-2024,12-25-56PM.mp4
# larvae_temp,24_5°C,15-10-2024,12-26-51PM.mp4
# larvae_temp,24_5°C,15-10-2024,12-26-58PM.mp4
# larvae_temp,24_5°C,15-10-2024,12-27-14PM.mp4
# larvae_temp,24_5°C,15-10-2024,12-27-29PM.mp4
# larvae_temp,24_5°C,15-10-2024,12-28-00PM.mp4
# larvae_temp,24_6°C,14-10-2024,03-03-25PM.mp4
# larvae_temp,24_6°C,14-10-2024,03-05-37PM.mp4
# larvae_temp,24_6°C,14-10-2024,04-31-17PM.mp4
# larvae_temp,24_6°C,15-10-2024,12-26-43PM.mp4
# larvae_temp,24_6°C,15-10-2024,12-28-08PM.mp4
# larvae_temp,24_6°C,15-10-2024,12-35-58PM.mp4
# larvae_temp,24_6°C,15-10-2024,12-36-05PM.mp4
# larvae_temp,24_7°C,14-10-2024,03-03-49PM.mp4
# larvae_temp,24_7°C,14-10-2024,03-04-12PM.mp4
# larvae_temp,24_7°C,14-10-2024,03-05-30PM.mp4
# larvae_temp,24_7°C,14-10-2024,04-28-44PM.mp4
# larvae_temp,24_7°C,14-10-2024,04-29-13PM.mp4
# larvae_temp,24_7°C,14-10-2024,04-29-52PM.mp4
# larvae_temp,24_7°C,14-10-2024,04-31-02PM.mp4
# larvae_temp,24_7°C,15-10-2024,12-25-48PM.mp4
# larvae_temp,24_7°C,15-10-2024,12-26-04PM.mp4
# larvae_temp,24_7°C,15-10-2024,12-26-12PM.mp4
# larvae_temp,24_7°C,15-10-2024,12-26-35PM.mp4
# larvae_temp,24_7°C,15-10-2024,12-27-06PM.mp4
# larvae_temp,24_7°C,15-10-2024,12-27-22PM.mp4
# larvae_temp,24_7°C,15-10-2024,12-27-53PM.mp4
# larvae_temp,24_7°C,15-10-2024,12-34-09PM.mp4
# larvae_temp,24_7°C,15-10-2024,12-34-17PM.mp4
# larvae_temp,24_7°C,15-10-2024,12-34-24PM.mp4
# larvae_temp,24_7°C,15-10-2024,12-34-55PM.mp4
# larvae_temp,24_7°C,15-10-2024,12-35-34PM.mp4
# larvae_temp,24_7°C,15-10-2024,12-38-27PM.mp4
# larvae_temp,24_7°C,16-10-2024,01-31-02PM.mp4
# larvae_temp,24_7°C,16-10-2024,01-31-26PM.mp4
# larvae_temp,24_7°C,16-10-2024,01-33-32PM.mp4
# larvae_temp,24_8°C,14-10-2024,02-33-16PM.mp4
# larvae_temp,24_8°C,14-10-2024,02-34-10PM.mp4
# larvae_temp,24_8°C,14-10-2024,03-03-18PM.mp4
# larvae_temp,24_8°C,14-10-2024,03-04-59PM.mp4
# larvae_temp,24_8°C,14-10-2024,03-05-06PM.mp4
# larvae_temp,24_8°C,14-10-2024,03-24-53PM.mp4
# larvae_temp,24_8°C,14-10-2024,03-25-10PM.mp4
# larvae_temp,24_8°C,14-10-2024,03-43-26PM.mp4
# larvae_temp,24_8°C,14-10-2024,04-29-29PM.mp4
# larvae_temp,24_8°C,14-10-2024,04-30-23PM.mp4
# larvae_temp,24_8°C,14-10-2024,04-30-31PM.mp4
# larvae_temp,24_8°C,14-10-2024,04-30-39PM.mp4
# larvae_temp,24_8°C,14-10-2024,04-30-46PM.mp4
# larvae_temp,24_8°C,15-10-2024,12-25-39PM.mp4
# larvae_temp,24_8°C,15-10-2024,12-26-19PM.mp4
# larvae_temp,24_8°C,15-10-2024,12-34-48PM.mp4
# larvae_temp,24_8°C,15-10-2024,12-35-11PM.mp4
# larvae_temp,24_8°C,15-10-2024,12-35-19PM.mp4
# larvae_temp,24_8°C,15-10-2024,12-35-26PM.mp4
# larvae_temp,24_8°C,15-10-2024,12-35-50PM.mp4
# larvae_temp,24_8°C,15-10-2024,12-37-41PM.mp4
# larvae_temp,24_8°C,15-10-2024,12-38-51PM.mp4
# larvae_temp,24_8°C,16-10-2024,01-29-52PM.mp4
# larvae_temp,24_8°C,16-10-2024,01-32-53PM.mp4
# larvae_temp,24_8°C,16-10-2024,01-34-03PM.mp4
# larvae_temp,24_8°C,16-10-2024,01-34-49PM.mp4
# larvae_temp,24_9°C,14-10-2024,02-33-00PM.mp4
# larvae_temp,24_9°C,14-10-2024,02-33-24PM.mp4
# larvae_temp,24_9°C,14-10-2024,02-33-47PM.mp4
# larvae_temp,24_9°C,14-10-2024,02-34-26PM.mp4
# larvae_temp,24_9°C,14-10-2024,02-45-51PM.mp4
# larvae_temp,24_9°C,14-10-2024,02-45-58PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-03-09PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-03-33PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-03-41PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-03-56PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-04-04PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-04-20PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-04-35PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-05-22PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-12-15PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-12-53PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-26-27PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-26-35PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-26-43PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-27-14PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-27-22PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-31-41PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-31-57PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-32-05PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-33-15PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-33-38PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-33-54PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-40-07PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-41-53PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-42-16PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-42-24PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-43-10PM.mp4
# larvae_temp,24_9°C,14-10-2024,03-43-41PM.mp4
# larvae_temp,24_9°C,14-10-2024,04-28-58PM.mp4
# larvae_temp,24_9°C,14-10-2024,04-29-05PM.mp4
# larvae_temp,24_9°C,14-10-2024,04-29-21PM.mp4
# larvae_temp,24_9°C,14-10-2024,04-29-36PM.mp4
# larvae_temp,24_9°C,14-10-2024,04-29-44PM.mp4
# larvae_temp,24_9°C,14-10-2024,04-30-07PM.mp4
# larvae_temp,24_9°C,14-10-2024,04-30-54PM.mp4
# larvae_temp,24_9°C,15-10-2024,01-01-07PM.mp4
# larvae_temp,24_9°C,15-10-2024,01-01-46PM.mp4
# larvae_temp,24_9°C,15-10-2024,01-01-54PM.mp4
# larvae_temp,24_9°C,15-10-2024,01-02-17PM.mp4
# larvae_temp,24_9°C,15-10-2024,01-02-32PM.mp4
# larvae_temp,24_9°C,15-10-2024,12-34-01PM.mp4
# larvae_temp,24_9°C,16-10-2024,01-30-31PM.mp4
# larvae_temp,24_9°C,16-10-2024,01-33-00PM.mp4
# larvae_temp,24_9°C,16-10-2024,01-34-11PM.mp4
# larvae_temp,24_9°C,16-10-2024,01-34-42PM.mp4
# larvae_temp,25_0°C,14-10-2024,02-32-12PM.mp4
# larvae_temp,25_0°C,14-10-2024,02-32-29PM.mp4
# larvae_temp,25_0°C,14-10-2024,02-32-37PM.mp4
# larvae_temp,25_0°C,14-10-2024,02-32-44PM.mp4
# larvae_temp,25_0°C,14-10-2024,02-33-08PM.mp4
# larvae_temp,25_0°C,14-10-2024,02-33-32PM.mp4
# larvae_temp,25_0°C,14-10-2024,02-34-42PM.mp4
# larvae_temp,25_0°C,14-10-2024,02-58-16PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-04-28PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-04-43PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-04-51PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-11-36PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-11-44PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-25-02PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-25-18PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-25-25PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-25-33PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-25-49PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-26-04PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-26-59PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-27-06PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-32-36PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-34-09PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-41-21PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-42-01PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-42-32PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-42-39PM.mp4
# larvae_temp,25_0°C,14-10-2024,03-43-34PM.mp4
# larvae_temp,25_0°C,14-10-2024,04-30-00PM.mp4
# larvae_temp,25_0°C,14-10-2024,04-31-10PM.mp4
# larvae_temp,25_0°C,15-10-2024,01-01-30PM.mp4
# larvae_temp,25_0°C,15-10-2024,01-02-09PM.mp4
# larvae_temp,25_0°C,15-10-2024,01-02-56PM.mp4
# larvae_temp,25_0°C,15-10-2024,01-06-48PM.mp4
# larvae_temp,25_0°C,15-10-2024,01-07-19PM.mp4
# larvae_temp,25_0°C,15-10-2024,01-07-27PM.mp4
# larvae_temp,25_0°C,15-10-2024,01-08-21PM.mp4
# larvae_temp,25_0°C,15-10-2024,01-08-29PM.mp4
# larvae_temp,25_0°C,16-10-2024,01-29-29PM.mp4
# larvae_temp,25_0°C,16-10-2024,01-30-08PM.mp4
# larvae_temp,25_0°C,16-10-2024,01-30-23PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-32-21PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-32-52PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-33-55PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-43-45PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-43-54PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-44-48PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-45-04PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-45-27PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-45-35PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-45-43PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-46-14PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-48-57PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-56-27PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-56-50PM.mp4
# larvae_temp,25_1°C,14-10-2024,02-58-08PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-10-49PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-10-57PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-11-13PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-11-28PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-11-51PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-11-59PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-12-07PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-12-22PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-12-30PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-12-38PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-12-46PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-13-01PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-13-09PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-25-41PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-25-56PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-26-12PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-26-20PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-32-13PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-33-30PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-41-45PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-42-47PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-43-03PM.mp4
# larvae_temp,25_1°C,14-10-2024,03-43-18PM.mp4
# larvae_temp,25_1°C,14-10-2024,04-22-36PM.mp4
# larvae_temp,25_1°C,14-10-2024,04-22-44PM.mp4
# larvae_temp,25_1°C,15-10-2024,01-01-38PM.mp4
# larvae_temp,25_1°C,15-10-2024,01-06-55PM.mp4
# larvae_temp,25_1°C,15-10-2024,01-45-53PM.mp4
# larvae_temp,25_1°C,15-10-2024,01-46-01PM.mp4
# larvae_temp,25_1°C,15-10-2024,01-46-48PM.mp4
# larvae_temp,25_1°C,15-10-2024,01-47-11PM.mp4
# larvae_temp,25_1°C,16-10-2024,01-33-55PM.mp4
# larvae_temp,25_1°C,16-10-2024,01-34-26PM.mp4
# larvae_temp,25_2°C,03-07-2025,10-08-16AM.mp4
# larvae_temp,25_2°C,03-07-2025,10-12-05AM.mp4
# larvae_temp,25_2°C,03-07-2025,10-21-30AM.mp4
# larvae_temp,25_2°C,14-10-2024,02-33-39PM.mp4
# larvae_temp,25_2°C,14-10-2024,02-44-01PM.mp4
# larvae_temp,25_2°C,14-10-2024,02-44-40PM.mp4
# larvae_temp,25_2°C,14-10-2024,02-51-02PM.mp4
# larvae_temp,25_2°C,14-10-2024,02-51-26PM.mp4
# larvae_temp,25_2°C,14-10-2024,02-55-55PM.mp4
# larvae_temp,25_2°C,14-10-2024,02-56-19PM.mp4
# larvae_temp,25_2°C,14-10-2024,02-56-43PM.mp4
# larvae_temp,25_2°C,14-10-2024,02-58-23PM.mp4
# larvae_temp,25_2°C,14-10-2024,03-05-14PM.mp4
# larvae_temp,25_2°C,14-10-2024,03-10-41PM.mp4
# larvae_temp,25_2°C,14-10-2024,03-11-20PM.mp4
# larvae_temp,25_2°C,14-10-2024,03-26-51PM.mp4
# larvae_temp,25_2°C,14-10-2024,03-33-23PM.mp4
# larvae_temp,25_2°C,14-10-2024,03-33-46PM.mp4
# larvae_temp,25_2°C,14-10-2024,03-34-02PM.mp4
# larvae_temp,25_2°C,14-10-2024,03-42-08PM.mp4
# larvae_temp,25_2°C,14-10-2024,03-42-55PM.mp4
# larvae_temp,25_2°C,14-10-2024,03-43-49PM.mp4
# larvae_temp,25_2°C,14-10-2024,03-52-11PM.mp4
# larvae_temp,25_2°C,14-10-2024,03-52-26PM.mp4
# larvae_temp,25_2°C,14-10-2024,04-20-31PM.mp4
# larvae_temp,25_2°C,14-10-2024,04-22-05PM.mp4
# larvae_temp,25_2°C,14-10-2024,04-22-29PM.mp4
# larvae_temp,25_2°C,14-10-2024,04-22-52PM.mp4
# larvae_temp,25_2°C,14-10-2024,04-23-00PM.mp4
# larvae_temp,25_2°C,14-10-2024,04-30-15PM.mp4
# larvae_temp,25_2°C,15-10-2024,01-07-50PM.mp4
# larvae_temp,25_2°C,15-10-2024,01-31-16PM.mp4
# larvae_temp,25_2°C,15-10-2024,01-43-00PM.mp4
# larvae_temp,25_2°C,15-10-2024,01-46-17PM.mp4
# larvae_temp,25_2°C,15-10-2024,01-46-56PM.mp4
# larvae_temp,25_2°C,15-10-2024,02-40-15PM.mp4
# larvae_temp,25_2°C,16-10-2024,01-32-45PM.mp4
# larvae_temp,25_2°C,16-10-2024,01-33-16PM.mp4
# larvae_temp,25_3°C,03-07-2025,10-08-08AM.mp4
# larvae_temp,25_3°C,03-07-2025,10-12-20AM.mp4
# larvae_temp,25_3°C,03-07-2025,10-13-38AM.mp4
# larvae_temp,25_3°C,03-07-2025,10-16-58AM.mp4
# larvae_temp,25_3°C,03-07-2025,10-19-41AM.mp4
# larvae_temp,25_3°C,03-07-2025,10-20-04AM.mp4
# larvae_temp,25_3°C,03-07-2025,10-22-01AM.mp4
# larvae_temp,25_3°C,14-10-2024,02-44-17PM.mp4
# larvae_temp,25_3°C,14-10-2024,02-45-19PM.mp4
# larvae_temp,25_3°C,14-10-2024,02-49-06PM.mp4
# larvae_temp,25_3°C,14-10-2024,02-49-21PM.mp4
# larvae_temp,25_3°C,14-10-2024,02-50-31PM.mp4
# larvae_temp,25_3°C,14-10-2024,02-51-10PM.mp4
# larvae_temp,25_3°C,14-10-2024,02-51-18PM.mp4
# larvae_temp,25_3°C,14-10-2024,02-56-04PM.mp4
# larvae_temp,25_3°C,14-10-2024,02-56-12PM.mp4
# larvae_temp,25_3°C,14-10-2024,02-57-45PM.mp4
# larvae_temp,25_3°C,14-10-2024,03-11-05PM.mp4
# larvae_temp,25_3°C,14-10-2024,03-41-30PM.mp4
# larvae_temp,25_3°C,14-10-2024,03-41-37PM.mp4
# larvae_temp,25_3°C,14-10-2024,03-50-52PM.mp4
# larvae_temp,25_3°C,14-10-2024,04-21-42PM.mp4
# larvae_temp,25_3°C,14-10-2024,04-21-50PM.mp4
# larvae_temp,25_3°C,14-10-2024,04-22-21PM.mp4
# larvae_temp,25_3°C,15-10-2024,01-06-00PM.mp4
# larvae_temp,25_3°C,15-10-2024,01-27-17PM.mp4
# larvae_temp,25_3°C,15-10-2024,01-29-59PM.mp4
# larvae_temp,25_3°C,15-10-2024,01-31-01PM.mp4
# larvae_temp,25_3°C,15-10-2024,01-32-03PM.mp4
# larvae_temp,25_3°C,15-10-2024,01-43-08PM.mp4
# larvae_temp,25_3°C,15-10-2024,01-43-47PM.mp4
# larvae_temp,25_3°C,15-10-2024,01-46-25PM.mp4
# larvae_temp,25_3°C,15-10-2024,02-40-07PM.mp4
# larvae_temp,25_3°C,15-10-2024,02-41-41PM.mp4
# larvae_temp,25_3°C,15-10-2024,02-43-36PM.mp4
# larvae_temp,25_3°C,15-10-2024,02-56-35PM.mp4
# larvae_temp,25_3°C,15-10-2024,02-57-46PM.mp4
# larvae_temp,25_3°C,16-10-2024,01-33-47PM.mp4
# larvae_temp,25_4°C,03-07-2025,10-03-48AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-04-11AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-08-55AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-09-26AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-13-22AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-13-30AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-16-35AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-16-50AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-17-14AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-17-22AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-17-29AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-17-37AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-17-53AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-19-57AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-20-12AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-20-28AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-20-43AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-20-59AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-21-14AM.mp4
# larvae_temp,25_4°C,03-07-2025,10-21-45AM.mp4
# larvae_temp,25_4°C,14-10-2024,02-49-29PM.mp4
# larvae_temp,25_4°C,14-10-2024,02-49-37PM.mp4
# larvae_temp,25_4°C,14-10-2024,02-50-16PM.mp4
# larvae_temp,25_4°C,14-10-2024,02-50-47PM.mp4
# larvae_temp,25_4°C,14-10-2024,02-56-58PM.mp4
# larvae_temp,25_4°C,14-10-2024,02-57-06PM.mp4
# larvae_temp,25_4°C,14-10-2024,02-57-29PM.mp4
# larvae_temp,25_4°C,14-10-2024,02-57-37PM.mp4
# larvae_temp,25_4°C,14-10-2024,02-58-00PM.mp4
# larvae_temp,25_4°C,14-10-2024,03-50-28PM.mp4
# larvae_temp,25_4°C,14-10-2024,03-50-36PM.mp4
# larvae_temp,25_4°C,14-10-2024,03-51-47PM.mp4
# larvae_temp,25_4°C,14-10-2024,03-52-03PM.mp4
# larvae_temp,25_4°C,14-10-2024,03-52-18PM.mp4
# larvae_temp,25_4°C,14-10-2024,04-00-09PM.mp4
# larvae_temp,25_4°C,14-10-2024,04-00-24PM.mp4
# larvae_temp,25_4°C,14-10-2024,04-00-42PM.mp4
# larvae_temp,25_4°C,14-10-2024,04-20-47PM.mp4
# larvae_temp,25_4°C,14-10-2024,04-20-55PM.mp4
# larvae_temp,25_4°C,14-10-2024,04-21-03PM.mp4
# larvae_temp,25_4°C,14-10-2024,04-21-11PM.mp4
# larvae_temp,25_4°C,14-10-2024,04-21-18PM.mp4
# larvae_temp,25_4°C,14-10-2024,04-21-26PM.mp4
# larvae_temp,25_4°C,14-10-2024,04-21-34PM.mp4
# larvae_temp,25_4°C,14-10-2024,04-21-57PM.mp4
# larvae_temp,25_4°C,14-10-2024,04-22-13PM.mp4
# larvae_temp,25_4°C,15-10-2024,01-27-32PM.mp4
# larvae_temp,25_4°C,15-10-2024,01-27-40PM.mp4
# larvae_temp,25_4°C,15-10-2024,01-27-48PM.mp4
# larvae_temp,25_4°C,15-10-2024,01-29-34PM.mp4
# larvae_temp,25_4°C,15-10-2024,01-31-47PM.mp4
# larvae_temp,25_4°C,15-10-2024,01-41-50PM.mp4
# larvae_temp,25_4°C,15-10-2024,01-43-16PM.mp4
# larvae_temp,25_4°C,15-10-2024,01-43-39PM.mp4
# larvae_temp,25_4°C,15-10-2024,01-43-55PM.mp4
# larvae_temp,25_4°C,15-10-2024,02-40-30PM.mp4
# larvae_temp,25_4°C,15-10-2024,02-41-33PM.mp4
# larvae_temp,25_4°C,15-10-2024,02-41-56PM.mp4
# larvae_temp,25_4°C,15-10-2024,02-43-51PM.mp4
# larvae_temp,25_4°C,15-10-2024,03-00-16PM.mp4
# larvae_temp,25_4°C,15-10-2024,03-00-55PM.mp4
# larvae_temp,25_4°C,15-10-2024,03-01-11PM.mp4
# larvae_temp,25_4°C,15-10-2024,03-01-18PM.mp4
# larvae_temp,25_4°C,15-10-2024,03-02-21PM.mp4
# larvae_temp,25_5°C,03-07-2025,09-59-41AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-01-52AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-02-15AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-02-46AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-03-17AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-03-25AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-03-33AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-03-40AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-03-56AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-07-53AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-08-32AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-08-39AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-09-03AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-09-10AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-09-34AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-11-41AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-12-12AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-12-36AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-12-43AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-13-46AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-13-53AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-16-12AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-16-43AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-17-06AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-17-45AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-19-49AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-20-20AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-20-35AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-20-51AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-21-07AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-21-22AM.mp4
# larvae_temp,25_5°C,03-07-2025,10-21-53AM.mp4
# larvae_temp,25_5°C,14-10-2024,02-44-09PM.mp4
# larvae_temp,25_5°C,14-10-2024,02-50-00PM.mp4
# larvae_temp,25_5°C,14-10-2024,02-50-08PM.mp4
# larvae_temp,25_5°C,14-10-2024,02-57-22PM.mp4
# larvae_temp,25_5°C,14-10-2024,03-52-34PM.mp4
# larvae_temp,25_5°C,14-10-2024,03-52-42PM.mp4
# larvae_temp,25_5°C,14-10-2024,03-52-52PM.mp4
# larvae_temp,25_5°C,14-10-2024,03-58-25PM.mp4
# larvae_temp,25_5°C,14-10-2024,03-58-32PM.mp4
# larvae_temp,25_5°C,14-10-2024,03-59-04PM.mp4
# larvae_temp,25_5°C,14-10-2024,03-59-29PM.mp4
# larvae_temp,25_5°C,14-10-2024,03-59-53PM.mp4
# larvae_temp,25_5°C,15-10-2024,01-25-59PM.mp4
# larvae_temp,25_5°C,15-10-2024,01-26-15PM.mp4
# larvae_temp,25_5°C,15-10-2024,01-28-03PM.mp4
# larvae_temp,25_5°C,15-10-2024,01-30-30PM.mp4
# larvae_temp,25_5°C,15-10-2024,01-31-24PM.mp4
# larvae_temp,25_5°C,15-10-2024,01-41-58PM.mp4
# larvae_temp,25_5°C,15-10-2024,01-43-24PM.mp4
# larvae_temp,25_5°C,15-10-2024,01-44-51PM.mp4
# larvae_temp,25_5°C,15-10-2024,01-45-14PM.mp4
# larvae_temp,25_5°C,15-10-2024,02-39-52PM.mp4
# larvae_temp,25_5°C,15-10-2024,02-40-23PM.mp4
# larvae_temp,25_5°C,15-10-2024,02-40-38PM.mp4
# larvae_temp,25_5°C,15-10-2024,02-42-57PM.mp4
# larvae_temp,25_5°C,15-10-2024,02-43-44PM.mp4
# larvae_temp,25_5°C,15-10-2024,02-43-59PM.mp4
# larvae_temp,25_5°C,15-10-2024,02-44-38PM.mp4
# larvae_temp,25_5°C,15-10-2024,02-57-30PM.mp4
# larvae_temp,25_5°C,15-10-2024,02-58-55PM.mp4
# larvae_temp,25_5°C,15-10-2024,02-59-52PM.mp4
# larvae_temp,25_5°C,15-10-2024,03-00-47PM.mp4
# larvae_temp,25_5°C,15-10-2024,03-02-13PM.mp4
# larvae_temp,25_5°C,15-10-2024,03-28-58PM.mp4
# larvae_temp,25_5°C,15-10-2024,03-29-29PM.mp4
# larvae_temp,25_5°C,15-10-2024,03-29-45PM.mp4
# larvae_temp,25_5°C,15-10-2024,03-30-00PM.mp4
# larvae_temp,25_5°C,15-10-2024,03-41-40PM.mp4
# larvae_temp,25_5°C,15-10-2024,03-42-27PM.mp4
# larvae_temp,25_5°C,15-10-2024,03-42-51PM.mp4
# larvae_temp,25_5°C,15-10-2024,03-55-18PM.mp4
# larvae_temp,25_5°C,16-10-2024,02-28-37PM.mp4
# larvae_temp,25_5°C,16-10-2024,02-29-00PM.mp4
# larvae_temp,25_5°C,16-10-2024,02-29-31PM.mp4
# larvae_temp,25_6°C,03-07-2025,09-58-31AM.mp4
# larvae_temp,25_6°C,03-07-2025,09-59-56AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-01-43AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-01-59AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-02-07AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-02-23AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-02-30AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-02-38AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-02-54AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-03-02AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-03-09AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-04-04AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-07-05AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-07-14AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-07-22AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-07-30AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-07-37AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-08-01AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-08-24AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-11-25AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-11-33AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-11-49AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-11-57AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-12-28AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-13-07AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-13-14AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-15-24AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-15-33AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-15-40AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-16-04AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-16-19AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-19-32AM.mp4
# larvae_temp,25_6°C,03-07-2025,10-28-04AM.mp4
# larvae_temp,25_6°C,14-10-2024,03-51-55PM.mp4
# larvae_temp,25_6°C,14-10-2024,03-58-16PM.mp4
# larvae_temp,25_6°C,14-10-2024,03-58-40PM.mp4
# larvae_temp,25_6°C,14-10-2024,03-59-12PM.mp4
# larvae_temp,25_6°C,14-10-2024,03-59-37PM.mp4
# larvae_temp,25_6°C,14-10-2024,04-00-16PM.mp4
# larvae_temp,25_6°C,14-10-2024,04-00-34PM.mp4
# larvae_temp,25_6°C,14-10-2024,04-17-09PM.mp4
# larvae_temp,25_6°C,14-10-2024,04-17-48PM.mp4
# larvae_temp,25_6°C,14-10-2024,04-20-39PM.mp4
# larvae_temp,25_6°C,15-10-2024,01-25-51PM.mp4
# larvae_temp,25_6°C,15-10-2024,01-26-07PM.mp4
# larvae_temp,25_6°C,15-10-2024,01-31-40PM.mp4
# larvae_temp,25_6°C,15-10-2024,02-41-09PM.mp4
# larvae_temp,25_6°C,15-10-2024,02-42-04PM.mp4
# larvae_temp,25_6°C,15-10-2024,02-56-43PM.mp4
# larvae_temp,25_6°C,15-10-2024,02-58-17PM.mp4
# larvae_temp,25_6°C,15-10-2024,02-58-40PM.mp4
# larvae_temp,25_6°C,15-10-2024,03-00-01PM.mp4
# larvae_temp,25_6°C,15-10-2024,03-00-08PM.mp4
# larvae_temp,25_6°C,15-10-2024,03-01-50PM.mp4
# larvae_temp,25_6°C,15-10-2024,03-28-34PM.mp4
# larvae_temp,25_6°C,15-10-2024,03-29-06PM.mp4
# larvae_temp,25_6°C,15-10-2024,03-29-13PM.mp4
# larvae_temp,25_6°C,15-10-2024,03-31-53PM.mp4
# larvae_temp,25_6°C,15-10-2024,03-41-32PM.mp4
# larvae_temp,25_6°C,15-10-2024,03-42-19PM.mp4
# larvae_temp,25_6°C,15-10-2024,03-53-44PM.mp4
# larvae_temp,25_6°C,15-10-2024,03-54-31PM.mp4
# larvae_temp,25_6°C,16-10-2024,02-27-18PM.mp4
# larvae_temp,25_6°C,16-10-2024,02-27-35PM.mp4
# larvae_temp,25_6°C,16-10-2024,02-28-06PM.mp4
# larvae_temp,25_6°C,16-10-2024,02-42-14PM.mp4
# larvae_temp,25_6°C,16-10-2024,03-11-48PM.mp4
# larvae_temp,25_6°C,16-10-2024,03-28-35PM.mp4
# larvae_temp,25_6°C,16-10-2024,03-32-10PM.mp4
# larvae_temp,25_6°C,16-10-2024,03-34-39PM.mp4
# larvae_temp,25_6°C,16-10-2024,03-50-34PM.mp4
# larvae_temp,25_6°C,16-10-2024,04-07-14PM.mp4
# larvae_temp,25_7°C,03-07-2025,09-57-35AM.mp4
# larvae_temp,25_7°C,03-07-2025,09-57-52AM.mp4
# larvae_temp,25_7°C,03-07-2025,09-57-59AM.mp4
# larvae_temp,25_7°C,03-07-2025,09-58-07AM.mp4
# larvae_temp,25_7°C,03-07-2025,09-58-15AM.mp4
# larvae_temp,25_7°C,03-07-2025,09-59-02AM.mp4
# larvae_temp,25_7°C,03-07-2025,09-59-10AM.mp4
# larvae_temp,25_7°C,03-07-2025,09-59-17AM.mp4
# larvae_temp,25_7°C,03-07-2025,09-59-25AM.mp4
# larvae_temp,25_7°C,03-07-2025,09-59-33AM.mp4
# larvae_temp,25_7°C,03-07-2025,09-59-48AM.mp4
# larvae_temp,25_7°C,03-07-2025,10-00-04AM.mp4
# larvae_temp,25_7°C,03-07-2025,10-08-47AM.mp4
# larvae_temp,25_7°C,03-07-2025,10-09-18AM.mp4
# larvae_temp,25_7°C,03-07-2025,10-12-51AM.mp4
# larvae_temp,25_7°C,03-07-2025,10-12-59AM.mp4
# larvae_temp,25_7°C,03-07-2025,10-15-48AM.mp4
# larvae_temp,25_7°C,03-07-2025,10-15-56AM.mp4
# larvae_temp,25_7°C,03-07-2025,10-16-27AM.mp4
# larvae_temp,25_7°C,03-07-2025,10-21-38AM.mp4
# larvae_temp,25_7°C,03-07-2025,10-28-43AM.mp4
# larvae_temp,25_7°C,03-07-2025,10-28-59AM.mp4
# larvae_temp,25_7°C,03-07-2025,10-30-01AM.mp4
# larvae_temp,25_7°C,03-07-2025,10-33-57AM.mp4
# larvae_temp,25_7°C,14-10-2024,02-56-35PM.mp4
# larvae_temp,25_7°C,14-10-2024,03-51-00PM.mp4
# larvae_temp,25_7°C,14-10-2024,03-58-56PM.mp4
# larvae_temp,25_7°C,14-10-2024,03-59-22PM.mp4
# larvae_temp,25_7°C,14-10-2024,03-59-45PM.mp4
# larvae_temp,25_7°C,14-10-2024,04-00-01PM.mp4
# larvae_temp,25_7°C,14-10-2024,04-16-22PM.mp4
# larvae_temp,25_7°C,14-10-2024,04-17-16PM.mp4
# larvae_temp,25_7°C,14-10-2024,04-17-40PM.mp4
# larvae_temp,25_7°C,15-10-2024,02-40-54PM.mp4
# larvae_temp,25_7°C,15-10-2024,02-41-02PM.mp4
# larvae_temp,25_7°C,15-10-2024,02-41-25PM.mp4
# larvae_temp,25_7°C,15-10-2024,02-58-01PM.mp4
# larvae_temp,25_7°C,15-10-2024,02-58-09PM.mp4
# larvae_temp,25_7°C,15-10-2024,03-30-08PM.mp4
# larvae_temp,25_7°C,15-10-2024,03-30-16PM.mp4
# larvae_temp,25_7°C,15-10-2024,03-30-23PM.mp4
# larvae_temp,25_7°C,15-10-2024,03-30-31PM.mp4
# larvae_temp,25_7°C,15-10-2024,03-30-39PM.mp4
# larvae_temp,25_7°C,15-10-2024,03-31-37PM.mp4
# larvae_temp,25_7°C,15-10-2024,03-32-01PM.mp4
# larvae_temp,25_7°C,15-10-2024,03-33-03PM.mp4
# larvae_temp,25_7°C,15-10-2024,03-33-11PM.mp4
# larvae_temp,25_7°C,15-10-2024,03-41-56PM.mp4
# larvae_temp,25_7°C,15-10-2024,03-42-43PM.mp4
# larvae_temp,25_7°C,15-10-2024,03-43-14PM.mp4
# larvae_temp,25_7°C,15-10-2024,03-54-23PM.mp4
# larvae_temp,25_7°C,15-10-2024,03-55-02PM.mp4
# larvae_temp,25_7°C,16-10-2024,02-27-43PM.mp4
# larvae_temp,25_7°C,16-10-2024,02-27-50PM.mp4
# larvae_temp,25_7°C,16-10-2024,02-28-21PM.mp4
# larvae_temp,25_7°C,16-10-2024,02-41-42PM.mp4
# larvae_temp,25_7°C,16-10-2024,02-44-03PM.mp4
# larvae_temp,25_7°C,16-10-2024,03-06-45PM.mp4
# larvae_temp,25_7°C,16-10-2024,03-10-35PM.mp4
# larvae_temp,25_7°C,16-10-2024,03-10-43PM.mp4
# larvae_temp,25_7°C,16-10-2024,03-10-51PM.mp4
# larvae_temp,25_7°C,16-10-2024,03-11-09PM.mp4
# larvae_temp,25_7°C,16-10-2024,03-11-33PM.mp4
# larvae_temp,25_7°C,16-10-2024,03-27-56PM.mp4
# larvae_temp,25_7°C,16-10-2024,03-33-29PM.mp4
# larvae_temp,25_7°C,16-10-2024,03-33-52PM.mp4
# larvae_temp,25_7°C,16-10-2024,03-34-23PM.mp4
# larvae_temp,25_7°C,16-10-2024,03-51-21PM.mp4
# larvae_temp,25_7°C,16-10-2024,04-06-43PM.mp4
# larvae_temp,25_7°C,16-10-2024,04-07-38PM.mp4
# larvae_temp,25_7°C,16-10-2024,04-08-09PM.mp4
# larvae_temp,25_7°C,16-10-2024,04-11-35PM.mp4
# larvae_temp,25_7°C,16-10-2024,04-11-43PM.mp4
# larvae_temp,25_8°C,03-07-2025,09-57-44AM.mp4
# larvae_temp,25_8°C,03-07-2025,09-58-23AM.mp4
# larvae_temp,25_8°C,03-07-2025,09-58-54AM.mp4
# larvae_temp,25_8°C,03-07-2025,10-07-45AM.mp4
# larvae_temp,25_8°C,03-07-2025,10-28-12AM.mp4
# larvae_temp,25_8°C,03-07-2025,10-28-20AM.mp4
# larvae_temp,25_8°C,03-07-2025,10-28-36AM.mp4
# larvae_temp,25_8°C,03-07-2025,10-29-22AM.mp4
# larvae_temp,25_8°C,03-07-2025,10-34-29AM.mp4
# larvae_temp,25_8°C,14-10-2024,02-49-14PM.mp4
# larvae_temp,25_8°C,14-10-2024,02-57-53PM.mp4
# larvae_temp,25_8°C,14-10-2024,03-58-48PM.mp4
# larvae_temp,25_8°C,14-10-2024,04-15-50PM.mp4
# larvae_temp,25_8°C,14-10-2024,04-16-14PM.mp4
# larvae_temp,25_8°C,14-10-2024,04-16-29PM.mp4
# larvae_temp,25_8°C,14-10-2024,04-16-37PM.mp4
# larvae_temp,25_8°C,14-10-2024,04-16-53PM.mp4
# larvae_temp,25_8°C,14-10-2024,04-17-24PM.mp4
# larvae_temp,25_8°C,15-10-2024,01-42-37PM.mp4
# larvae_temp,25_8°C,15-10-2024,03-29-52PM.mp4
# larvae_temp,25_8°C,15-10-2024,03-32-09PM.mp4
# larvae_temp,25_8°C,15-10-2024,03-41-17PM.mp4
# larvae_temp,25_8°C,15-10-2024,03-42-58PM.mp4
# larvae_temp,25_8°C,15-10-2024,03-54-39PM.mp4
# larvae_temp,25_8°C,15-10-2024,03-54-47PM.mp4
# larvae_temp,25_8°C,16-10-2024,02-27-27PM.mp4
# larvae_temp,25_8°C,16-10-2024,02-43-16PM.mp4
# larvae_temp,25_8°C,16-10-2024,03-06-06PM.mp4
# larvae_temp,25_8°C,16-10-2024,03-07-47PM.mp4
# larvae_temp,25_8°C,16-10-2024,03-09-41PM.mp4
# larvae_temp,25_8°C,16-10-2024,03-11-25PM.mp4
# larvae_temp,25_8°C,16-10-2024,03-11-40PM.mp4
# larvae_temp,25_8°C,16-10-2024,03-11-56PM.mp4
# larvae_temp,25_8°C,16-10-2024,03-12-04PM.mp4
# larvae_temp,25_8°C,16-10-2024,03-27-41PM.mp4
# larvae_temp,25_8°C,16-10-2024,03-28-04PM.mp4
# larvae_temp,25_8°C,16-10-2024,03-28-51PM.mp4
# larvae_temp,25_8°C,16-10-2024,03-33-13PM.mp4
# larvae_temp,25_8°C,16-10-2024,03-34-07PM.mp4
# larvae_temp,25_8°C,16-10-2024,03-34-15PM.mp4
# larvae_temp,25_8°C,16-10-2024,03-50-26PM.mp4
# larvae_temp,25_8°C,16-10-2024,04-07-53PM.mp4
# larvae_temp,25_8°C,16-10-2024,04-08-01PM.mp4
# larvae_temp,25_8°C,16-10-2024,04-10-02PM.mp4
# larvae_temp,25_8°C,16-10-2024,04-22-57PM.mp4
# larvae_temp,25_8°C,16-10-2024,04-25-10PM.mp4
# larvae_temp,25_8°C,16-10-2024,04-25-26PM.mp4
# larvae_temp,25_8°C,16-10-2024,04-27-35PM.mp4
# larvae_temp,25_9°C,03-07-2025,09-58-38AM.mp4
# larvae_temp,25_9°C,03-07-2025,09-58-46AM.mp4
# larvae_temp,25_9°C,03-07-2025,10-28-28AM.mp4
# larvae_temp,25_9°C,03-07-2025,10-29-07AM.mp4
# larvae_temp,25_9°C,03-07-2025,10-29-14AM.mp4
# larvae_temp,25_9°C,03-07-2025,10-29-38AM.mp4
# larvae_temp,25_9°C,03-07-2025,10-29-46AM.mp4
# larvae_temp,25_9°C,03-07-2025,10-29-53AM.mp4
# larvae_temp,25_9°C,03-07-2025,10-30-09AM.mp4
# larvae_temp,25_9°C,03-07-2025,10-30-17AM.mp4
# larvae_temp,25_9°C,03-07-2025,10-30-25AM.mp4
# larvae_temp,25_9°C,03-07-2025,10-33-42AM.mp4
# larvae_temp,25_9°C,14-10-2024,03-31-49PM.mp4
# larvae_temp,25_9°C,14-10-2024,03-33-07PM.mp4
# larvae_temp,25_9°C,14-10-2024,04-16-06PM.mp4
# larvae_temp,25_9°C,14-10-2024,04-16-45PM.mp4
# larvae_temp,25_9°C,14-10-2024,04-17-32PM.mp4
# larvae_temp,25_9°C,15-10-2024,03-29-37PM.mp4
# larvae_temp,25_9°C,15-10-2024,03-41-25PM.mp4
# larvae_temp,25_9°C,15-10-2024,03-42-12PM.mp4
# larvae_temp,25_9°C,16-10-2024,02-29-47PM.mp4
# larvae_temp,25_9°C,16-10-2024,02-43-24PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-05-35PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-07-08PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-11-17PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-32-19PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-32-34PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-32-57PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-34-00PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-34-31PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-47-06PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-47-22PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-47-30PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-48-24PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-50-57PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-51-05PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-51-13PM.mp4
# larvae_temp,25_9°C,16-10-2024,03-51-52PM.mp4
# larvae_temp,25_9°C,16-10-2024,04-07-46PM.mp4
# larvae_temp,25_9°C,16-10-2024,04-09-38PM.mp4
# larvae_temp,25_9°C,16-10-2024,04-10-09PM.mp4
# larvae_temp,25_9°C,16-10-2024,04-10-17PM.mp4
# larvae_temp,25_9°C,16-10-2024,04-10-56PM.mp4
# larvae_temp,25_9°C,16-10-2024,04-28-14PM.mp4
# larvae_temp,25_9°C,16-10-2024,04-28-37PM.mp4
# larvae_temp,25_9°C,16-10-2024,04-28-45PM.mp4
# larvae_temp,25_9°C,16-10-2024,04-28-53PM.mp4
# larvae_temp,26_0°C,03-07-2025,10-28-51AM.mp4
# larvae_temp,26_0°C,03-07-2025,10-29-30AM.mp4
# larvae_temp,26_0°C,03-07-2025,10-33-02AM.mp4
# larvae_temp,26_0°C,03-07-2025,10-33-18AM.mp4
# larvae_temp,26_0°C,03-07-2025,10-34-21AM.mp4
# larvae_temp,26_0°C,03-07-2025,10-34-44AM.mp4
# larvae_temp,26_0°C,03-07-2025,10-35-00AM.mp4
# larvae_temp,26_0°C,14-10-2024,02-44-33PM.mp4
# larvae_temp,26_0°C,14-10-2024,02-50-24PM.mp4
# larvae_temp,26_0°C,14-10-2024,03-50-44PM.mp4
# larvae_temp,26_0°C,14-10-2024,03-51-08PM.mp4
# larvae_temp,26_0°C,14-10-2024,04-15-16PM.mp4
# larvae_temp,26_0°C,14-10-2024,04-15-24PM.mp4
# larvae_temp,26_0°C,14-10-2024,04-15-35PM.mp4
# larvae_temp,26_0°C,14-10-2024,04-15-58PM.mp4
# larvae_temp,26_0°C,14-10-2024,04-17-01PM.mp4
# larvae_temp,26_0°C,16-10-2024,02-41-50PM.mp4
# larvae_temp,26_0°C,16-10-2024,02-43-55PM.mp4
# larvae_temp,26_0°C,16-10-2024,03-10-12PM.mp4
# larvae_temp,26_0°C,16-10-2024,03-10-28PM.mp4
# larvae_temp,26_0°C,16-10-2024,03-27-33PM.mp4
# larvae_temp,26_0°C,16-10-2024,03-46-43PM.mp4
# larvae_temp,26_0°C,16-10-2024,03-46-51PM.mp4
# larvae_temp,26_0°C,16-10-2024,03-48-09PM.mp4
# larvae_temp,26_0°C,16-10-2024,03-49-03PM.mp4
# larvae_temp,26_0°C,16-10-2024,03-49-55PM.mp4
# larvae_temp,26_0°C,16-10-2024,03-51-36PM.mp4
# larvae_temp,26_0°C,16-10-2024,03-52-00PM.mp4
# larvae_temp,26_0°C,16-10-2024,04-06-20PM.mp4
# larvae_temp,26_0°C,16-10-2024,04-06-28PM.mp4
# larvae_temp,26_0°C,16-10-2024,04-06-51PM.mp4
# larvae_temp,26_0°C,16-10-2024,04-23-06PM.mp4
# larvae_temp,26_0°C,16-10-2024,04-24-55PM.mp4
# larvae_temp,26_0°C,16-10-2024,04-27-03PM.mp4
# larvae_temp,26_0°C,16-10-2024,04-28-06PM.mp4
# larvae_temp,26_0°C,16-10-2024,04-43-06PM.mp4
# larvae_temp,26_1°C,03-07-2025,10-33-11AM.mp4
# larvae_temp,26_1°C,03-07-2025,10-33-34AM.mp4
# larvae_temp,26_1°C,03-07-2025,10-34-13AM.mp4
# larvae_temp,26_1°C,03-07-2025,10-35-08AM.mp4
# larvae_temp,26_1°C,03-07-2025,10-35-15AM.mp4
# larvae_temp,26_1°C,03-07-2025,10-35-31AM.mp4
# larvae_temp,26_1°C,03-07-2025,10-38-02AM.mp4
# larvae_temp,26_1°C,03-07-2025,10-38-25AM.mp4
# larvae_temp,26_1°C,03-07-2025,10-38-33AM.mp4
# larvae_temp,26_1°C,03-07-2025,10-38-41AM.mp4
# larvae_temp,26_1°C,03-07-2025,10-39-04AM.mp4
# larvae_temp,26_1°C,03-07-2025,10-39-20AM.mp4
# larvae_temp,26_1°C,03-07-2025,10-39-27AM.mp4
# larvae_temp,26_1°C,14-10-2024,03-32-44PM.mp4
# larvae_temp,26_1°C,14-10-2024,03-32-59PM.mp4
# larvae_temp,26_1°C,14-10-2024,03-51-39PM.mp4
# larvae_temp,26_1°C,14-10-2024,04-15-42PM.mp4
# larvae_temp,26_1°C,16-10-2024,03-26-54PM.mp4
# larvae_temp,26_1°C,16-10-2024,03-47-45PM.mp4
# larvae_temp,26_1°C,16-10-2024,04-07-22PM.mp4
# larvae_temp,26_1°C,16-10-2024,04-09-54PM.mp4
# larvae_temp,26_1°C,16-10-2024,04-27-58PM.mp4
# larvae_temp,26_2°C,03-07-2025,10-30-32AM.mp4
# larvae_temp,26_2°C,03-07-2025,10-33-26AM.mp4
# larvae_temp,26_2°C,03-07-2025,10-33-50AM.mp4
# larvae_temp,26_2°C,03-07-2025,10-34-05AM.mp4
# larvae_temp,26_2°C,03-07-2025,10-34-36AM.mp4
# larvae_temp,26_2°C,03-07-2025,10-34-52AM.mp4
# larvae_temp,26_2°C,03-07-2025,10-37-45AM.mp4
# larvae_temp,26_2°C,03-07-2025,10-39-43AM.mp4
# larvae_temp,26_2°C,03-07-2025,10-39-59AM.mp4
# larvae_temp,26_2°C,03-07-2025,10-40-14AM.mp4
# larvae_temp,26_2°C,14-10-2024,03-32-21PM.mp4
# larvae_temp,26_2°C,15-10-2024,01-07-35PM.mp4
# larvae_temp,26_2°C,16-10-2024,04-24-31PM.mp4
# larvae_temp,26_2°C,16-10-2024,04-24-39PM.mp4
# larvae_temp,26_2°C,16-10-2024,04-26-46PM.mp4
# larvae_temp,26_2°C,16-10-2024,04-30-39PM.mp4
# larvae_temp,26_3°C,03-07-2025,10-35-23AM.mp4
# larvae_temp,26_3°C,03-07-2025,10-37-54AM.mp4
# larvae_temp,26_3°C,03-07-2025,10-38-09AM.mp4
# larvae_temp,26_3°C,03-07-2025,10-38-56AM.mp4
# larvae_temp,26_3°C,03-07-2025,10-39-12AM.mp4
# larvae_temp,26_3°C,03-07-2025,10-39-35AM.mp4
# larvae_temp,26_3°C,03-07-2025,10-39-51AM.mp4
# larvae_temp,26_3°C,03-07-2025,10-40-06AM.mp4
# larvae_temp,26_3°C,03-07-2025,10-43-48AM.mp4
# larvae_temp,26_3°C,14-10-2024,02-46-06PM.mp4
# larvae_temp,26_3°C,14-10-2024,02-57-14PM.mp4
# larvae_temp,26_4°C,03-07-2025,10-38-17AM.mp4
# larvae_temp,26_4°C,03-07-2025,10-38-48AM.mp4
# larvae_temp,26_4°C,03-07-2025,10-43-24AM.mp4
# larvae_temp,26_4°C,03-07-2025,10-44-27AM.mp4
# larvae_temp,26_4°C,14-10-2024,02-44-56PM.mp4
# larvae_temp,26_5°C,03-07-2025,10-42-52AM.mp4
# larvae_temp,26_5°C,03-07-2025,10-43-01AM.mp4
# larvae_temp,26_5°C,03-07-2025,10-43-55AM.mp4
# larvae_temp,26_5°C,03-07-2025,10-44-19AM.mp4
# larvae_temp,26_5°C,03-07-2025,10-44-34AM.mp4
# larvae_temp,26_5°C,03-07-2025,10-44-42AM.mp4
# larvae_temp,26_6°C,03-07-2025,10-43-09AM.mp4
# larvae_temp,26_6°C,03-07-2025,10-43-40AM.mp4
# larvae_temp,26_6°C,03-07-2025,10-44-03AM.mp4
# larvae_temp,26_6°C,03-07-2025,10-44-11AM.mp4
# larvae_temp,26_6°C,03-07-2025,10-44-50AM.mp4
# larvae_temp,26_6°C,03-07-2025,10-44-58AM.mp4
# larvae_temp,26_6°C,03-07-2025,10-45-05AM.mp4
# larvae_temp,26_6°C,03-07-2025,10-45-13AM.mp4
# larvae_temp,26_6°C,03-07-2025,10-45-21AM.mp4
# larvae_temp,26_6°C,14-10-2024,02-49-53PM.mp4
# larvae_temp,26_6°C,14-10-2024,03-32-28PM.mp4
# larvae_temp,26_7°C,03-07-2025,01-54-06PM.mp4
# larvae_temp,26_7°C,03-07-2025,02-28-30PM.mp4
# larvae_temp,26_7°C,03-07-2025,02-42-44PM.mp4
# larvae_temp,26_7°C,03-07-2025,10-43-32AM.mp4
# larvae_temp,26_7°C,03-07-2025,10-54-22AM.mp4
# larvae_temp,26_7°C,03-07-2025,10-55-16AM.mp4
# larvae_temp,26_7°C,14-10-2024,02-44-25PM.mp4
# larvae_temp,26_8°C,03-07-2025,01-46-55PM.mp4
# larvae_temp,26_8°C,03-07-2025,01-48-44PM.mp4
# larvae_temp,26_8°C,03-07-2025,01-53-58PM.mp4
# larvae_temp,26_8°C,03-07-2025,01-54-14PM.mp4
# larvae_temp,26_8°C,03-07-2025,01-55-01PM.mp4
# larvae_temp,26_8°C,03-07-2025,01-55-47PM.mp4
# larvae_temp,26_8°C,03-07-2025,01-59-00PM.mp4
# larvae_temp,26_8°C,03-07-2025,02-04-31PM.mp4
# larvae_temp,26_8°C,03-07-2025,02-05-25PM.mp4
# larvae_temp,26_8°C,03-07-2025,02-29-40PM.mp4
# larvae_temp,26_8°C,03-07-2025,02-33-18PM.mp4
# larvae_temp,26_8°C,03-07-2025,02-37-32PM.mp4
# larvae_temp,26_8°C,03-07-2025,02-37-55PM.mp4
# larvae_temp,26_8°C,03-07-2025,02-38-50PM.mp4
# larvae_temp,26_8°C,03-07-2025,02-41-49PM.mp4
# larvae_temp,26_8°C,03-07-2025,02-42-13PM.mp4
# larvae_temp,26_8°C,03-07-2025,02-42-36PM.mp4
# larvae_temp,26_8°C,03-07-2025,02-47-00PM.mp4
# larvae_temp,26_8°C,03-07-2025,10-43-16AM.mp4
# larvae_temp,26_8°C,03-07-2025,10-54-37AM.mp4
# larvae_temp,26_8°C,03-07-2025,10-54-45AM.mp4
# larvae_temp,26_8°C,03-07-2025,10-55-01AM.mp4
# larvae_temp,26_9°C,03-07-2025,01-47-34PM.mp4
# larvae_temp,26_9°C,03-07-2025,01-47-50PM.mp4
# larvae_temp,26_9°C,03-07-2025,01-48-13PM.mp4
# larvae_temp,26_9°C,03-07-2025,01-53-50PM.mp4
# larvae_temp,26_9°C,03-07-2025,01-54-37PM.mp4
# larvae_temp,26_9°C,03-07-2025,01-54-45PM.mp4
# larvae_temp,26_9°C,03-07-2025,01-55-16PM.mp4
# larvae_temp,26_9°C,03-07-2025,01-55-24PM.mp4
# larvae_temp,26_9°C,03-07-2025,01-55-32PM.mp4
# larvae_temp,26_9°C,03-07-2025,01-55-55PM.mp4
# larvae_temp,26_9°C,03-07-2025,01-56-03PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-00-26PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-03-52PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-04-15PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-04-46PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-04-54PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-15-53PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-25-22PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-25-53PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-28-22PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-28-37PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-29-01PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-29-09PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-29-24PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-29-47PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-33-26PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-35-07PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-37-00PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-37-40PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-37-48PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-38-03PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-38-11PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-38-34PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-39-29PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-41-33PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-41-41PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-41-57PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-42-05PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-42-20PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-42-51PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-42-59PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-43-38PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-44-02PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-45-58PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-46-06PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-46-21PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-46-29PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-46-37PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-46-52PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-47-16PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-47-23PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-47-54PM.mp4
# larvae_temp,26_9°C,03-07-2025,02-48-18PM.mp4
# larvae_temp,26_9°C,03-07-2025,10-54-53AM.mp4
# larvae_temp,26_9°C,03-07-2025,10-55-08AM.mp4
# larvae_temp,26_9°C,03-07-2025,10-55-55AM.mp4
# larvae_temp,26_9°C,03-07-2025,11-02-37AM.mp4
# larvae_temp,26_9°C,03-07-2025,11-06-10AM.mp4
# larvae_temp,26_9°C,14-10-2024,02-50-55PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-41-55PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-42-27PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-42-35PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-42-43PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-43-30PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-46-32PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-46-40PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-46-47PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-47-03PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-47-11PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-47-58PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-48-05PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-48-21PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-48-29PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-48-36PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-54-22PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-54-53PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-55-08PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-55-40PM.mp4
# larvae_temp,27_0°C,03-07-2025,01-59-32PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-00-03PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-00-11PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-00-42PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-00-50PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-01-05PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-01-13PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-01-21PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-03-35PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-04-07PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-05-10PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-05-33PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-05-41PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-05-56PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-10-59PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-11-30PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-11-38PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-12-09PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-12-56PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-13-04PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-15-22PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-16-17PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-17-03PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-26-40PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-26-48PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-28-45PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-28-53PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-29-16PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-29-32PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-30-03PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-33-03PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-33-34PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-33-41PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-33-49PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-34-20PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-34-36PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-34-51PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-34-59PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-35-23PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-37-09PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-38-42PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-38-57PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-39-21PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-42-28PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-43-30PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-43-46PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-46-13PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-47-08PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-48-02PM.mp4
# larvae_temp,27_0°C,03-07-2025,02-48-10PM.mp4
# larvae_temp,27_0°C,03-07-2025,10-53-42AM.mp4
# larvae_temp,27_0°C,03-07-2025,10-53-50AM.mp4
# larvae_temp,27_0°C,03-07-2025,10-55-24AM.mp4
# larvae_temp,27_0°C,03-07-2025,10-55-47AM.mp4
# larvae_temp,27_0°C,03-07-2025,11-01-34AM.mp4
# larvae_temp,27_0°C,03-07-2025,11-02-29AM.mp4
# larvae_temp,27_0°C,03-07-2025,11-04-37AM.mp4
# larvae_temp,27_0°C,03-07-2025,11-05-00AM.mp4
# larvae_temp,27_0°C,03-07-2025,11-05-16AM.mp4
# larvae_temp,27_0°C,03-07-2025,11-05-55AM.mp4
# larvae_temp,27_0°C,14-10-2024,02-49-45PM.mp4
# larvae_temp,27_0°C,14-10-2024,02-50-39PM.mp4
# larvae_temp,27_0°C,14-10-2024,03-51-23PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-36-58PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-37-29PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-37-37PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-38-00PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-42-04PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-42-58PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-43-06PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-43-37PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-43-45PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-43-53PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-44-01PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-46-23PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-47-19PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-47-42PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-48-52PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-54-29PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-56-11PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-59-16PM.mp4
# larvae_temp,27_1°C,03-07-2025,01-59-40PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-00-19PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-01-29PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-04-23PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-05-02PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-05-17PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-05-49PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-06-04PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-10-51PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-11-15PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-11-54PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-12-02PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-12-33PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-12-40PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-12-48PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-13-19PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-15-38PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-15-45PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-16-01PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-16-09PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-16-56PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-17-11PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-24-43PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-24-51PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-24-59PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-25-14PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-26-01PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-26-09PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-26-32PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-28-06PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-28-14PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-29-55PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-30-26PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-32-54PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-33-10PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-34-28PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-34-44PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-35-15PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-37-24PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-38-26PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-39-05PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-39-13PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-43-15PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-43-23PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-43-54PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-45-49PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-46-45PM.mp4
# larvae_temp,27_1°C,03-07-2025,02-47-47PM.mp4
# larvae_temp,27_1°C,03-07-2025,10-53-58AM.mp4
# larvae_temp,27_1°C,03-07-2025,10-54-14AM.mp4
# larvae_temp,27_1°C,03-07-2025,10-54-29AM.mp4
# larvae_temp,27_1°C,03-07-2025,10-55-32AM.mp4
# larvae_temp,27_1°C,03-07-2025,10-55-40AM.mp4
# larvae_temp,27_1°C,03-07-2025,10-56-11AM.mp4
# larvae_temp,27_1°C,03-07-2025,11-00-40AM.mp4
# larvae_temp,27_1°C,03-07-2025,11-00-48AM.mp4
# larvae_temp,27_1°C,03-07-2025,11-02-21AM.mp4
# larvae_temp,27_1°C,03-07-2025,11-02-45AM.mp4
# larvae_temp,27_1°C,03-07-2025,11-04-52AM.mp4
# larvae_temp,27_1°C,03-07-2025,11-05-31AM.mp4
# larvae_temp,27_1°C,03-07-2025,11-05-47AM.mp4
# larvae_temp,27_1°C,03-07-2025,11-06-18AM.mp4
# larvae_temp,27_1°C,03-07-2025,11-06-34AM.mp4
# larvae_temp,27_2°C,03-07-2025,01-26-59PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-28-49PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-32-41PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-32-57PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-33-20PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-33-59PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-36-04PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-36-42PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-37-06PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-37-21PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-37-45PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-37-52PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-38-08PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-42-12PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-42-20PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-43-14PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-44-09PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-44-16PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-44-24PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-47-26PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-56-18PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-59-08PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-59-24PM.mp4
# larvae_temp,27_2°C,03-07-2025,01-59-47PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-00-34PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-00-58PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-03-44PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-04-38PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-11-07PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-11-46PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-12-25PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-14-59PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-15-14PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-16-24PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-16-32PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-16-40PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-17-19PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-19-57PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-21-30PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-21-38PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-24-19PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-24-35PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-25-06PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-25-30PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-25-38PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-25-45PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-33-57PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-34-05PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-34-13PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-37-16PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-38-19PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-43-07PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-47-31PM.mp4
# larvae_temp,27_2°C,03-07-2025,02-47-39PM.mp4
# larvae_temp,27_2°C,03-07-2025,10-54-06AM.mp4
# larvae_temp,27_2°C,03-07-2025,10-56-03AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-00-16AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-00-24AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-01-03AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-01-27AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-01-42AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-01-50AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-01-58AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-02-06AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-02-13AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-04-45AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-05-08AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-05-24AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-05-39AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-06-03AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-06-26AM.mp4
# larvae_temp,27_2°C,03-07-2025,11-06-49AM.mp4
# larvae_temp,27_2°C,14-10-2024,02-34-18PM.mp4
# larvae_temp,27_2°C,14-10-2024,03-51-31PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-25-41PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-26-35PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-26-51PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-28-56PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-29-04PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-29-12PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-29-20PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-29-28PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-29-35PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-30-14PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-30-30PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-30-45PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-32-25PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-32-33PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-32-49PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-33-28PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-33-36PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-33-51PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-34-22PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-34-30PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-36-19PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-36-35PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-37-13PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-38-24PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-42-51PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-43-22PM.mp4
# larvae_temp,27_3°C,03-07-2025,01-59-55PM.mp4
# larvae_temp,27_3°C,03-07-2025,02-03-59PM.mp4
# larvae_temp,27_3°C,03-07-2025,02-12-17PM.mp4
# larvae_temp,27_3°C,03-07-2025,02-15-07PM.mp4
# larvae_temp,27_3°C,03-07-2025,02-16-48PM.mp4
# larvae_temp,27_3°C,03-07-2025,02-19-18PM.mp4
# larvae_temp,27_3°C,03-07-2025,02-19-49PM.mp4
# larvae_temp,27_3°C,03-07-2025,02-20-04PM.mp4
# larvae_temp,27_3°C,03-07-2025,02-20-12PM.mp4
# larvae_temp,27_3°C,03-07-2025,02-20-59PM.mp4
# larvae_temp,27_3°C,03-07-2025,02-21-15PM.mp4
# larvae_temp,27_3°C,03-07-2025,02-27-58PM.mp4
# larvae_temp,27_3°C,03-07-2025,02-30-11PM.mp4
# larvae_temp,27_3°C,03-07-2025,02-30-19PM.mp4
# larvae_temp,27_3°C,03-07-2025,11-00-32AM.mp4
# larvae_temp,27_3°C,03-07-2025,11-00-56AM.mp4
# larvae_temp,27_3°C,03-07-2025,11-01-11AM.mp4
# larvae_temp,27_3°C,03-07-2025,11-01-19AM.mp4
# larvae_temp,27_3°C,03-07-2025,11-04-29AM.mp4
# larvae_temp,27_3°C,14-10-2024,03-51-16PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-21-21PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-21-52PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-22-24PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-24-54PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-25-02PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-25-18PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-25-25PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-25-49PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-25-56PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-26-12PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-26-20PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-26-28PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-26-43PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-28-16PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-28-25PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-28-33PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-28-41PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-29-51PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-32-01PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-33-04PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-33-12PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-34-14PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-36-11PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-36-27PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-36-50PM.mp4
# larvae_temp,27_4°C,03-07-2025,01-38-16PM.mp4
# larvae_temp,27_4°C,03-07-2025,02-11-23PM.mp4
# larvae_temp,27_4°C,03-07-2025,02-13-11PM.mp4
# larvae_temp,27_4°C,03-07-2025,02-15-30PM.mp4
# larvae_temp,27_4°C,03-07-2025,02-19-09PM.mp4
# larvae_temp,27_4°C,03-07-2025,02-19-33PM.mp4
# larvae_temp,27_4°C,03-07-2025,02-19-41PM.mp4
# larvae_temp,27_4°C,03-07-2025,02-20-28PM.mp4
# larvae_temp,27_4°C,03-07-2025,02-20-43PM.mp4
# larvae_temp,27_4°C,03-07-2025,02-20-51PM.mp4
# larvae_temp,27_4°C,03-07-2025,02-21-07PM.mp4
# larvae_temp,27_4°C,03-07-2025,02-21-22PM.mp4
# larvae_temp,27_4°C,03-07-2025,02-24-28PM.mp4
# larvae_temp,27_4°C,03-07-2025,02-26-17PM.mp4
# larvae_temp,27_4°C,03-07-2025,11-04-20AM.mp4
# larvae_temp,27_4°C,03-07-2025,11-06-42AM.mp4
# larvae_temp,27_4°C,14-10-2024,02-34-34PM.mp4
# larvae_temp,27_4°C,15-10-2024,12-34-32PM.mp4
# larvae_temp,27_5°C,03-07-2025,01-20-42PM.mp4
# larvae_temp,27_5°C,03-07-2025,01-22-00PM.mp4
# larvae_temp,27_5°C,03-07-2025,01-25-10PM.mp4
# larvae_temp,27_5°C,03-07-2025,01-26-04PM.mp4
# larvae_temp,27_5°C,03-07-2025,01-29-43PM.mp4
# larvae_temp,27_5°C,03-07-2025,01-29-59PM.mp4
# larvae_temp,27_5°C,03-07-2025,01-30-06PM.mp4
# larvae_temp,27_5°C,03-07-2025,01-30-22PM.mp4
# larvae_temp,27_5°C,03-07-2025,01-30-37PM.mp4
# larvae_temp,27_5°C,03-07-2025,01-33-43PM.mp4
# larvae_temp,27_5°C,03-07-2025,01-35-55PM.mp4
# larvae_temp,27_5°C,03-07-2025,02-14-50PM.mp4
# larvae_temp,27_5°C,03-07-2025,02-19-26PM.mp4
# larvae_temp,27_5°C,03-07-2025,02-20-20PM.mp4
# larvae_temp,27_5°C,03-07-2025,02-20-36PM.mp4
# larvae_temp,27_5°C,03-07-2025,02-26-25PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-16-42PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-17-29PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-20-27PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-20-35PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-20-50PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-21-14PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-21-29PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-21-45PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-22-16PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-24-30PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-24-47PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-25-33PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-32-10PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-32-18PM.mp4
# larvae_temp,27_6°C,03-07-2025,01-34-07PM.mp4
# larvae_temp,27_6°C,16-10-2024,03-46-59PM.mp4
# larvae_temp,27_7°C,03-07-2025,01-16-27PM.mp4
# larvae_temp,27_7°C,03-07-2025,01-17-37PM.mp4
# larvae_temp,27_7°C,03-07-2025,01-20-03PM.mp4
# larvae_temp,27_7°C,03-07-2025,01-20-11PM.mp4
# larvae_temp,27_7°C,03-07-2025,01-20-19PM.mp4
# larvae_temp,27_7°C,03-07-2025,01-20-58PM.mp4
# larvae_temp,27_7°C,03-07-2025,01-21-06PM.mp4
# larvae_temp,27_7°C,03-07-2025,01-21-37PM.mp4
# larvae_temp,27_7°C,15-10-2024,01-00-51PM.mp4
# larvae_temp,27_8°C,03-07-2025,01-15-56PM.mp4
# larvae_temp,27_8°C,03-07-2025,01-16-19PM.mp4
# larvae_temp,27_8°C,03-07-2025,01-17-13PM.mp4
# larvae_temp,27_8°C,03-07-2025,01-17-45PM.mp4
# larvae_temp,27_8°C,03-07-2025,01-17-52PM.mp4
# larvae_temp,27_8°C,03-07-2025,01-19-55PM.mp4
# larvae_temp,27_8°C,03-07-2025,01-22-08PM.mp4
# larvae_temp,27_8°C,03-07-2025,01-24-39PM.mp4
# larvae_temp,27_9°C,03-07-2025,01-12-47PM.mp4
# larvae_temp,27_9°C,03-07-2025,01-15-32PM.mp4
# larvae_temp,27_9°C,03-07-2025,01-16-03PM.mp4
# larvae_temp,27_9°C,03-07-2025,01-16-34PM.mp4
# larvae_temp,27_9°C,03-07-2025,01-16-50PM.mp4
# larvae_temp,27_9°C,03-07-2025,01-16-58PM.mp4
# larvae_temp,27_9°C,03-07-2025,01-17-06PM.mp4
# larvae_temp,27_9°C,03-07-2025,01-17-21PM.mp4
# larvae_temp,27_9°C,03-07-2025,12-47-59PM.mp4
# larvae_temp,27_9°C,03-07-2025,12-48-30PM.mp4
# larvae_temp,27_9°C,03-07-2025,12-52-29PM.mp4
# larvae_temp,28_0°C,03-07-2025,01-00-51PM.mp4
# larvae_temp,28_0°C,03-07-2025,01-00-59PM.mp4
# larvae_temp,28_0°C,03-07-2025,01-12-15PM.mp4
# larvae_temp,28_0°C,03-07-2025,01-13-18PM.mp4
# larvae_temp,28_0°C,03-07-2025,01-13-33PM.mp4
# larvae_temp,28_0°C,03-07-2025,01-15-23PM.mp4
# larvae_temp,28_0°C,03-07-2025,12-47-28PM.mp4
# larvae_temp,28_0°C,03-07-2025,12-47-36PM.mp4
# larvae_temp,28_0°C,03-07-2025,12-47-43PM.mp4
# larvae_temp,28_0°C,03-07-2025,12-47-51PM.mp4
# larvae_temp,28_0°C,03-07-2025,12-48-15PM.mp4
# larvae_temp,28_0°C,03-07-2025,12-51-58PM.mp4
# larvae_temp,28_0°C,03-07-2025,12-52-05PM.mp4
# larvae_temp,28_0°C,03-07-2025,12-52-13PM.mp4
# larvae_temp,28_0°C,03-07-2025,12-52-37PM.mp4
# larvae_temp,28_0°C,03-07-2025,12-52-44PM.mp4
# larvae_temp,28_0°C,03-07-2025,12-53-16PM.mp4
# larvae_temp,28_0°C,03-07-2025,12-53-31PM.mp4
# larvae_temp,28_1°C,03-07-2025,01-00-04PM.mp4
# larvae_temp,28_1°C,03-07-2025,01-01-46PM.mp4
# larvae_temp,28_1°C,03-07-2025,01-02-17PM.mp4
# larvae_temp,28_1°C,03-07-2025,01-02-32PM.mp4
# larvae_temp,28_1°C,03-07-2025,01-05-11PM.mp4
# larvae_temp,28_1°C,03-07-2025,01-13-10PM.mp4
# larvae_temp,28_1°C,03-07-2025,01-13-41PM.mp4
# larvae_temp,28_1°C,03-07-2025,01-15-40PM.mp4
# larvae_temp,28_1°C,03-07-2025,01-15-48PM.mp4
# larvae_temp,28_1°C,03-07-2025,01-16-11PM.mp4
# larvae_temp,28_1°C,03-07-2025,12-47-05PM.mp4
# larvae_temp,28_1°C,03-07-2025,12-47-12PM.mp4
# larvae_temp,28_1°C,03-07-2025,12-48-07PM.mp4
# larvae_temp,28_1°C,03-07-2025,12-49-09PM.mp4
# larvae_temp,28_1°C,03-07-2025,12-49-17PM.mp4
# larvae_temp,28_1°C,03-07-2025,12-52-21PM.mp4
# larvae_temp,28_1°C,03-07-2025,12-52-52PM.mp4
# larvae_temp,28_1°C,03-07-2025,12-53-23PM.mp4
# larvae_temp,28_1°C,03-07-2025,12-53-47PM.mp4
# larvae_temp,28_1°C,16-10-2024,04-23-45PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-00-12PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-00-36PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-00-43PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-01-07PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-01-22PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-01-38PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-05-19PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-05-42PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-05-50PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-06-06PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-06-13PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-06-21PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-11-36PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-12-08PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-12-23PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-13-26PM.mp4
# larvae_temp,28_2°C,03-07-2025,01-13-49PM.mp4
# larvae_temp,28_2°C,03-07-2025,12-46-56PM.mp4
# larvae_temp,28_2°C,03-07-2025,12-47-20PM.mp4
# larvae_temp,28_2°C,03-07-2025,12-48-23PM.mp4
# larvae_temp,28_2°C,03-07-2025,12-48-38PM.mp4
# larvae_temp,28_2°C,03-07-2025,12-48-54PM.mp4
# larvae_temp,28_2°C,03-07-2025,12-49-25PM.mp4
# larvae_temp,28_2°C,03-07-2025,12-51-34PM.mp4
# larvae_temp,28_2°C,03-07-2025,12-51-50PM.mp4
# larvae_temp,28_2°C,03-07-2025,12-53-00PM.mp4
# larvae_temp,28_2°C,03-07-2025,12-53-08PM.mp4
# larvae_temp,28_2°C,03-07-2025,12-53-39PM.mp4
# larvae_temp,28_2°C,03-07-2025,12-53-55PM.mp4
# larvae_temp,28_2°C,15-10-2024,12-37-02PM.mp4
# larvae_temp,28_2°C,16-10-2024,04-29-08PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-00-28PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-01-15PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-01-30PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-01-54PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-02-09PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-02-25PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-04-15PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-04-32PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-04-47PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-04-55PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-05-34PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-05-58PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-06-45PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-12-00PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-12-31PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-12-39PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-12-54PM.mp4
# larvae_temp,28_3°C,03-07-2025,01-13-02PM.mp4
# larvae_temp,28_3°C,03-07-2025,12-48-46PM.mp4
# larvae_temp,28_3°C,03-07-2025,12-49-02PM.mp4
# larvae_temp,28_3°C,03-07-2025,12-51-42PM.mp4
# larvae_temp,28_3°C,16-10-2024,02-42-45PM.mp4
# larvae_temp,28_4°C,03-07-2025,01-00-20PM.mp4
# larvae_temp,28_4°C,03-07-2025,01-02-01PM.mp4
# larvae_temp,28_4°C,03-07-2025,01-05-27PM.mp4
# larvae_temp,28_4°C,03-07-2025,01-06-37PM.mp4
# larvae_temp,28_4°C,03-07-2025,01-11-20PM.mp4
# larvae_temp,28_4°C,03-07-2025,01-11-52PM.mp4
# larvae_temp,28_4°C,03-07-2025,12-51-26PM.mp4
# larvae_temp,28_4°C,15-10-2024,03-55-41PM.mp4
# larvae_temp,28_5°C,03-07-2025,01-04-24PM.mp4
# larvae_temp,28_5°C,03-07-2025,01-04-40PM.mp4
# larvae_temp,28_5°C,03-07-2025,01-05-03PM.mp4
# larvae_temp,28_5°C,03-07-2025,01-06-29PM.mp4
# larvae_temp,28_5°C,03-07-2025,01-11-29PM.mp4
# larvae_temp,28_5°C,03-07-2025,01-11-44PM.mp4
# larvae_temp,28_7°C,15-10-2024,01-06-32PM.mp4
# larvae_temp,28_7°C,15-10-2024,01-26-38PM.mp4
# larvae_temp,28_8°C,14-10-2024,03-32-52PM.mp4
# larvae_temp,29_0°C,15-10-2024,12-39-14PM.mp4
# larvae_temp,29_1°C,15-10-2024,12-38-20PM.mp4

# %%
# count the number of videos in all_phs1_phs6lv1_lv38_vids
video_count = len(os.listdir('all_phs1_phs6lv1_lv38_vids'))
print(f"Number of videos in the folder: {video_count}")
# Out:
# Number of videos in the folder: 1351

# %%
#import excel metadata
metadata_file = pd.read_excel('all_phs1_phs6lv1_lv38_vids_meta_data.xlsx')

# %%
#display contents of metadata excel file
metadata_file
# Out:
#      larvae_Id                                    video_name       tag
# 0         LV_1  larvae_temp,25_0°C,14-10-2024,02-32-12PM.mp4  positive
# 1          NaN  larvae_temp,25_1°C,14-10-2024,02-32-21PM.mp4  positive
# 2          NaN  larvae_temp,25_0°C,14-10-2024,02-32-29PM.mp4  positive
# 3          NaN  larvae_temp,25_0°C,14-10-2024,02-32-37PM.mp4  positive
# 4          NaN  larvae_temp,25_0°C,14-10-2024,02-32-44PM.mp4  positive
# ...        ...                                           ...       ...
# 1346       NaN  larvae_temp,27_1°C,03-07-2025,02-47-47PM.mp4  negative
# 1347       NaN  larvae_temp,26_9°C,03-07-2025,02-47-54PM.mp4  negative
# 1348       NaN  larvae_temp,27_0°C,03-07-2025,02-48-02PM.mp4  negative
# 1349       NaN  larvae_temp,27_0°C,03-07-2025,02-48-10PM.mp4  negative
# 1350       NaN  larvae_temp,26_9°C,03-07-2025,02-48-18PM.mp4  negative
#
# [1351 rows x 3 columns]

# %%
metadata_file.shape
# Out:
# (1351, 3)

# %%
# FRAME PREPROCESSING
def preprocess_frame(frame, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT)):
    """
    Center crop, resize, and normalize a frame for model input.
    Args:
        frame (np.ndarray): Raw BGR frame from video.
        target_size (tuple): (width, height) for resizing.
    Returns:
        np.ndarray: Preprocessed frame normalized to [0,1].
    """
    h, w = frame.shape[:2]
    min_dim = min(h, w)
    start_x = (w - min_dim) // 2
    start_y = (h - min_dim) // 2
    cropped_frame = frame[start_y:start_y + min_dim, start_x:start_x + min_dim]
    frame_resized = cv2.resize(cropped_frame, target_size)
    return frame_resized  # leave as 0-255 for SSIM selection

# %%
def extract_all_frames(video_path, max_frames):
    """
    Extracts up to `max_frames` frames from a video.
    Returns array of frames (0-255, dtype=uint8).
    """
    cap = cv2.VideoCapture(video_path)
    frames = []
    frame_count = 0

    while frame_count < max_frames:
        ret, frame = cap.read()
        if not ret:
            break
        frame = preprocess_frame(frame)
        frames.append(frame)
        frame_count += 1

    cap.release()
    frames_array = np.array(frames)
    print(f"Extracted {len(frames_array)} frames from {video_path}. Target: {max_frames}")
    return frames_array

# %%
def segment_frames(frames, num_segments=NUM_FRAMES):
    """
    Divide frames into equal segments for SSIM sampling.
    """
    total_frames = len(frames)
    segments = np.array_split(np.arange(total_frames), num_segments)
    print("Segments (frame index ranges):")
    for i, seg in enumerate(segments):
        print(f" Segment {i}: {seg}")
    return segments

# %%
def sample_diverse_frames(frames, segments, ssim_threshold=SSIM_THRESHOLD):
    """
    Selects diverse frames per segment using SSIM, with bootstrapping.
    Returns selected frames array or None if failed.
    """
    selected_frames = []
    prev_gray = None

    for seg_idx, segment in enumerate(segments):
        print(f"\nSegment {seg_idx} original indices: {segment}")
        shuffled_sets = [np.random.choice(segment, size=len(segment), replace=True) for _ in range(NUM_SHUFFLES)]
        for shuffle_idx, s in enumerate(shuffled_sets):
            print(f"Segment {seg_idx} shuffle {shuffle_idx + 1} indices: {s}")
        all_candidates = np.concatenate(shuffled_sets)
        np.random.shuffle(all_candidates)

        best_frame = None
        best_similarity = 1.0
        fallback_frame = None
        fallback_similarity = 1.0

        for idx in all_candidates:
            frame = frames[idx]
            gray = cv2.cvtColor(frame.astype('uint8'), cv2.COLOR_BGR2GRAY)

            if prev_gray is None:
                selected_frames.append(frame)
                prev_gray = gray
                print(f"Segment {seg_idx}: Picked index {idx} (SSIM=N/A, first frame)")
                break

            similarity = ssim(prev_gray, gray, data_range=255) #changed gray.max() - gray.min()
            print(f"Segment {seg_idx}: SSIM(prev, frame[{idx}]) = {similarity:.4f}")

            if similarity < ssim_threshold:
                if similarity < best_similarity:
                    best_similarity = similarity
                    best_frame = (frame, gray, idx)
            else:
                if similarity < fallback_similarity:
                    fallback_similarity = similarity
                    fallback_frame = (frame, gray, idx)

        else:
            if best_frame:
                selected_frames.append(best_frame[0])
                prev_gray = best_frame[1]
                print(f"Segment {seg_idx}: Picked index {best_frame[2]} below threshold")
            elif fallback_frame:
                selected_frames.append(fallback_frame[0])
                prev_gray = fallback_frame[1]
                print(f"Segment {seg_idx}: Picked index {fallback_frame[2]} as fallback")
            else:
                print(f"Segment {seg_idx}: No valid frames found.")

    if len(selected_frames) == len(segments):

        # NORMALIZATION FOR InceptionV3 AFTER SSIM
        frames_array = np.array(selected_frames).astype("float32")
        frames_array = frames_array / 127.5 - 1  # [-1,1] normalization
        return frames_array
    else:
        print("Not enough diverse frames selected.")
        return None

# %%
def load_video_data(data_path, metadata_file, num_frames=NUM_FRAMES):
    """
    Loads and processes videos into machine learning samples.
    Returns X (frame arrays) and y (binary labels)
    """
    metadata = pd.read_excel(metadata_file)
    X, y = [], []
    skipped_videos = []

    for _, row in metadata.iterrows():
        video_name = row['video_name']
        video_path = os.path.join(data_path, video_name)
        try:
            all_frames = extract_all_frames(video_path, max_frames)
            if all_frames is None or len(all_frames) < MIN_FRAMES:
                skipped_videos.append((video_name, "insufficient frames"))
                continue

            segments = segment_frames(all_frames, num_frames)
            sampled = sample_diverse_frames(all_frames, segments, SSIM_THRESHOLD)
            if sampled is not None:
                X.append(sampled)
                label = 1 if row['tag'].strip().lower() == 'positive' else 0
                y.append(label)
            else:
                skipped_videos.append((video_name, "SSIM sampling failed"))
        except Exception as e:
            skipped_videos.append((video_name, f"exception: {str(e)}"))

    print("\nSkipped videos summary:")
    for vid, reason in skipped_videos:
        print(f"- {vid}: {reason}")

    return np.array(X), np.array(y)

# %%
# === MAIN EXECUTION ===
if __name__ == "__main__":
    data_path = 'all_phs1_phs6lv1_lv38_vids'
    metadata_file = 'all_phs1_phs6lv1_lv38_vids_meta_data.xlsx'

    print("Loading and preprocessing video data...")
    X, y = load_video_data(data_path, metadata_file)

    print("Shape of X after loading and normalization:", X.shape)
    print("Shape of y after loading:", y.shape)

    print("Saving preprocessed arrays...")
    np.save('X_prep_segments_30.npy', X)
    np.save('y_labels_segments_30.npy', y)

    print("Feature shape:", X.shape)
    print("Label shape:", y.shape)
# Out:
# Streaming output truncated to the last 5000 lines.
# Segment 29: SSIM(prev, frame[118]) = 0.9960
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: Picked index 119 as fallback
# Extracted 120 frames from all_phs1_phs6lv1_lv38_vids/larvae_temp,27_1°C,03-07-2025,02-47-47PM.mp4. Target: 120
# Segments (frame index ranges):
#  Segment 0: [0 1 2 3]
#  Segment 1: [4 5 6 7]
#  Segment 2: [ 8  9 10 11]
#  Segment 3: [12 13 14 15]
#  Segment 4: [16 17 18 19]
#  Segment 5: [20 21 22 23]
#  Segment 6: [24 25 26 27]
#  Segment 7: [28 29 30 31]
#  Segment 8: [32 33 34 35]
#  Segment 9: [36 37 38 39]
#  Segment 10: [40 41 42 43]
#  Segment 11: [44 45 46 47]
#  Segment 12: [48 49 50 51]
#  Segment 13: [52 53 54 55]
#  Segment 14: [56 57 58 59]
#  Segment 15: [60 61 62 63]
#  Segment 16: [64 65 66 67]
#  Segment 17: [68 69 70 71]
#  Segment 18: [72 73 74 75]
#  Segment 19: [76 77 78 79]
#  Segment 20: [80 81 82 83]
#  Segment 21: [84 85 86 87]
#  Segment 22: [88 89 90 91]
#  Segment 23: [92 93 94 95]
#  Segment 24: [96 97 98 99]
#  Segment 25: [100 101 102 103]
#  Segment 26: [104 105 106 107]
#  Segment 27: [108 109 110 111]
#  Segment 28: [112 113 114 115]
#  Segment 29: [116 117 118 119]
#
# Segment 0 original indices: [0 1 2 3]
# Segment 0 shuffle 1 indices: [1 2 0 3]
# Segment 0 shuffle 2 indices: [3 1 2 3]
# Segment 0 shuffle 3 indices: [2 3 3 1]
# Segment 0 shuffle 4 indices: [0 1 3 2]
# Segment 0 shuffle 5 indices: [2 0 2 0]
# Segment 0 shuffle 6 indices: [2 1 1 1]
# Segment 0: Picked index 0 (SSIM=N/A, first frame)
#
# Segment 1 original indices: [4 5 6 7]
# Segment 1 shuffle 1 indices: [6 5 4 6]
# Segment 1 shuffle 2 indices: [4 5 5 5]
# Segment 1 shuffle 3 indices: [4 7 6 6]
# Segment 1 shuffle 4 indices: [7 4 5 5]
# Segment 1 shuffle 5 indices: [5 6 7 7]
# Segment 1 shuffle 6 indices: [4 4 6 7]
# Segment 1: SSIM(prev, frame[5]) = 0.9921
# Segment 1: SSIM(prev, frame[7]) = 0.9915
# Segment 1: SSIM(prev, frame[5]) = 0.9921
# Segment 1: SSIM(prev, frame[4]) = 0.9921
# Segment 1: SSIM(prev, frame[4]) = 0.9921
# Segment 1: SSIM(prev, frame[4]) = 0.9921
# Segment 1: SSIM(prev, frame[5]) = 0.9921
# Segment 1: SSIM(prev, frame[4]) = 0.9921
# Segment 1: SSIM(prev, frame[7]) = 0.9915
# Segment 1: SSIM(prev, frame[5]) = 0.9921
# Segment 1: SSIM(prev, frame[6]) = 0.9918
# Segment 1: SSIM(prev, frame[6]) = 0.9918
# Segment 1: SSIM(prev, frame[6]) = 0.9918
# Segment 1: SSIM(prev, frame[6]) = 0.9918
# Segment 1: SSIM(prev, frame[6]) = 0.9918
# Segment 1: SSIM(prev, frame[7]) = 0.9915
# Segment 1: SSIM(prev, frame[5]) = 0.9921
# Segment 1: SSIM(prev, frame[6]) = 0.9918
# Segment 1: SSIM(prev, frame[4]) = 0.9921
# Segment 1: SSIM(prev, frame[5]) = 0.9921
# Segment 1: SSIM(prev, frame[4]) = 0.9921
# Segment 1: SSIM(prev, frame[5]) = 0.9921
# Segment 1: SSIM(prev, frame[7]) = 0.9915
# Segment 1: SSIM(prev, frame[7]) = 0.9915
# Segment 1: Picked index 7 as fallback
#
# Segment 2 original indices: [ 8  9 10 11]
# Segment 2 shuffle 1 indices: [10 11 11 10]
# Segment 2 shuffle 2 indices: [ 8 11 10 10]
# Segment 2 shuffle 3 indices: [ 9 11 10  9]
# Segment 2 shuffle 4 indices: [10 10 10  8]
# Segment 2 shuffle 5 indices: [11  9 10  9]
# Segment 2 shuffle 6 indices: [11  8 10 10]
# Segment 2: SSIM(prev, frame[11]) = 0.9938
# Segment 2: SSIM(prev, frame[10]) = 0.9940
# Segment 2: SSIM(prev, frame[10]) = 0.9940
# Segment 2: SSIM(prev, frame[10]) = 0.9940
# Segment 2: SSIM(prev, frame[11]) = 0.9938
# Segment 2: SSIM(prev, frame[11]) = 0.9938
# Segment 2: SSIM(prev, frame[11]) = 0.9938
# Segment 2: SSIM(prev, frame[11]) = 0.9938
# Segment 2: SSIM(prev, frame[10]) = 0.9940
# Segment 2: SSIM(prev, frame[10]) = 0.9940
# Segment 2: SSIM(prev, frame[8]) = 0.9963
# Segment 2: SSIM(prev, frame[10]) = 0.9940
# Segment 2: SSIM(prev, frame[10]) = 0.9940
# Segment 2: SSIM(prev, frame[9]) = 0.9943
# Segment 2: SSIM(prev, frame[10]) = 0.9940
# Segment 2: SSIM(prev, frame[9]) = 0.9943
# Segment 2: SSIM(prev, frame[8]) = 0.9963
# Segment 2: SSIM(prev, frame[10]) = 0.9940
# Segment 2: SSIM(prev, frame[11]) = 0.9938
# Segment 2: SSIM(prev, frame[10]) = 0.9940
# Segment 2: SSIM(prev, frame[9]) = 0.9943
# Segment 2: SSIM(prev, frame[9]) = 0.9943
# Segment 2: SSIM(prev, frame[8]) = 0.9963
# Segment 2: SSIM(prev, frame[10]) = 0.9940
# Segment 2: Picked index 11 as fallback
#
# Segment 3 original indices: [12 13 14 15]
# Segment 3 shuffle 1 indices: [14 13 14 13]
# Segment 3 shuffle 2 indices: [14 12 14 13]
# Segment 3 shuffle 3 indices: [12 13 12 14]
# Segment 3 shuffle 4 indices: [15 12 13 13]
# Segment 3 shuffle 5 indices: [12 14 12 13]
# Segment 3 shuffle 6 indices: [15 13 15 15]
# Segment 3: SSIM(prev, frame[12]) = 0.9980
# Segment 3: SSIM(prev, frame[15]) = 0.9949
# Segment 3: SSIM(prev, frame[15]) = 0.9949
# Segment 3: SSIM(prev, frame[14]) = 0.9959
# Segment 3: SSIM(prev, frame[13]) = 0.9967
# Segment 3: SSIM(prev, frame[14]) = 0.9959
# Segment 3: SSIM(prev, frame[14]) = 0.9959
# Segment 3: SSIM(prev, frame[14]) = 0.9959
# Segment 3: SSIM(prev, frame[13]) = 0.9967
# Segment 3: SSIM(prev, frame[15]) = 0.9949
# Segment 3: SSIM(prev, frame[14]) = 0.9959
# Segment 3: SSIM(prev, frame[13]) = 0.9967
# Segment 3: SSIM(prev, frame[15]) = 0.9949
# Segment 3: SSIM(prev, frame[13]) = 0.9967
# Segment 3: SSIM(prev, frame[13]) = 0.9967
# Segment 3: SSIM(prev, frame[12]) = 0.9980
# Segment 3: SSIM(prev, frame[13]) = 0.9967
# Segment 3: SSIM(prev, frame[12]) = 0.9980
# Segment 3: SSIM(prev, frame[14]) = 0.9959
# Segment 3: SSIM(prev, frame[13]) = 0.9967
# Segment 3: SSIM(prev, frame[12]) = 0.9980
# Segment 3: SSIM(prev, frame[13]) = 0.9967
# Segment 3: SSIM(prev, frame[12]) = 0.9980
# Segment 3: SSIM(prev, frame[12]) = 0.9980
# Segment 3: Picked index 15 as fallback
#
# Segment 4 original indices: [16 17 18 19]
# Segment 4 shuffle 1 indices: [16 16 16 16]
# Segment 4 shuffle 2 indices: [19 19 17 18]
# Segment 4 shuffle 3 indices: [17 16 17 16]
# Segment 4 shuffle 4 indices: [18 19 18 19]
# Segment 4 shuffle 5 indices: [18 18 17 16]
# Segment 4 shuffle 6 indices: [17 17 18 16]
# Segment 4: SSIM(prev, frame[19]) = 0.9954
# Segment 4: SSIM(prev, frame[16]) = 0.9970
# Segment 4: SSIM(prev, frame[16]) = 0.9970
# Segment 4: SSIM(prev, frame[17]) = 0.9965
# Segment 4: SSIM(prev, frame[17]) = 0.9965
# Segment 4: SSIM(prev, frame[16]) = 0.9970
# Segment 4: SSIM(prev, frame[17]) = 0.9965
# Segment 4: SSIM(prev, frame[18]) = 0.9959
# Segment 4: SSIM(prev, frame[19]) = 0.9954
# Segment 4: SSIM(prev, frame[16]) = 0.9970
# Segment 4: SSIM(prev, frame[17]) = 0.9965
# Segment 4: SSIM(prev, frame[19]) = 0.9954
# Segment 4: SSIM(prev, frame[16]) = 0.9970
# Segment 4: SSIM(prev, frame[18]) = 0.9959
# Segment 4: SSIM(prev, frame[17]) = 0.9965
# Segment 4: SSIM(prev, frame[18]) = 0.9959
# Segment 4: SSIM(prev, frame[16]) = 0.9970
# Segment 4: SSIM(prev, frame[16]) = 0.9970
# Segment 4: SSIM(prev, frame[18]) = 0.9959
# Segment 4: SSIM(prev, frame[19]) = 0.9954
# Segment 4: SSIM(prev, frame[18]) = 0.9959
# Segment 4: SSIM(prev, frame[17]) = 0.9965
# Segment 4: SSIM(prev, frame[18]) = 0.9959
# Segment 4: SSIM(prev, frame[16]) = 0.9970
# Segment 4: Picked index 19 as fallback
#
# Segment 5 original indices: [20 21 22 23]
# Segment 5 shuffle 1 indices: [22 22 22 23]
# Segment 5 shuffle 2 indices: [23 22 21 23]
# Segment 5 shuffle 3 indices: [21 20 21 21]
# Segment 5 shuffle 4 indices: [23 22 23 22]
# Segment 5 shuffle 5 indices: [21 21 20 21]
# Segment 5 shuffle 6 indices: [23 20 23 22]
# Segment 5: SSIM(prev, frame[23]) = 0.9959
# Segment 5: SSIM(prev, frame[21]) = 0.9971
# Segment 5: SSIM(prev, frame[23]) = 0.9959
# Segment 5: SSIM(prev, frame[21]) = 0.9971
# Segment 5: SSIM(prev, frame[23]) = 0.9959
# Segment 5: SSIM(prev, frame[23]) = 0.9959
# Segment 5: SSIM(prev, frame[23]) = 0.9959
# Segment 5: SSIM(prev, frame[22]) = 0.9964
# Segment 5: SSIM(prev, frame[21]) = 0.9971
# Segment 5: SSIM(prev, frame[22]) = 0.9964
# Segment 5: SSIM(prev, frame[22]) = 0.9964
# Segment 5: SSIM(prev, frame[22]) = 0.9964
# Segment 5: SSIM(prev, frame[23]) = 0.9959
# Segment 5: SSIM(prev, frame[22]) = 0.9964
# Segment 5: SSIM(prev, frame[21]) = 0.9971
# Segment 5: SSIM(prev, frame[20]) = 0.9982
# Segment 5: SSIM(prev, frame[20]) = 0.9982
# Segment 5: SSIM(prev, frame[22]) = 0.9964
# Segment 5: SSIM(prev, frame[20]) = 0.9982
# Segment 5: SSIM(prev, frame[21]) = 0.9971
# Segment 5: SSIM(prev, frame[23]) = 0.9959
# Segment 5: SSIM(prev, frame[21]) = 0.9971
# Segment 5: SSIM(prev, frame[22]) = 0.9964
# Segment 5: SSIM(prev, frame[21]) = 0.9971
# Segment 5: Picked index 23 as fallback
#
# Segment 6 original indices: [24 25 26 27]
# Segment 6 shuffle 1 indices: [26 24 25 27]
# Segment 6 shuffle 2 indices: [24 24 27 26]
# Segment 6 shuffle 3 indices: [26 27 27 27]
# Segment 6 shuffle 4 indices: [27 26 27 24]
# Segment 6 shuffle 5 indices: [25 27 25 26]
# Segment 6 shuffle 6 indices: [27 26 26 25]
# Segment 6: SSIM(prev, frame[25]) = 0.9965
# Segment 6: SSIM(prev, frame[27]) = 0.9953
# Segment 6: SSIM(prev, frame[26]) = 0.9958
# Segment 6: SSIM(prev, frame[27]) = 0.9953
# Segment 6: SSIM(prev, frame[25]) = 0.9965
# Segment 6: SSIM(prev, frame[24]) = 0.9981
# Segment 6: SSIM(prev, frame[26]) = 0.9958
# Segment 6: SSIM(prev, frame[25]) = 0.9965
# Segment 6: SSIM(prev, frame[26]) = 0.9958
# Segment 6: SSIM(prev, frame[27]) = 0.9953
# Segment 6: SSIM(prev, frame[26]) = 0.9958
# Segment 6: SSIM(prev, frame[26]) = 0.9958
# Segment 6: SSIM(prev, frame[27]) = 0.9953
# Segment 6: SSIM(prev, frame[24]) = 0.9981
# Segment 6: SSIM(prev, frame[26]) = 0.9958
# Segment 6: SSIM(prev, frame[27]) = 0.9953
# Segment 6: SSIM(prev, frame[26]) = 0.9958
# Segment 6: SSIM(prev, frame[25]) = 0.9965
# Segment 6: SSIM(prev, frame[27]) = 0.9953
# Segment 6: SSIM(prev, frame[24]) = 0.9981
# Segment 6: SSIM(prev, frame[24]) = 0.9981
# Segment 6: SSIM(prev, frame[27]) = 0.9953
# Segment 6: SSIM(prev, frame[27]) = 0.9953
# Segment 6: SSIM(prev, frame[27]) = 0.9953
# Segment 6: Picked index 27 as fallback
#
# Segment 7 original indices: [28 29 30 31]
# Segment 7 shuffle 1 indices: [29 31 29 31]
# Segment 7 shuffle 2 indices: [28 28 30 30]
# Segment 7 shuffle 3 indices: [31 31 28 29]
# Segment 7 shuffle 4 indices: [29 29 31 28]
# Segment 7 shuffle 5 indices: [31 30 28 31]
# Segment 7 shuffle 6 indices: [28 31 28 29]
# Segment 7: SSIM(prev, frame[31]) = 0.9931
# Segment 7: SSIM(prev, frame[31]) = 0.9931
# Segment 7: SSIM(prev, frame[30]) = 0.9930
# Segment 7: SSIM(prev, frame[31]) = 0.9931
# Segment 7: SSIM(prev, frame[28]) = 0.9978
# Segment 7: SSIM(prev, frame[29]) = 0.9967
# Segment 7: SSIM(prev, frame[31]) = 0.9931
# Segment 7: SSIM(prev, frame[30]) = 0.9930
# Segment 7: SSIM(prev, frame[28]) = 0.9978
# Segment 7: SSIM(prev, frame[31]) = 0.9931
# Segment 7: SSIM(prev, frame[30]) = 0.9930
# Segment 7: SSIM(prev, frame[28]) = 0.9978
# Segment 7: SSIM(prev, frame[31]) = 0.9931
# Segment 7: SSIM(prev, frame[28]) = 0.9978
# Segment 7: SSIM(prev, frame[31]) = 0.9931
# Segment 7: SSIM(prev, frame[29]) = 0.9967
# Segment 7: SSIM(prev, frame[31]) = 0.9931
# Segment 7: SSIM(prev, frame[28]) = 0.9978
# Segment 7: SSIM(prev, frame[28]) = 0.9978
# Segment 7: SSIM(prev, frame[29]) = 0.9967
# Segment 7: SSIM(prev, frame[28]) = 0.9978
# Segment 7: SSIM(prev, frame[29]) = 0.9967
# Segment 7: SSIM(prev, frame[29]) = 0.9967
# Segment 7: SSIM(prev, frame[29]) = 0.9967
# Segment 7: Picked index 30 as fallback
#
# Segment 8 original indices: [32 33 34 35]
# Segment 8 shuffle 1 indices: [35 35 34 33]
# Segment 8 shuffle 2 indices: [32 32 32 32]
# Segment 8 shuffle 3 indices: [35 32 33 35]
# Segment 8 shuffle 4 indices: [32 34 32 33]
# Segment 8 shuffle 5 indices: [32 35 34 33]
# Segment 8 shuffle 6 indices: [32 34 34 32]
# Segment 8: SSIM(prev, frame[33]) = 0.9960
# Segment 8: SSIM(prev, frame[34]) = 0.9953
# Segment 8: SSIM(prev, frame[34]) = 0.9953
# Segment 8: SSIM(prev, frame[34]) = 0.9953
# Segment 8: SSIM(prev, frame[32]) = 0.9968
# Segment 8: SSIM(prev, frame[32]) = 0.9968
# Segment 8: SSIM(prev, frame[35]) = 0.9948
# Segment 8: SSIM(prev, frame[35]) = 0.9948
# Segment 8: SSIM(prev, frame[32]) = 0.9968
# Segment 8: SSIM(prev, frame[32]) = 0.9968
# Segment 8: SSIM(prev, frame[32]) = 0.9968
# Segment 8: SSIM(prev, frame[32]) = 0.9968
# Segment 8: SSIM(prev, frame[34]) = 0.9953
# Segment 8: SSIM(prev, frame[32]) = 0.9968
# Segment 8: SSIM(prev, frame[32]) = 0.9968
# Segment 8: SSIM(prev, frame[33]) = 0.9960
# Segment 8: SSIM(prev, frame[35]) = 0.9948
# Segment 8: SSIM(prev, frame[35]) = 0.9948
# Segment 8: SSIM(prev, frame[35]) = 0.9948
# Segment 8: SSIM(prev, frame[32]) = 0.9968
# Segment 8: SSIM(prev, frame[34]) = 0.9953
# Segment 8: SSIM(prev, frame[32]) = 0.9968
# Segment 8: SSIM(prev, frame[33]) = 0.9960
# Segment 8: SSIM(prev, frame[33]) = 0.9960
# Segment 8: Picked index 35 as fallback
#
# Segment 9 original indices: [36 37 38 39]
# Segment 9 shuffle 1 indices: [39 39 37 39]
# Segment 9 shuffle 2 indices: [39 36 39 38]
# Segment 9 shuffle 3 indices: [36 36 39 38]
# Segment 9 shuffle 4 indices: [39 39 39 37]
# Segment 9 shuffle 5 indices: [39 39 36 39]
# Segment 9 shuffle 6 indices: [37 39 37 38]
# Segment 9: SSIM(prev, frame[39]) = 0.9953
# Segment 9: SSIM(prev, frame[36]) = 0.9977
# Segment 9: SSIM(prev, frame[38]) = 0.9959
# Segment 9: SSIM(prev, frame[36]) = 0.9977
# Segment 9: SSIM(prev, frame[36]) = 0.9977
# Segment 9: SSIM(prev, frame[39]) = 0.9953
# Segment 9: SSIM(prev, frame[39]) = 0.9953
# Segment 9: SSIM(prev, frame[39]) = 0.9953
# Segment 9: SSIM(prev, frame[39]) = 0.9953
# Segment 9: SSIM(prev, frame[39]) = 0.9953
# Segment 9: SSIM(prev, frame[37]) = 0.9966
# Segment 9: SSIM(prev, frame[38]) = 0.9959
# Segment 9: SSIM(prev, frame[39]) = 0.9953
# Segment 9: SSIM(prev, frame[39]) = 0.9953
# Segment 9: SSIM(prev, frame[38]) = 0.9959
# Segment 9: SSIM(prev, frame[39]) = 0.9953
# Segment 9: SSIM(prev, frame[39]) = 0.9953
# Segment 9: SSIM(prev, frame[39]) = 0.9953
# Segment 9: SSIM(prev, frame[37]) = 0.9966
# Segment 9: SSIM(prev, frame[36]) = 0.9977
# Segment 9: SSIM(prev, frame[37]) = 0.9966
# Segment 9: SSIM(prev, frame[39]) = 0.9953
# Segment 9: SSIM(prev, frame[37]) = 0.9966
# Segment 9: SSIM(prev, frame[39]) = 0.9953
# Segment 9: Picked index 39 as fallback
#
# Segment 10 original indices: [40 41 42 43]
# Segment 10 shuffle 1 indices: [41 40 43 42]
# Segment 10 shuffle 2 indices: [41 41 41 41]
# Segment 10 shuffle 3 indices: [40 43 43 43]
# Segment 10 shuffle 4 indices: [43 40 40 43]
# Segment 10 shuffle 5 indices: [43 41 41 41]
# Segment 10 shuffle 6 indices: [41 43 41 43]
# Segment 10: SSIM(prev, frame[40]) = 0.9977
# Segment 10: SSIM(prev, frame[41]) = 0.9966
# Segment 10: SSIM(prev, frame[43]) = 0.9954
# Segment 10: SSIM(prev, frame[43]) = 0.9954
# Segment 10: SSIM(prev, frame[43]) = 0.9954
# Segment 10: SSIM(prev, frame[40]) = 0.9977
# Segment 10: SSIM(prev, frame[41]) = 0.9966
# Segment 10: SSIM(prev, frame[41]) = 0.9966
# Segment 10: SSIM(prev, frame[40]) = 0.9977
# Segment 10: SSIM(prev, frame[41]) = 0.9966
# Segment 10: SSIM(prev, frame[43]) = 0.9954
# Segment 10: SSIM(prev, frame[41]) = 0.9966
# Segment 10: SSIM(prev, frame[41]) = 0.9966
# Segment 10: SSIM(prev, frame[41]) = 0.9966
# Segment 10: SSIM(prev, frame[40]) = 0.9977
# Segment 10: SSIM(prev, frame[43]) = 0.9954
# Segment 10: SSIM(prev, frame[41]) = 0.9966
# Segment 10: SSIM(prev, frame[43]) = 0.9954
# Segment 10: SSIM(prev, frame[41]) = 0.9966
# Segment 10: SSIM(prev, frame[41]) = 0.9966
# Segment 10: SSIM(prev, frame[43]) = 0.9954
# Segment 10: SSIM(prev, frame[43]) = 0.9954
# Segment 10: SSIM(prev, frame[43]) = 0.9954
# Segment 10: SSIM(prev, frame[42]) = 0.9959
# Segment 10: Picked index 43 as fallback
#
# Segment 11 original indices: [44 45 46 47]
# Segment 11 shuffle 1 indices: [45 45 47 45]
# Segment 11 shuffle 2 indices: [46 47 44 47]
# Segment 11 shuffle 3 indices: [45 44 47 44]
# Segment 11 shuffle 4 indices: [46 46 47 45]
# Segment 11 shuffle 5 indices: [46 47 44 45]
# Segment 11 shuffle 6 indices: [45 46 47 44]
# Segment 11: SSIM(prev, frame[45]) = 0.9967
# Segment 11: SSIM(prev, frame[45]) = 0.9967
# Segment 11: SSIM(prev, frame[45]) = 0.9967
# Segment 11: SSIM(prev, frame[44]) = 0.9977
# Segment 11: SSIM(prev, frame[47]) = 0.9955
# Segment 11: SSIM(prev, frame[44]) = 0.9977
# Segment 11: SSIM(prev, frame[47]) = 0.9955
# Segment 11: SSIM(prev, frame[45]) = 0.9967
# Segment 11: SSIM(prev, frame[44]) = 0.9977
# Segment 11: SSIM(prev, frame[46]) = 0.9959
# Segment 11: SSIM(prev, frame[46]) = 0.9959
# Segment 11: SSIM(prev, frame[44]) = 0.9977
# Segment 11: SSIM(prev, frame[47]) = 0.9955
# Segment 11: SSIM(prev, frame[46]) = 0.9959
# Segment 11: SSIM(prev, frame[47]) = 0.9955
# Segment 11: SSIM(prev, frame[47]) = 0.9955
# Segment 11: SSIM(prev, frame[45]) = 0.9967
# Segment 11: SSIM(prev, frame[45]) = 0.9967
# Segment 11: SSIM(prev, frame[47]) = 0.9955
# Segment 11: SSIM(prev, frame[45]) = 0.9967
# Segment 11: SSIM(prev, frame[44]) = 0.9977
# Segment 11: SSIM(prev, frame[46]) = 0.9959
# Segment 11: SSIM(prev, frame[46]) = 0.9959
# Segment 11: SSIM(prev, frame[47]) = 0.9955
# Segment 11: Picked index 47 as fallback
#
# Segment 12 original indices: [48 49 50 51]
# Segment 12 shuffle 1 indices: [49 49 48 49]
# Segment 12 shuffle 2 indices: [51 50 51 51]
# Segment 12 shuffle 3 indices: [48 48 49 48]
# Segment 12 shuffle 4 indices: [51 50 51 50]
# Segment 12 shuffle 5 indices: [48 51 50 49]
# Segment 12 shuffle 6 indices: [49 51 50 49]
# Segment 12: SSIM(prev, frame[50]) = 0.9959
# Segment 12: SSIM(prev, frame[51]) = 0.9954
# Segment 12: SSIM(prev, frame[51]) = 0.9954
# Segment 12: SSIM(prev, frame[49]) = 0.9966
# Segment 12: SSIM(prev, frame[50]) = 0.9959
# Segment 12: SSIM(prev, frame[48]) = 0.9977
# Segment 12: SSIM(prev, frame[49]) = 0.9966
# Segment 12: SSIM(prev, frame[51]) = 0.9954
# Segment 12: SSIM(prev, frame[48]) = 0.9977
# Segment 12: SSIM(prev, frame[49]) = 0.9966
# Segment 12: SSIM(prev, frame[51]) = 0.9954
# Segment 12: SSIM(prev, frame[49]) = 0.9966
# Segment 12: SSIM(prev, frame[49]) = 0.9966
# Segment 12: SSIM(prev, frame[50]) = 0.9959
# Segment 12: SSIM(prev, frame[48]) = 0.9977
# Segment 12: SSIM(prev, frame[49]) = 0.9966
# Segment 12: SSIM(prev, frame[51]) = 0.9954
# Segment 12: SSIM(prev, frame[50]) = 0.9959
# Segment 12: SSIM(prev, frame[48]) = 0.9977
# Segment 12: SSIM(prev, frame[49]) = 0.9966
# Segment 12: SSIM(prev, frame[51]) = 0.9954
# Segment 12: SSIM(prev, frame[48]) = 0.9977
# Segment 12: SSIM(prev, frame[50]) = 0.9959
# Segment 12: SSIM(prev, frame[51]) = 0.9954
# Segment 12: Picked index 51 as fallback
#
# Segment 13 original indices: [52 53 54 55]
# Segment 13 shuffle 1 indices: [55 54 52 52]
# Segment 13 shuffle 2 indices: [53 55 52 52]
# Segment 13 shuffle 3 indices: [52 55 53 54]
# Segment 13 shuffle 4 indices: [53 52 54 55]
# Segment 13 shuffle 5 indices: [54 55 55 53]
# Segment 13 shuffle 6 indices: [53 54 52 55]
# Segment 13: SSIM(prev, frame[53]) = 0.9966
# Segment 13: SSIM(prev, frame[52]) = 0.9977
# Segment 13: SSIM(prev, frame[52]) = 0.9977
# Segment 13: SSIM(prev, frame[55]) = 0.9955
# Segment 13: SSIM(prev, frame[55]) = 0.9955
# Segment 13: SSIM(prev, frame[55]) = 0.9955
# Segment 13: SSIM(prev, frame[55]) = 0.9955
# Segment 13: SSIM(prev, frame[54]) = 0.9959
# Segment 13: SSIM(prev, frame[54]) = 0.9959
# Segment 13: SSIM(prev, frame[55]) = 0.9955
# Segment 13: SSIM(prev, frame[52]) = 0.9977
# Segment 13: SSIM(prev, frame[52]) = 0.9977
# Segment 13: SSIM(prev, frame[52]) = 0.9977
# Segment 13: SSIM(prev, frame[53]) = 0.9966
# Segment 13: SSIM(prev, frame[55]) = 0.9955
# Segment 13: SSIM(prev, frame[52]) = 0.9977
# Segment 13: SSIM(prev, frame[52]) = 0.9977
# Segment 13: SSIM(prev, frame[53]) = 0.9966
# Segment 13: SSIM(prev, frame[54]) = 0.9959
# Segment 13: SSIM(prev, frame[53]) = 0.9966
# Segment 13: SSIM(prev, frame[53]) = 0.9966
# Segment 13: SSIM(prev, frame[54]) = 0.9959
# Segment 13: SSIM(prev, frame[54]) = 0.9959
# Segment 13: SSIM(prev, frame[55]) = 0.9955
# Segment 13: Picked index 55 as fallback
#
# Segment 14 original indices: [56 57 58 59]
# Segment 14 shuffle 1 indices: [56 59 59 56]
# Segment 14 shuffle 2 indices: [58 58 56 56]
# Segment 14 shuffle 3 indices: [56 58 59 57]
# Segment 14 shuffle 4 indices: [57 57 59 57]
# Segment 14 shuffle 5 indices: [56 59 59 59]
# Segment 14 shuffle 6 indices: [59 58 57 58]
# Segment 14: SSIM(prev, frame[59]) = 0.9954
# Segment 14: SSIM(prev, frame[59]) = 0.9954
# Segment 14: SSIM(prev, frame[57]) = 0.9966
# Segment 14: SSIM(prev, frame[58]) = 0.9959
# Segment 14: SSIM(prev, frame[56]) = 0.9977
# Segment 14: SSIM(prev, frame[56]) = 0.9977
# Segment 14: SSIM(prev, frame[57]) = 0.9966
# Segment 14: SSIM(prev, frame[57]) = 0.9966
# Segment 14: SSIM(prev, frame[57]) = 0.9966
# Segment 14: SSIM(prev, frame[58]) = 0.9959
# Segment 14: SSIM(prev, frame[56]) = 0.9977
# Segment 14: SSIM(prev, frame[57]) = 0.9966
# Segment 14: SSIM(prev, frame[59]) = 0.9954
# Segment 14: SSIM(prev, frame[56]) = 0.9977
# Segment 14: SSIM(prev, frame[59]) = 0.9954
# Segment 14: SSIM(prev, frame[59]) = 0.9954
# Segment 14: SSIM(prev, frame[58]) = 0.9959
# Segment 14: SSIM(prev, frame[59]) = 0.9954
# Segment 14: SSIM(prev, frame[56]) = 0.9977
# Segment 14: SSIM(prev, frame[58]) = 0.9959
# Segment 14: SSIM(prev, frame[56]) = 0.9977
# Segment 14: SSIM(prev, frame[59]) = 0.9954
# Segment 14: SSIM(prev, frame[59]) = 0.9954
# Segment 14: SSIM(prev, frame[58]) = 0.9959
# Segment 14: Picked index 59 as fallback
#
# Segment 15 original indices: [60 61 62 63]
# Segment 15 shuffle 1 indices: [62 60 63 61]
# Segment 15 shuffle 2 indices: [63 62 61 60]
# Segment 15 shuffle 3 indices: [63 62 60 60]
# Segment 15 shuffle 4 indices: [60 63 63 63]
# Segment 15 shuffle 5 indices: [62 63 63 60]
# Segment 15 shuffle 6 indices: [63 63 60 60]
# Segment 15: SSIM(prev, frame[60]) = 0.9937
# Segment 15: SSIM(prev, frame[60]) = 0.9937
# Segment 15: SSIM(prev, frame[60]) = 0.9937
# Segment 15: SSIM(prev, frame[60]) = 0.9937
# Segment 15: SSIM(prev, frame[61]) = 0.9936
# Segment 15: SSIM(prev, frame[63]) = 0.9934
# Segment 15: SSIM(prev, frame[63]) = 0.9934
# Segment 15: SSIM(prev, frame[63]) = 0.9934
# Segment 15: SSIM(prev, frame[63]) = 0.9934
# Segment 15: SSIM(prev, frame[63]) = 0.9934
# Segment 15: SSIM(prev, frame[63]) = 0.9934
# Segment 15: SSIM(prev, frame[61]) = 0.9936
# Segment 15: SSIM(prev, frame[62]) = 0.9935
# Segment 15: SSIM(prev, frame[62]) = 0.9935
# Segment 15: SSIM(prev, frame[62]) = 0.9935
# Segment 15: SSIM(prev, frame[62]) = 0.9935
# Segment 15: SSIM(prev, frame[63]) = 0.9934
# Segment 15: SSIM(prev, frame[60]) = 0.9937
# Segment 15: SSIM(prev, frame[63]) = 0.9934
# Segment 15: SSIM(prev, frame[60]) = 0.9937
# Segment 15: SSIM(prev, frame[60]) = 0.9937
# Segment 15: SSIM(prev, frame[60]) = 0.9937
# Segment 15: SSIM(prev, frame[63]) = 0.9934
# Segment 15: SSIM(prev, frame[63]) = 0.9934
# Segment 15: Picked index 63 as fallback
#
# Segment 16 original indices: [64 65 66 67]
# Segment 16 shuffle 1 indices: [65 67 64 66]
# Segment 16 shuffle 2 indices: [64 67 67 64]
# Segment 16 shuffle 3 indices: [67 65 66 66]
# Segment 16 shuffle 4 indices: [65 65 65 64]
# Segment 16 shuffle 5 indices: [65 67 64 64]
# Segment 16 shuffle 6 indices: [66 67 65 65]
# Segment 16: SSIM(prev, frame[64]) = 0.9976
# Segment 16: SSIM(prev, frame[67]) = 0.9952
# Segment 16: SSIM(prev, frame[64]) = 0.9976
# Segment 16: SSIM(prev, frame[65]) = 0.9965
# Segment 16: SSIM(prev, frame[67]) = 0.9952
# Segment 16: SSIM(prev, frame[66]) = 0.9958
# Segment 16: SSIM(prev, frame[64]) = 0.9976
# Segment 16: SSIM(prev, frame[65]) = 0.9965
# Segment 16: SSIM(prev, frame[65]) = 0.9965
# Segment 16: SSIM(prev, frame[67]) = 0.9952
# Segment 16: SSIM(prev, frame[67]) = 0.9952
# Segment 16: SSIM(prev, frame[66]) = 0.9958
# Segment 16: SSIM(prev, frame[64]) = 0.9976
# Segment 16: SSIM(prev, frame[66]) = 0.9958
# Segment 16: SSIM(prev, frame[65]) = 0.9965
# Segment 16: SSIM(prev, frame[65]) = 0.9965
# Segment 16: SSIM(prev, frame[67]) = 0.9952
# Segment 16: SSIM(prev, frame[65]) = 0.9965
# Segment 16: SSIM(prev, frame[66]) = 0.9958
# Segment 16: SSIM(prev, frame[65]) = 0.9965
# Segment 16: SSIM(prev, frame[64]) = 0.9976
# Segment 16: SSIM(prev, frame[64]) = 0.9976
# Segment 16: SSIM(prev, frame[67]) = 0.9952
# Segment 16: SSIM(prev, frame[65]) = 0.9965
# Segment 16: Picked index 67 as fallback
#
# Segment 17 original indices: [68 69 70 71]
# Segment 17 shuffle 1 indices: [68 69 68 71]
# Segment 17 shuffle 2 indices: [71 71 71 70]
# Segment 17 shuffle 3 indices: [69 70 68 71]
# Segment 17 shuffle 4 indices: [69 68 68 71]
# Segment 17 shuffle 5 indices: [71 71 71 70]
# Segment 17 shuffle 6 indices: [70 70 71 70]
# Segment 17: SSIM(prev, frame[69]) = 0.9965
# Segment 17: SSIM(prev, frame[70]) = 0.9958
# Segment 17: SSIM(prev, frame[70]) = 0.9958
# Segment 17: SSIM(prev, frame[70]) = 0.9958
# Segment 17: SSIM(prev, frame[71]) = 0.9953
# Segment 17: SSIM(prev, frame[71]) = 0.9953
# Segment 17: SSIM(prev, frame[71]) = 0.9953
# Segment 17: SSIM(prev, frame[70]) = 0.9958
# Segment 17: SSIM(prev, frame[68]) = 0.9976
# Segment 17: SSIM(prev, frame[68]) = 0.9976
# Segment 17: SSIM(prev, frame[69]) = 0.9965
# Segment 17: SSIM(prev, frame[71]) = 0.9953
# Segment 17: SSIM(prev, frame[68]) = 0.9976
# Segment 17: SSIM(prev, frame[71]) = 0.9953
# Segment 17: SSIM(prev, frame[68]) = 0.9976
# Segment 17: SSIM(prev, frame[71]) = 0.9953
# Segment 17: SSIM(prev, frame[70]) = 0.9958
# Segment 17: SSIM(prev, frame[71]) = 0.9953
# Segment 17: SSIM(prev, frame[71]) = 0.9953
# Segment 17: SSIM(prev, frame[68]) = 0.9976
# Segment 17: SSIM(prev, frame[71]) = 0.9953
# Segment 17: SSIM(prev, frame[70]) = 0.9958
# Segment 17: SSIM(prev, frame[69]) = 0.9965
# Segment 17: SSIM(prev, frame[71]) = 0.9953
# Segment 17: Picked index 71 as fallback
#
# Segment 18 original indices: [72 73 74 75]
# Segment 18 shuffle 1 indices: [75 72 75 72]
# Segment 18 shuffle 2 indices: [74 73 73 73]
# Segment 18 shuffle 3 indices: [72 72 72 72]
# Segment 18 shuffle 4 indices: [73 73 75 74]
# Segment 18 shuffle 5 indices: [73 74 73 75]
# Segment 18 shuffle 6 indices: [75 74 74 75]
# Segment 18: SSIM(prev, frame[72]) = 0.9977
# Segment 18: SSIM(prev, frame[75]) = 0.9954
# Segment 18: SSIM(prev, frame[75]) = 0.9954
# Segment 18: SSIM(prev, frame[72]) = 0.9977
# Segment 18: SSIM(prev, frame[75]) = 0.9954
# Segment 18: SSIM(prev, frame[74]) = 0.9957
# Segment 18: SSIM(prev, frame[73]) = 0.9965
# Segment 18: SSIM(prev, frame[75]) = 0.9954
# Segment 18: SSIM(prev, frame[72]) = 0.9977
# Segment 18: SSIM(prev, frame[73]) = 0.9965
# Segment 18: SSIM(prev, frame[75]) = 0.9954
# Segment 18: SSIM(prev, frame[72]) = 0.9977
# Segment 18: SSIM(prev, frame[72]) = 0.9977
# Segment 18: SSIM(prev, frame[74]) = 0.9957
# Segment 18: SSIM(prev, frame[73]) = 0.9965
# Segment 18: SSIM(prev, frame[74]) = 0.9957
# Segment 18: SSIM(prev, frame[73]) = 0.9965
# Segment 18: SSIM(prev, frame[73]) = 0.9965
# Segment 18: SSIM(prev, frame[74]) = 0.9957
# Segment 18: SSIM(prev, frame[72]) = 0.9977
# Segment 18: SSIM(prev, frame[74]) = 0.9957
# Segment 18: SSIM(prev, frame[73]) = 0.9965
# Segment 18: SSIM(prev, frame[73]) = 0.9965
# Segment 18: SSIM(prev, frame[75]) = 0.9954
# Segment 18: Picked index 75 as fallback
#
# Segment 19 original indices: [76 77 78 79]
# Segment 19 shuffle 1 indices: [78 78 78 77]
# Segment 19 shuffle 2 indices: [78 76 78 79]
# Segment 19 shuffle 3 indices: [76 79 79 76]
# Segment 19 shuffle 4 indices: [76 77 77 76]
# Segment 19 shuffle 5 indices: [78 77 79 78]
# Segment 19 shuffle 6 indices: [78 78 76 78]
# Segment 19: SSIM(prev, frame[77]) = 0.9966
# Segment 19: SSIM(prev, frame[76]) = 0.9977
# Segment 19: SSIM(prev, frame[76]) = 0.9977
# Segment 19: SSIM(prev, frame[76]) = 0.9977
# Segment 19: SSIM(prev, frame[79]) = 0.9955
# Segment 19: SSIM(prev, frame[78]) = 0.9960
# Segment 19: SSIM(prev, frame[78]) = 0.9960
# Segment 19: SSIM(prev, frame[78]) = 0.9960
# Segment 19: SSIM(prev, frame[77]) = 0.9966
# Segment 19: SSIM(prev, frame[78]) = 0.9960
# Segment 19: SSIM(prev, frame[79]) = 0.9955
# Segment 19: SSIM(prev, frame[77]) = 0.9966
# Segment 19: SSIM(prev, frame[79]) = 0.9955
# Segment 19: SSIM(prev, frame[76]) = 0.9977
# Segment 19: SSIM(prev, frame[78]) = 0.9960
# Segment 19: SSIM(prev, frame[78]) = 0.9960
# Segment 19: SSIM(prev, frame[78]) = 0.9960
# Segment 19: SSIM(prev, frame[77]) = 0.9966
# Segment 19: SSIM(prev, frame[78]) = 0.9960
# Segment 19: SSIM(prev, frame[78]) = 0.9960
# Segment 19: SSIM(prev, frame[76]) = 0.9977
# Segment 19: SSIM(prev, frame[79]) = 0.9955
# Segment 19: SSIM(prev, frame[76]) = 0.9977
# Segment 19: SSIM(prev, frame[78]) = 0.9960
# Segment 19: Picked index 79 as fallback
#
# Segment 20 original indices: [80 81 82 83]
# Segment 20 shuffle 1 indices: [81 83 80 81]
# Segment 20 shuffle 2 indices: [82 80 81 81]
# Segment 20 shuffle 3 indices: [82 81 81 82]
# Segment 20 shuffle 4 indices: [83 80 83 80]
# Segment 20 shuffle 5 indices: [80 82 80 80]
# Segment 20 shuffle 6 indices: [82 80 82 83]
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: SSIM(prev, frame[81]) = 0.9966
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: SSIM(prev, frame[81]) = 0.9966
# Segment 20: SSIM(prev, frame[81]) = 0.9966
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: SSIM(prev, frame[81]) = 0.9966
# Segment 20: SSIM(prev, frame[81]) = 0.9966
# Segment 20: SSIM(prev, frame[82]) = 0.9959
# Segment 20: SSIM(prev, frame[83]) = 0.9955
# Segment 20: SSIM(prev, frame[82]) = 0.9959
# Segment 20: SSIM(prev, frame[83]) = 0.9955
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: SSIM(prev, frame[82]) = 0.9959
# Segment 20: SSIM(prev, frame[82]) = 0.9959
# Segment 20: SSIM(prev, frame[83]) = 0.9955
# Segment 20: SSIM(prev, frame[83]) = 0.9955
# Segment 20: SSIM(prev, frame[82]) = 0.9959
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: SSIM(prev, frame[82]) = 0.9959
# Segment 20: SSIM(prev, frame[81]) = 0.9966
# Segment 20: Picked index 83 as fallback
#
# Segment 21 original indices: [84 85 86 87]
# Segment 21 shuffle 1 indices: [87 84 84 84]
# Segment 21 shuffle 2 indices: [87 86 87 86]
# Segment 21 shuffle 3 indices: [85 85 86 87]
# Segment 21 shuffle 4 indices: [87 87 87 86]
# Segment 21 shuffle 5 indices: [86 85 85 87]
# Segment 21 shuffle 6 indices: [85 86 86 85]
# Segment 21: SSIM(prev, frame[87]) = 0.9954
# Segment 21: SSIM(prev, frame[86]) = 0.9960
# Segment 21: SSIM(prev, frame[86]) = 0.9960
# Segment 21: SSIM(prev, frame[87]) = 0.9954
# Segment 21: SSIM(prev, frame[85]) = 0.9966
# Segment 21: SSIM(prev, frame[84]) = 0.9977
# Segment 21: SSIM(prev, frame[87]) = 0.9954
# Segment 21: SSIM(prev, frame[84]) = 0.9977
# Segment 21: SSIM(prev, frame[87]) = 0.9954
# Segment 21: SSIM(prev, frame[87]) = 0.9954
# Segment 21: SSIM(prev, frame[86]) = 0.9960
# Segment 21: SSIM(prev, frame[86]) = 0.9960
# Segment 21: SSIM(prev, frame[86]) = 0.9960
# Segment 21: SSIM(prev, frame[87]) = 0.9954
# Segment 21: SSIM(prev, frame[87]) = 0.9954
# Segment 21: SSIM(prev, frame[85]) = 0.9966
# Segment 21: SSIM(prev, frame[86]) = 0.9960
# Segment 21: SSIM(prev, frame[85]) = 0.9966
# Segment 21: SSIM(prev, frame[84]) = 0.9977
# Segment 21: SSIM(prev, frame[87]) = 0.9954
# Segment 21: SSIM(prev, frame[85]) = 0.9966
# Segment 21: SSIM(prev, frame[86]) = 0.9960
# Segment 21: SSIM(prev, frame[85]) = 0.9966
# Segment 21: SSIM(prev, frame[85]) = 0.9966
# Segment 21: Picked index 87 as fallback
#
# Segment 22 original indices: [88 89 90 91]
# Segment 22 shuffle 1 indices: [90 89 88 90]
# Segment 22 shuffle 2 indices: [88 90 90 91]
# Segment 22 shuffle 3 indices: [89 88 89 89]
# Segment 22 shuffle 4 indices: [91 88 90 90]
# Segment 22 shuffle 5 indices: [88 89 89 88]
# Segment 22 shuffle 6 indices: [88 90 91 89]
# Segment 22: SSIM(prev, frame[89]) = 0.9967
# Segment 22: SSIM(prev, frame[89]) = 0.9967
# Segment 22: SSIM(prev, frame[90]) = 0.9933
# Segment 22: SSIM(prev, frame[88]) = 0.9978
# Segment 22: SSIM(prev, frame[91]) = 0.9933
# Segment 22: SSIM(prev, frame[88]) = 0.9978
# Segment 22: SSIM(prev, frame[90]) = 0.9933
# Segment 22: SSIM(prev, frame[88]) = 0.9978
# Segment 22: SSIM(prev, frame[89]) = 0.9967
# Segment 22: SSIM(prev, frame[91]) = 0.9933
# Segment 22: SSIM(prev, frame[89]) = 0.9967
# Segment 22: SSIM(prev, frame[88]) = 0.9978
# Segment 22: SSIM(prev, frame[89]) = 0.9967
# Segment 22: SSIM(prev, frame[91]) = 0.9933
# Segment 22: SSIM(prev, frame[89]) = 0.9967
# Segment 22: SSIM(prev, frame[90]) = 0.9933
# Segment 22: SSIM(prev, frame[88]) = 0.9978
# Segment 22: SSIM(prev, frame[90]) = 0.9933
# Segment 22: SSIM(prev, frame[90]) = 0.9933
# Segment 22: SSIM(prev, frame[88]) = 0.9978
# Segment 22: SSIM(prev, frame[90]) = 0.9933
# Segment 22: SSIM(prev, frame[90]) = 0.9933
# Segment 22: SSIM(prev, frame[89]) = 0.9967
# Segment 22: SSIM(prev, frame[88]) = 0.9978
# Segment 22: Picked index 91 as fallback
#
# Segment 23 original indices: [92 93 94 95]
# Segment 23 shuffle 1 indices: [93 94 95 93]
# Segment 23 shuffle 2 indices: [95 95 92 95]
# Segment 23 shuffle 3 indices: [92 95 93 93]
# Segment 23 shuffle 4 indices: [94 95 93 94]
# Segment 23 shuffle 5 indices: [93 93 95 93]
# Segment 23 shuffle 6 indices: [95 92 94 92]
# Segment 23: SSIM(prev, frame[95]) = 0.9955
# Segment 23: SSIM(prev, frame[95]) = 0.9955
# Segment 23: SSIM(prev, frame[93]) = 0.9969
# Segment 23: SSIM(prev, frame[95]) = 0.9955
# Segment 23: SSIM(prev, frame[92]) = 0.9984
# Segment 23: SSIM(prev, frame[95]) = 0.9955
# Segment 23: SSIM(prev, frame[93]) = 0.9969
# Segment 23: SSIM(prev, frame[95]) = 0.9955
# Segment 23: SSIM(prev, frame[92]) = 0.9984
# Segment 23: SSIM(prev, frame[94]) = 0.9961
# Segment 23: SSIM(prev, frame[95]) = 0.9955
# Segment 23: SSIM(prev, frame[93]) = 0.9969
# Segment 23: SSIM(prev, frame[93]) = 0.9969
# Segment 23: SSIM(prev, frame[94]) = 0.9961
# Segment 23: SSIM(prev, frame[93]) = 0.9969
# Segment 23: SSIM(prev, frame[95]) = 0.9955
# Segment 23: SSIM(prev, frame[93]) = 0.9969
# Segment 23: SSIM(prev, frame[93]) = 0.9969
# Segment 23: SSIM(prev, frame[95]) = 0.9955
# Segment 23: SSIM(prev, frame[94]) = 0.9961
# Segment 23: SSIM(prev, frame[93]) = 0.9969
# Segment 23: SSIM(prev, frame[92]) = 0.9984
# Segment 23: SSIM(prev, frame[94]) = 0.9961
# Segment 23: SSIM(prev, frame[92]) = 0.9984
# Segment 23: Picked index 95 as fallback
#
# Segment 24 original indices: [96 97 98 99]
# Segment 24 shuffle 1 indices: [99 97 96 98]
# Segment 24 shuffle 2 indices: [98 97 99 98]
# Segment 24 shuffle 3 indices: [98 98 96 99]
# Segment 24 shuffle 4 indices: [99 96 96 99]
# Segment 24 shuffle 5 indices: [96 97 97 99]
# Segment 24 shuffle 6 indices: [97 99 96 99]
# Segment 24: SSIM(prev, frame[98]) = 0.9958
# Segment 24: SSIM(prev, frame[96]) = 0.9975
# Segment 24: SSIM(prev, frame[99]) = 0.9953
# Segment 24: SSIM(prev, frame[98]) = 0.9958
# Segment 24: SSIM(prev, frame[99]) = 0.9953
# Segment 24: SSIM(prev, frame[98]) = 0.9958
# Segment 24: SSIM(prev, frame[96]) = 0.9975
# Segment 24: SSIM(prev, frame[97]) = 0.9964
# Segment 24: SSIM(prev, frame[96]) = 0.9975
# Segment 24: SSIM(prev, frame[97]) = 0.9964
# Segment 24: SSIM(prev, frame[98]) = 0.9958
# Segment 24: SSIM(prev, frame[97]) = 0.9964
# Segment 24: SSIM(prev, frame[99]) = 0.9953
# Segment 24: SSIM(prev, frame[99]) = 0.9953
# Segment 24: SSIM(prev, frame[99]) = 0.9953
# Segment 24: SSIM(prev, frame[99]) = 0.9953
# Segment 24: SSIM(prev, frame[97]) = 0.9964
# Segment 24: SSIM(prev, frame[96]) = 0.9975
# Segment 24: SSIM(prev, frame[99]) = 0.9953
# Segment 24: SSIM(prev, frame[98]) = 0.9958
# Segment 24: SSIM(prev, frame[96]) = 0.9975
# Segment 24: SSIM(prev, frame[99]) = 0.9953
# Segment 24: SSIM(prev, frame[96]) = 0.9975
# Segment 24: SSIM(prev, frame[97]) = 0.9964
# Segment 24: Picked index 99 as fallback
#
# Segment 25 original indices: [100 101 102 103]
# Segment 25 shuffle 1 indices: [101 103 102 100]
# Segment 25 shuffle 2 indices: [101 102 101 100]
# Segment 25 shuffle 3 indices: [101 102 103 103]
# Segment 25 shuffle 4 indices: [101 103 102 103]
# Segment 25 shuffle 5 indices: [100 100 101 103]
# Segment 25 shuffle 6 indices: [101 100 102 103]
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: SSIM(prev, frame[102]) = 0.9960
# Segment 25: SSIM(prev, frame[102]) = 0.9960
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: SSIM(prev, frame[100]) = 0.9977
# Segment 25: SSIM(prev, frame[100]) = 0.9977
# Segment 25: SSIM(prev, frame[101]) = 0.9966
# Segment 25: SSIM(prev, frame[102]) = 0.9960
# Segment 25: SSIM(prev, frame[100]) = 0.9977
# Segment 25: SSIM(prev, frame[101]) = 0.9966
# Segment 25: SSIM(prev, frame[101]) = 0.9966
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: SSIM(prev, frame[102]) = 0.9960
# Segment 25: SSIM(prev, frame[101]) = 0.9966
# Segment 25: SSIM(prev, frame[101]) = 0.9966
# Segment 25: SSIM(prev, frame[100]) = 0.9977
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: SSIM(prev, frame[100]) = 0.9977
# Segment 25: SSIM(prev, frame[101]) = 0.9966
# Segment 25: SSIM(prev, frame[102]) = 0.9960
# Segment 25: SSIM(prev, frame[101]) = 0.9966
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: Picked index 103 as fallback
#
# Segment 26 original indices: [104 105 106 107]
# Segment 26 shuffle 1 indices: [104 104 106 107]
# Segment 26 shuffle 2 indices: [107 106 107 107]
# Segment 26 shuffle 3 indices: [106 105 104 104]
# Segment 26 shuffle 4 indices: [104 106 105 106]
# Segment 26 shuffle 5 indices: [106 107 107 106]
# Segment 26 shuffle 6 indices: [105 107 106 106]
# Segment 26: SSIM(prev, frame[105]) = 0.9966
# Segment 26: SSIM(prev, frame[107]) = 0.9955
# Segment 26: SSIM(prev, frame[104]) = 0.9977
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[107]) = 0.9955
# Segment 26: SSIM(prev, frame[107]) = 0.9955
# Segment 26: SSIM(prev, frame[107]) = 0.9955
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[105]) = 0.9966
# Segment 26: SSIM(prev, frame[107]) = 0.9955
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[104]) = 0.9977
# Segment 26: SSIM(prev, frame[107]) = 0.9955
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[107]) = 0.9955
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[105]) = 0.9966
# Segment 26: SSIM(prev, frame[104]) = 0.9977
# Segment 26: SSIM(prev, frame[104]) = 0.9977
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[104]) = 0.9977
# Segment 26: Picked index 107 as fallback
#
# Segment 27 original indices: [108 109 110 111]
# Segment 27 shuffle 1 indices: [109 109 110 111]
# Segment 27 shuffle 2 indices: [109 110 111 108]
# Segment 27 shuffle 3 indices: [109 108 109 110]
# Segment 27 shuffle 4 indices: [110 111 110 110]
# Segment 27 shuffle 5 indices: [110 111 109 109]
# Segment 27 shuffle 6 indices: [108 111 110 109]
# Segment 27: SSIM(prev, frame[109]) = 0.9966
# Segment 27: SSIM(prev, frame[110]) = 0.9960
# Segment 27: SSIM(prev, frame[108]) = 0.9978
# Segment 27: SSIM(prev, frame[111]) = 0.9955
# Segment 27: SSIM(prev, frame[110]) = 0.9960
# Segment 27: SSIM(prev, frame[110]) = 0.9960
# Segment 27: SSIM(prev, frame[109]) = 0.9966
# Segment 27: SSIM(prev, frame[110]) = 0.9960
# Segment 27: SSIM(prev, frame[111]) = 0.9955
# Segment 27: SSIM(prev, frame[109]) = 0.9966
# Segment 27: SSIM(prev, frame[111]) = 0.9955
# Segment 27: SSIM(prev, frame[108]) = 0.9978
# Segment 27: SSIM(prev, frame[110]) = 0.9960
# Segment 27: SSIM(prev, frame[109]) = 0.9966
# Segment 27: SSIM(prev, frame[109]) = 0.9966
# Segment 27: SSIM(prev, frame[111]) = 0.9955
# Segment 27: SSIM(prev, frame[108]) = 0.9978
# Segment 27: SSIM(prev, frame[111]) = 0.9955
# Segment 27: SSIM(prev, frame[109]) = 0.9966
# Segment 27: SSIM(prev, frame[110]) = 0.9960
# Segment 27: SSIM(prev, frame[109]) = 0.9966
# Segment 27: SSIM(prev, frame[110]) = 0.9960
# Segment 27: SSIM(prev, frame[109]) = 0.9966
# Segment 27: SSIM(prev, frame[110]) = 0.9960
# Segment 27: Picked index 111 as fallback
#
# Segment 28 original indices: [112 113 114 115]
# Segment 28 shuffle 1 indices: [114 114 113 112]
# Segment 28 shuffle 2 indices: [114 115 112 113]
# Segment 28 shuffle 3 indices: [114 115 112 112]
# Segment 28 shuffle 4 indices: [114 113 112 112]
# Segment 28 shuffle 5 indices: [112 113 113 114]
# Segment 28 shuffle 6 indices: [113 115 113 113]
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[115]) = 0.9954
# Segment 28: SSIM(prev, frame[114]) = 0.9959
# Segment 28: SSIM(prev, frame[113]) = 0.9965
# Segment 28: SSIM(prev, frame[113]) = 0.9965
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[113]) = 0.9965
# Segment 28: SSIM(prev, frame[113]) = 0.9965
# Segment 28: SSIM(prev, frame[114]) = 0.9959
# Segment 28: SSIM(prev, frame[113]) = 0.9965
# Segment 28: SSIM(prev, frame[114]) = 0.9959
# Segment 28: SSIM(prev, frame[115]) = 0.9954
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[115]) = 0.9954
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[114]) = 0.9959
# Segment 28: SSIM(prev, frame[114]) = 0.9959
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[113]) = 0.9965
# Segment 28: SSIM(prev, frame[114]) = 0.9959
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[113]) = 0.9965
# Segment 28: SSIM(prev, frame[113]) = 0.9965
# Segment 28: Picked index 115 as fallback
#
# Segment 29 original indices: [116 117 118 119]
# Segment 29 shuffle 1 indices: [117 116 119 117]
# Segment 29 shuffle 2 indices: [117 116 118 116]
# Segment 29 shuffle 3 indices: [118 119 117 119]
# Segment 29 shuffle 4 indices: [117 116 119 118]
# Segment 29 shuffle 5 indices: [119 119 119 119]
# Segment 29 shuffle 6 indices: [118 118 117 119]
# Segment 29: SSIM(prev, frame[118]) = 0.9960
# Segment 29: SSIM(prev, frame[116]) = 0.9977
# Segment 29: SSIM(prev, frame[116]) = 0.9977
# Segment 29: SSIM(prev, frame[118]) = 0.9960
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: SSIM(prev, frame[117]) = 0.9966
# Segment 29: SSIM(prev, frame[117]) = 0.9966
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: SSIM(prev, frame[118]) = 0.9960
# Segment 29: SSIM(prev, frame[116]) = 0.9977
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: SSIM(prev, frame[117]) = 0.9966
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: SSIM(prev, frame[117]) = 0.9966
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: SSIM(prev, frame[118]) = 0.9960
# Segment 29: SSIM(prev, frame[117]) = 0.9966
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: SSIM(prev, frame[117]) = 0.9966
# Segment 29: SSIM(prev, frame[118]) = 0.9960
# Segment 29: SSIM(prev, frame[116]) = 0.9977
# Segment 29: Picked index 119 as fallback
# Extracted 120 frames from all_phs1_phs6lv1_lv38_vids/larvae_temp,26_9°C,03-07-2025,02-47-54PM.mp4. Target: 120
# Segments (frame index ranges):
#  Segment 0: [0 1 2 3]
#  Segment 1: [4 5 6 7]
#  Segment 2: [ 8  9 10 11]
#  Segment 3: [12 13 14 15]
#  Segment 4: [16 17 18 19]
#  Segment 5: [20 21 22 23]
#  Segment 6: [24 25 26 27]
#  Segment 7: [28 29 30 31]
#  Segment 8: [32 33 34 35]
#  Segment 9: [36 37 38 39]
#  Segment 10: [40 41 42 43]
#  Segment 11: [44 45 46 47]
#  Segment 12: [48 49 50 51]
#  Segment 13: [52 53 54 55]
#  Segment 14: [56 57 58 59]
#  Segment 15: [60 61 62 63]
#  Segment 16: [64 65 66 67]
#  Segment 17: [68 69 70 71]
#  Segment 18: [72 73 74 75]
#  Segment 19: [76 77 78 79]
#  Segment 20: [80 81 82 83]
#  Segment 21: [84 85 86 87]
#  Segment 22: [88 89 90 91]
#  Segment 23: [92 93 94 95]
#  Segment 24: [96 97 98 99]
#  Segment 25: [100 101 102 103]
#  Segment 26: [104 105 106 107]
#  Segment 27: [108 109 110 111]
#  Segment 28: [112 113 114 115]
#  Segment 29: [116 117 118 119]
#
# Segment 0 original indices: [0 1 2 3]
# Segment 0 shuffle 1 indices: [3 1 1 2]
# Segment 0 shuffle 2 indices: [2 3 3 3]
# Segment 0 shuffle 3 indices: [1 1 3 0]
# Segment 0 shuffle 4 indices: [2 1 1 3]
# Segment 0 shuffle 5 indices: [3 2 1 1]
# Segment 0 shuffle 6 indices: [0 0 2 2]
# Segment 0: Picked index 3 (SSIM=N/A, first frame)
#
# Segment 1 original indices: [4 5 6 7]
# Segment 1 shuffle 1 indices: [6 5 7 4]
# Segment 1 shuffle 2 indices: [6 4 6 4]
# Segment 1 shuffle 3 indices: [4 7 6 6]
# Segment 1 shuffle 4 indices: [4 5 5 5]
# Segment 1 shuffle 5 indices: [4 7 5 5]
# Segment 1 shuffle 6 indices: [5 4 4 4]
# Segment 1: SSIM(prev, frame[6]) = 0.9966
# Segment 1: SSIM(prev, frame[6]) = 0.9966
# Segment 1: SSIM(prev, frame[4]) = 0.9994
# Segment 1: SSIM(prev, frame[5]) = 0.9988
# Segment 1: SSIM(prev, frame[6]) = 0.9966
# Segment 1: SSIM(prev, frame[5]) = 0.9988
# Segment 1: SSIM(prev, frame[4]) = 0.9994
# Segment 1: SSIM(prev, frame[4]) = 0.9994
# Segment 1: SSIM(prev, frame[4]) = 0.9994
# Segment 1: SSIM(prev, frame[7]) = 0.9957
# Segment 1: SSIM(prev, frame[5]) = 0.9988
# Segment 1: SSIM(prev, frame[4]) = 0.9994
# Segment 1: SSIM(prev, frame[4]) = 0.9994
# Segment 1: SSIM(prev, frame[7]) = 0.9957
# Segment 1: SSIM(prev, frame[4]) = 0.9994
# Segment 1: SSIM(prev, frame[5]) = 0.9988
# Segment 1: SSIM(prev, frame[6]) = 0.9966
# Segment 1: SSIM(prev, frame[5]) = 0.9988
# Segment 1: SSIM(prev, frame[4]) = 0.9994
# Segment 1: SSIM(prev, frame[5]) = 0.9988
# Segment 1: SSIM(prev, frame[4]) = 0.9994
# Segment 1: SSIM(prev, frame[5]) = 0.9988
# Segment 1: SSIM(prev, frame[7]) = 0.9957
# Segment 1: SSIM(prev, frame[6]) = 0.9966
# Segment 1: Picked index 7 as fallback
#
# Segment 2 original indices: [ 8  9 10 11]
# Segment 2 shuffle 1 indices: [10  9 11 11]
# Segment 2 shuffle 2 indices: [ 8 10 10  9]
# Segment 2 shuffle 3 indices: [ 9  9 10 10]
# Segment 2 shuffle 4 indices: [ 9 11 10 11]
# Segment 2 shuffle 5 indices: [11 11  8 11]
# Segment 2 shuffle 6 indices: [11  9  8 11]
# Segment 2: SSIM(prev, frame[9]) = 0.9962
# Segment 2: SSIM(prev, frame[11]) = 0.9940
# Segment 2: SSIM(prev, frame[9]) = 0.9962
# Segment 2: SSIM(prev, frame[11]) = 0.9940
# Segment 2: SSIM(prev, frame[10]) = 0.9944
# Segment 2: SSIM(prev, frame[10]) = 0.9944
# Segment 2: SSIM(prev, frame[11]) = 0.9940
# Segment 2: SSIM(prev, frame[11]) = 0.9940
# Segment 2: SSIM(prev, frame[10]) = 0.9944
# Segment 2: SSIM(prev, frame[8]) = 0.9985
# Segment 2: SSIM(prev, frame[11]) = 0.9940
# Segment 2: SSIM(prev, frame[8]) = 0.9985
# Segment 2: SSIM(prev, frame[10]) = 0.9944
# Segment 2: SSIM(prev, frame[9]) = 0.9962
# Segment 2: SSIM(prev, frame[9]) = 0.9962
# Segment 2: SSIM(prev, frame[11]) = 0.9940
# Segment 2: SSIM(prev, frame[9]) = 0.9962
# Segment 2: SSIM(prev, frame[9]) = 0.9962
# Segment 2: SSIM(prev, frame[11]) = 0.9940
# Segment 2: SSIM(prev, frame[8]) = 0.9985
# Segment 2: SSIM(prev, frame[11]) = 0.9940
# Segment 2: SSIM(prev, frame[11]) = 0.9940
# Segment 2: SSIM(prev, frame[10]) = 0.9944
# Segment 2: SSIM(prev, frame[10]) = 0.9944
# Segment 2: Picked index 11 as fallback
#
# Segment 3 original indices: [12 13 14 15]
# Segment 3 shuffle 1 indices: [14 15 15 15]
# Segment 3 shuffle 2 indices: [15 14 15 15]
# Segment 3 shuffle 3 indices: [12 12 12 13]
# Segment 3 shuffle 4 indices: [14 12 13 13]
# Segment 3 shuffle 5 indices: [15 15 15 12]
# Segment 3 shuffle 6 indices: [15 12 14 13]
# Segment 3: SSIM(prev, frame[15]) = 0.9949
# Segment 3: SSIM(prev, frame[15]) = 0.9949
# Segment 3: SSIM(prev, frame[15]) = 0.9949
# Segment 3: SSIM(prev, frame[15]) = 0.9949
# Segment 3: SSIM(prev, frame[12]) = 0.9976
# Segment 3: SSIM(prev, frame[14]) = 0.9955
# Segment 3: SSIM(prev, frame[13]) = 0.9963
# Segment 3: SSIM(prev, frame[15]) = 0.9949
# Segment 3: SSIM(prev, frame[13]) = 0.9963
# Segment 3: SSIM(prev, frame[12]) = 0.9976
# Segment 3: SSIM(prev, frame[12]) = 0.9976
# Segment 3: SSIM(prev, frame[14]) = 0.9955
# Segment 3: SSIM(prev, frame[14]) = 0.9955
# Segment 3: SSIM(prev, frame[12]) = 0.9976
# Segment 3: SSIM(prev, frame[13]) = 0.9963
# Segment 3: SSIM(prev, frame[15]) = 0.9949
# Segment 3: SSIM(prev, frame[15]) = 0.9949
# Segment 3: SSIM(prev, frame[14]) = 0.9955
# Segment 3: SSIM(prev, frame[13]) = 0.9963
# Segment 3: SSIM(prev, frame[15]) = 0.9949
# Segment 3: SSIM(prev, frame[15]) = 0.9949
# Segment 3: SSIM(prev, frame[12]) = 0.9976
# Segment 3: SSIM(prev, frame[15]) = 0.9949
# Segment 3: SSIM(prev, frame[12]) = 0.9976
# Segment 3: Picked index 15 as fallback
#
# Segment 4 original indices: [16 17 18 19]
# Segment 4 shuffle 1 indices: [19 17 18 17]
# Segment 4 shuffle 2 indices: [16 17 16 17]
# Segment 4 shuffle 3 indices: [16 19 18 18]
# Segment 4 shuffle 4 indices: [19 16 19 19]
# Segment 4 shuffle 5 indices: [18 18 18 19]
# Segment 4 shuffle 6 indices: [16 17 17 19]
# Segment 4: SSIM(prev, frame[19]) = 0.9952
# Segment 4: SSIM(prev, frame[17]) = 0.9965
# Segment 4: SSIM(prev, frame[19]) = 0.9952
# Segment 4: SSIM(prev, frame[18]) = 0.9953
# Segment 4: SSIM(prev, frame[19]) = 0.9952
# Segment 4: SSIM(prev, frame[16]) = 0.9979
# Segment 4: SSIM(prev, frame[18]) = 0.9953
# Segment 4: SSIM(prev, frame[16]) = 0.9979
# Segment 4: SSIM(prev, frame[19]) = 0.9952
# Segment 4: SSIM(prev, frame[17]) = 0.9965
# Segment 4: SSIM(prev, frame[16]) = 0.9979
# Segment 4: SSIM(prev, frame[18]) = 0.9953
# Segment 4: SSIM(prev, frame[18]) = 0.9953
# Segment 4: SSIM(prev, frame[19]) = 0.9952
# Segment 4: SSIM(prev, frame[19]) = 0.9952
# Segment 4: SSIM(prev, frame[19]) = 0.9952
# Segment 4: SSIM(prev, frame[17]) = 0.9965
# Segment 4: SSIM(prev, frame[16]) = 0.9979
# Segment 4: SSIM(prev, frame[17]) = 0.9965
# Segment 4: SSIM(prev, frame[18]) = 0.9953
# Segment 4: SSIM(prev, frame[16]) = 0.9979
# Segment 4: SSIM(prev, frame[17]) = 0.9965
# Segment 4: SSIM(prev, frame[17]) = 0.9965
# Segment 4: SSIM(prev, frame[18]) = 0.9953
# ...
# Segment 18: SSIM(prev, frame[72]) = 0.9977
# Segment 18: SSIM(prev, frame[72]) = 0.9977
# Segment 18: SSIM(prev, frame[74]) = 0.9958
# Segment 18: SSIM(prev, frame[73]) = 0.9966
# Segment 18: SSIM(prev, frame[72]) = 0.9977
# Segment 18: SSIM(prev, frame[72]) = 0.9977
# Segment 18: Picked index 75 as fallback
#
# Segment 19 original indices: [76 77 78 79]
# Segment 19 shuffle 1 indices: [77 76 76 79]
# Segment 19 shuffle 2 indices: [78 78 76 79]
# Segment 19 shuffle 3 indices: [77 78 78 76]
# Segment 19 shuffle 4 indices: [77 79 77 77]
# Segment 19 shuffle 5 indices: [77 79 77 76]
# Segment 19 shuffle 6 indices: [77 76 77 77]
# Segment 19: SSIM(prev, frame[77]) = 0.9966
# Segment 19: SSIM(prev, frame[79]) = 0.9956
# Segment 19: SSIM(prev, frame[76]) = 0.9977
# Segment 19: SSIM(prev, frame[76]) = 0.9977
# Segment 19: SSIM(prev, frame[76]) = 0.9977
# Segment 19: SSIM(prev, frame[76]) = 0.9977
# Segment 19: SSIM(prev, frame[76]) = 0.9977
# Segment 19: SSIM(prev, frame[77]) = 0.9966
# Segment 19: SSIM(prev, frame[78]) = 0.9960
# Segment 19: SSIM(prev, frame[77]) = 0.9966
# Segment 19: SSIM(prev, frame[78]) = 0.9960
# Segment 19: SSIM(prev, frame[77]) = 0.9966
# Segment 19: SSIM(prev, frame[79]) = 0.9956
# Segment 19: SSIM(prev, frame[77]) = 0.9966
# Segment 19: SSIM(prev, frame[78]) = 0.9960
# Segment 19: SSIM(prev, frame[77]) = 0.9966
# Segment 19: SSIM(prev, frame[76]) = 0.9977
# Segment 19: SSIM(prev, frame[79]) = 0.9956
# Segment 19: SSIM(prev, frame[77]) = 0.9966
# Segment 19: SSIM(prev, frame[78]) = 0.9960
# Segment 19: SSIM(prev, frame[77]) = 0.9966
# Segment 19: SSIM(prev, frame[77]) = 0.9966
# Segment 19: SSIM(prev, frame[77]) = 0.9966
# Segment 19: SSIM(prev, frame[79]) = 0.9956
# Segment 19: Picked index 79 as fallback
#
# Segment 20 original indices: [80 81 82 83]
# Segment 20 shuffle 1 indices: [81 82 83 80]
# Segment 20 shuffle 2 indices: [82 81 83 82]
# Segment 20 shuffle 3 indices: [83 82 81 80]
# Segment 20 shuffle 4 indices: [81 83 80 83]
# Segment 20 shuffle 5 indices: [80 81 81 82]
# Segment 20 shuffle 6 indices: [80 80 82 80]
# Segment 20: SSIM(prev, frame[82]) = 0.9959
# Segment 20: SSIM(prev, frame[83]) = 0.9955
# Segment 20: SSIM(prev, frame[82]) = 0.9959
# Segment 20: SSIM(prev, frame[81]) = 0.9967
# Segment 20: SSIM(prev, frame[81]) = 0.9967
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: SSIM(prev, frame[81]) = 0.9967
# Segment 20: SSIM(prev, frame[82]) = 0.9959
# Segment 20: SSIM(prev, frame[83]) = 0.9955
# Segment 20: SSIM(prev, frame[82]) = 0.9959
# Segment 20: SSIM(prev, frame[83]) = 0.9955
# Segment 20: SSIM(prev, frame[83]) = 0.9955
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: SSIM(prev, frame[82]) = 0.9959
# Segment 20: SSIM(prev, frame[83]) = 0.9955
# Segment 20: SSIM(prev, frame[81]) = 0.9967
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: SSIM(prev, frame[81]) = 0.9967
# Segment 20: SSIM(prev, frame[82]) = 0.9959
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: SSIM(prev, frame[81]) = 0.9967
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: SSIM(prev, frame[80]) = 0.9977
# Segment 20: Picked index 83 as fallback
#
# Segment 21 original indices: [84 85 86 87]
# Segment 21 shuffle 1 indices: [87 87 86 87]
# Segment 21 shuffle 2 indices: [85 84 87 87]
# Segment 21 shuffle 3 indices: [84 84 85 85]
# Segment 21 shuffle 4 indices: [84 86 84 84]
# Segment 21 shuffle 5 indices: [84 84 85 84]
# Segment 21 shuffle 6 indices: [86 85 86 85]
# Segment 21: SSIM(prev, frame[85]) = 0.9965
# Segment 21: SSIM(prev, frame[84]) = 0.9977
# Segment 21: SSIM(prev, frame[87]) = 0.9955
# Segment 21: SSIM(prev, frame[84]) = 0.9977
# Segment 21: SSIM(prev, frame[85]) = 0.9965
# Segment 21: SSIM(prev, frame[86]) = 0.9959
# Segment 21: SSIM(prev, frame[84]) = 0.9977
# Segment 21: SSIM(prev, frame[84]) = 0.9977
# Segment 21: SSIM(prev, frame[84]) = 0.9977
# Segment 21: SSIM(prev, frame[85]) = 0.9965
# Segment 21: SSIM(prev, frame[87]) = 0.9955
# Segment 21: SSIM(prev, frame[84]) = 0.9977
# Segment 21: SSIM(prev, frame[86]) = 0.9959
# Segment 21: SSIM(prev, frame[87]) = 0.9955
# Segment 21: SSIM(prev, frame[85]) = 0.9965
# Segment 21: SSIM(prev, frame[84]) = 0.9977
# Segment 21: SSIM(prev, frame[84]) = 0.9977
# Segment 21: SSIM(prev, frame[87]) = 0.9955
# Segment 21: SSIM(prev, frame[84]) = 0.9977
# Segment 21: SSIM(prev, frame[85]) = 0.9965
# Segment 21: SSIM(prev, frame[87]) = 0.9955
# Segment 21: SSIM(prev, frame[85]) = 0.9965
# Segment 21: SSIM(prev, frame[86]) = 0.9959
# Segment 21: SSIM(prev, frame[86]) = 0.9959
# Segment 21: Picked index 87 as fallback
#
# Segment 22 original indices: [88 89 90 91]
# Segment 22 shuffle 1 indices: [88 88 88 91]
# Segment 22 shuffle 2 indices: [89 89 90 88]
# Segment 22 shuffle 3 indices: [91 88 90 91]
# Segment 22 shuffle 4 indices: [90 90 91 91]
# Segment 22 shuffle 5 indices: [88 90 91 91]
# Segment 22 shuffle 6 indices: [90 88 90 90]
# Segment 22: SSIM(prev, frame[91]) = 0.9933
# Segment 22: SSIM(prev, frame[88]) = 0.9976
# Segment 22: SSIM(prev, frame[91]) = 0.9933
# Segment 22: SSIM(prev, frame[91]) = 0.9933
# Segment 22: SSIM(prev, frame[89]) = 0.9966
# Segment 22: SSIM(prev, frame[88]) = 0.9976
# Segment 22: SSIM(prev, frame[91]) = 0.9933
# Segment 22: SSIM(prev, frame[90]) = 0.9932
# Segment 22: SSIM(prev, frame[90]) = 0.9932
# Segment 22: SSIM(prev, frame[90]) = 0.9932
# Segment 22: SSIM(prev, frame[91]) = 0.9933
# Segment 22: SSIM(prev, frame[90]) = 0.9932
# Segment 22: SSIM(prev, frame[91]) = 0.9933
# Segment 22: SSIM(prev, frame[90]) = 0.9932
# Segment 22: SSIM(prev, frame[90]) = 0.9932
# Segment 22: SSIM(prev, frame[88]) = 0.9976
# Segment 22: SSIM(prev, frame[89]) = 0.9966
# Segment 22: SSIM(prev, frame[90]) = 0.9932
# Segment 22: SSIM(prev, frame[91]) = 0.9933
# Segment 22: SSIM(prev, frame[88]) = 0.9976
# Segment 22: SSIM(prev, frame[88]) = 0.9976
# Segment 22: SSIM(prev, frame[88]) = 0.9976
# Segment 22: SSIM(prev, frame[88]) = 0.9976
# Segment 22: SSIM(prev, frame[90]) = 0.9932
# Segment 22: Picked index 90 as fallback
#
# Segment 23 original indices: [92 93 94 95]
# Segment 23 shuffle 1 indices: [92 95 93 94]
# Segment 23 shuffle 2 indices: [92 92 93 95]
# Segment 23 shuffle 3 indices: [95 95 93 95]
# Segment 23 shuffle 4 indices: [95 93 95 93]
# Segment 23 shuffle 5 indices: [94 94 94 93]
# Segment 23 shuffle 6 indices: [92 95 95 94]
# Segment 23: SSIM(prev, frame[92]) = 0.9978
# Segment 23: SSIM(prev, frame[93]) = 0.9965
# Segment 23: SSIM(prev, frame[94]) = 0.9959
# Segment 23: SSIM(prev, frame[93]) = 0.9965
# Segment 23: SSIM(prev, frame[93]) = 0.9965
# Segment 23: SSIM(prev, frame[95]) = 0.9953
# Segment 23: SSIM(prev, frame[95]) = 0.9953
# Segment 23: SSIM(prev, frame[92]) = 0.9978
# Segment 23: SSIM(prev, frame[93]) = 0.9965
# Segment 23: SSIM(prev, frame[95]) = 0.9953
# Segment 23: SSIM(prev, frame[95]) = 0.9953
# Segment 23: SSIM(prev, frame[93]) = 0.9965
# Segment 23: SSIM(prev, frame[95]) = 0.9953
# Segment 23: SSIM(prev, frame[92]) = 0.9978
# Segment 23: SSIM(prev, frame[94]) = 0.9959
# Segment 23: SSIM(prev, frame[95]) = 0.9953
# Segment 23: SSIM(prev, frame[94]) = 0.9959
# Segment 23: SSIM(prev, frame[95]) = 0.9953
# Segment 23: SSIM(prev, frame[94]) = 0.9959
# Segment 23: SSIM(prev, frame[95]) = 0.9953
# Segment 23: SSIM(prev, frame[93]) = 0.9965
# Segment 23: SSIM(prev, frame[94]) = 0.9959
# Segment 23: SSIM(prev, frame[92]) = 0.9978
# Segment 23: SSIM(prev, frame[95]) = 0.9953
# Segment 23: Picked index 95 as fallback
#
# Segment 24 original indices: [96 97 98 99]
# Segment 24 shuffle 1 indices: [98 96 99 96]
# Segment 24 shuffle 2 indices: [97 99 97 98]
# Segment 24 shuffle 3 indices: [99 98 97 96]
# Segment 24 shuffle 4 indices: [96 96 98 97]
# Segment 24 shuffle 5 indices: [96 99 96 97]
# Segment 24 shuffle 6 indices: [97 96 96 99]
# Segment 24: SSIM(prev, frame[96]) = 0.9977
# Segment 24: SSIM(prev, frame[98]) = 0.9959
# Segment 24: SSIM(prev, frame[96]) = 0.9977
# Segment 24: SSIM(prev, frame[97]) = 0.9966
# Segment 24: SSIM(prev, frame[96]) = 0.9977
# Segment 24: SSIM(prev, frame[98]) = 0.9959
# Segment 24: SSIM(prev, frame[99]) = 0.9955
# Segment 24: SSIM(prev, frame[97]) = 0.9966
# Segment 24: SSIM(prev, frame[99]) = 0.9955
# Segment 24: SSIM(prev, frame[96]) = 0.9977
# Segment 24: SSIM(prev, frame[96]) = 0.9977
# Segment 24: SSIM(prev, frame[97]) = 0.9966
# Segment 24: SSIM(prev, frame[99]) = 0.9955
# Segment 24: SSIM(prev, frame[98]) = 0.9959
# Segment 24: SSIM(prev, frame[97]) = 0.9966
# Segment 24: SSIM(prev, frame[96]) = 0.9977
# Segment 24: SSIM(prev, frame[96]) = 0.9977
# Segment 24: SSIM(prev, frame[97]) = 0.9966
# Segment 24: SSIM(prev, frame[97]) = 0.9966
# Segment 24: SSIM(prev, frame[96]) = 0.9977
# Segment 24: SSIM(prev, frame[98]) = 0.9959
# Segment 24: SSIM(prev, frame[99]) = 0.9955
# Segment 24: SSIM(prev, frame[96]) = 0.9977
# Segment 24: SSIM(prev, frame[99]) = 0.9955
# Segment 24: Picked index 99 as fallback
#
# Segment 25 original indices: [100 101 102 103]
# Segment 25 shuffle 1 indices: [100 100 100 101]
# Segment 25 shuffle 2 indices: [103 102 103 103]
# Segment 25 shuffle 3 indices: [100 103 103 102]
# Segment 25 shuffle 4 indices: [100 100 103 102]
# Segment 25 shuffle 5 indices: [100 102 103 100]
# Segment 25 shuffle 6 indices: [103 102 100 103]
# Segment 25: SSIM(prev, frame[102]) = 0.9959
# Segment 25: SSIM(prev, frame[100]) = 0.9977
# Segment 25: SSIM(prev, frame[101]) = 0.9966
# Segment 25: SSIM(prev, frame[100]) = 0.9977
# Segment 25: SSIM(prev, frame[100]) = 0.9977
# Segment 25: SSIM(prev, frame[102]) = 0.9959
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: SSIM(prev, frame[102]) = 0.9959
# Segment 25: SSIM(prev, frame[100]) = 0.9977
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: SSIM(prev, frame[100]) = 0.9977
# Segment 25: SSIM(prev, frame[100]) = 0.9977
# Segment 25: SSIM(prev, frame[100]) = 0.9977
# Segment 25: SSIM(prev, frame[102]) = 0.9959
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: SSIM(prev, frame[102]) = 0.9959
# Segment 25: SSIM(prev, frame[100]) = 0.9977
# Segment 25: SSIM(prev, frame[100]) = 0.9977
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: SSIM(prev, frame[103]) = 0.9955
# Segment 25: Picked index 103 as fallback
#
# Segment 26 original indices: [104 105 106 107]
# Segment 26 shuffle 1 indices: [104 107 105 106]
# Segment 26 shuffle 2 indices: [107 107 104 105]
# Segment 26 shuffle 3 indices: [106 107 104 105]
# Segment 26 shuffle 4 indices: [106 107 106 106]
# Segment 26 shuffle 5 indices: [106 106 106 105]
# Segment 26 shuffle 6 indices: [107 105 104 107]
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[104]) = 0.9976
# Segment 26: SSIM(prev, frame[107]) = 0.9955
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[107]) = 0.9955
# Segment 26: SSIM(prev, frame[104]) = 0.9976
# Segment 26: SSIM(prev, frame[104]) = 0.9976
# Segment 26: SSIM(prev, frame[107]) = 0.9955
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[105]) = 0.9966
# Segment 26: SSIM(prev, frame[105]) = 0.9966
# Segment 26: SSIM(prev, frame[104]) = 0.9976
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[107]) = 0.9955
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[107]) = 0.9955
# Segment 26: SSIM(prev, frame[105]) = 0.9966
# Segment 26: SSIM(prev, frame[107]) = 0.9955
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[107]) = 0.9955
# Segment 26: SSIM(prev, frame[105]) = 0.9966
# Segment 26: SSIM(prev, frame[106]) = 0.9959
# Segment 26: SSIM(prev, frame[105]) = 0.9966
# Segment 26: Picked index 107 as fallback
#
# Segment 27 original indices: [108 109 110 111]
# Segment 27 shuffle 1 indices: [110 110 108 111]
# Segment 27 shuffle 2 indices: [109 108 110 111]
# Segment 27 shuffle 3 indices: [111 108 110 110]
# Segment 27 shuffle 4 indices: [109 108 111 109]
# Segment 27 shuffle 5 indices: [110 109 110 109]
# Segment 27 shuffle 6 indices: [111 111 108 109]
# Segment 27: SSIM(prev, frame[108]) = 0.9977
# Segment 27: SSIM(prev, frame[109]) = 0.9966
# Segment 27: SSIM(prev, frame[108]) = 0.9977
# Segment 27: SSIM(prev, frame[109]) = 0.9966
# Segment 27: SSIM(prev, frame[109]) = 0.9966
# Segment 27: SSIM(prev, frame[111]) = 0.9955
# Segment 27: SSIM(prev, frame[110]) = 0.9958
# Segment 27: SSIM(prev, frame[109]) = 0.9966
# Segment 27: SSIM(prev, frame[108]) = 0.9977
# Segment 27: SSIM(prev, frame[110]) = 0.9958
# Segment 27: SSIM(prev, frame[110]) = 0.9958
# Segment 27: SSIM(prev, frame[110]) = 0.9958
# Segment 27: SSIM(prev, frame[110]) = 0.9958
# Segment 27: SSIM(prev, frame[109]) = 0.9966
# Segment 27: SSIM(prev, frame[110]) = 0.9958
# Segment 27: SSIM(prev, frame[111]) = 0.9955
# Segment 27: SSIM(prev, frame[111]) = 0.9955
# Segment 27: SSIM(prev, frame[109]) = 0.9966
# Segment 27: SSIM(prev, frame[110]) = 0.9958
# Segment 27: SSIM(prev, frame[111]) = 0.9955
# Segment 27: SSIM(prev, frame[108]) = 0.9977
# Segment 27: SSIM(prev, frame[111]) = 0.9955
# Segment 27: SSIM(prev, frame[108]) = 0.9977
# Segment 27: SSIM(prev, frame[111]) = 0.9955
# Segment 27: Picked index 111 as fallback
#
# Segment 28 original indices: [112 113 114 115]
# Segment 28 shuffle 1 indices: [112 112 114 115]
# Segment 28 shuffle 2 indices: [112 115 113 115]
# Segment 28 shuffle 3 indices: [115 112 112 114]
# Segment 28 shuffle 4 indices: [115 112 115 113]
# Segment 28 shuffle 5 indices: [112 115 113 112]
# Segment 28 shuffle 6 indices: [114 114 115 113]
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[115]) = 0.9955
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[113]) = 0.9967
# Segment 28: SSIM(prev, frame[113]) = 0.9967
# Segment 28: SSIM(prev, frame[115]) = 0.9955
# Segment 28: SSIM(prev, frame[114]) = 0.9959
# Segment 28: SSIM(prev, frame[113]) = 0.9967
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[114]) = 0.9959
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[115]) = 0.9955
# Segment 28: SSIM(prev, frame[113]) = 0.9967
# Segment 28: SSIM(prev, frame[112]) = 0.9977
# Segment 28: SSIM(prev, frame[114]) = 0.9959
# Segment 28: SSIM(prev, frame[114]) = 0.9959
# Segment 28: SSIM(prev, frame[115]) = 0.9955
# Segment 28: SSIM(prev, frame[115]) = 0.9955
# Segment 28: SSIM(prev, frame[115]) = 0.9955
# Segment 28: SSIM(prev, frame[115]) = 0.9955
# Segment 28: SSIM(prev, frame[115]) = 0.9955
# Segment 28: Picked index 115 as fallback
#
# Segment 29 original indices: [116 117 118 119]
# Segment 29 shuffle 1 indices: [119 119 116 119]
# Segment 29 shuffle 2 indices: [116 118 117 117]
# Segment 29 shuffle 3 indices: [118 116 117 117]
# Segment 29 shuffle 4 indices: [119 116 118 118]
# Segment 29 shuffle 5 indices: [117 116 119 117]
# Segment 29 shuffle 6 indices: [118 116 118 118]
# Segment 29: SSIM(prev, frame[118]) = 0.9961
# Segment 29: SSIM(prev, frame[116]) = 0.9978
# Segment 29: SSIM(prev, frame[118]) = 0.9961
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: SSIM(prev, frame[117]) = 0.9967
# Segment 29: SSIM(prev, frame[118]) = 0.9961
# Segment 29: SSIM(prev, frame[118]) = 0.9961
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: SSIM(prev, frame[116]) = 0.9978
# Segment 29: SSIM(prev, frame[118]) = 0.9961
# Segment 29: SSIM(prev, frame[117]) = 0.9967
# Segment 29: SSIM(prev, frame[117]) = 0.9967
# Segment 29: SSIM(prev, frame[117]) = 0.9967
# Segment 29: SSIM(prev, frame[118]) = 0.9961
# Segment 29: SSIM(prev, frame[116]) = 0.9978
# Segment 29: SSIM(prev, frame[117]) = 0.9967
# Segment 29: SSIM(prev, frame[117]) = 0.9967
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: SSIM(prev, frame[118]) = 0.9961
# Segment 29: SSIM(prev, frame[116]) = 0.9978
# Segment 29: SSIM(prev, frame[116]) = 0.9978
# Segment 29: SSIM(prev, frame[116]) = 0.9978
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: SSIM(prev, frame[119]) = 0.9956
# Segment 29: Picked index 119 as fallback
#
# Skipped videos summary:
# Shape of X after loading and normalization: (1351, 30, 224, 224, 3)
# Shape of y after loading: (1351,)
# Saving preprocessed arrays...
# Feature shape: (1351, 30, 224, 224, 3)
# Label shape: (1351,)

# %%
#load X_prep_segments_30.npy
X = np.load('X_prep_segments_30.npy')

# %%
#load y_labels_segments_30.npy
y = np.load('y_labels_segments_30.npy')

# %%
#print features
print("Features (X) shape:", X.shape)
print("Labels (y) shape:", y.shape)
# Out:
# Features (X) shape: (1351, 30, 224, 224, 3)
# Labels (y) shape: (1351,)

# %%
# #load X_prep_segments.npy
# X = np.load('X_prep_segments_30.npy')

# %%
#print X features
print("Features (X) shape:", X.shape)
# Out:
# Features (X) shape: (1351, 30, 224, 224, 3)

# %%
print(X)
# Out:
# [[[[[0.30980396 0.34901965 0.33333337]
#     [0.32549024 0.35686278 0.33333337]
#     [0.33333337 0.3411765  0.33333337]
#     ...
#     [0.4039216  0.3803922  0.39607847]
#     [0.39607847 0.37254906 0.3803922 ]
#     [0.3803922  0.4039216  0.4039216 ]]
#
#    [[0.36470592 0.3411765  0.33333337]
#     [0.35686278 0.35686278 0.3411765 ]
#     [0.34901965 0.34901965 0.3411765 ]
#     ...
#     [0.4039216  0.38823533 0.39607847]
#     [0.41960788 0.39607847 0.4039216 ]
#     [0.41176474 0.38823533 0.39607847]]
#
#    [[0.36470592 0.3411765  0.34901965]
#     [0.36470592 0.3411765  0.34901965]
#     [0.35686278 0.34901965 0.3411765 ]
#     ...
#     [0.4039216  0.38823533 0.4039216 ]
#     [0.41176474 0.38823533 0.4039216 ]
#     [0.3803922  0.37254906 0.38823533]]
#
#    ...
#
#    [[0.21568632 0.20784318 0.21568632]
#     [0.14509809 0.14509809 0.14509809]
#     [0.1686275  0.16078436 0.17647064]
#     ...
#     [0.26274514 0.26274514 0.30196083]
#     [0.254902   0.23921573 0.27843142]
#     [0.27058828 0.254902   0.2941177 ]]
#
#    [[0.1686275  0.13725495 0.16078436]
#     [0.18431377 0.13725495 0.16078436]
#     [0.1686275  0.12941182 0.15294123]
#     ...
#     [0.24705887 0.26274514 0.30980396]
#     [0.26274514 0.26274514 0.3176471 ]
#     [0.28627455 0.26274514 0.3176471 ]]
#
#    [[0.14509809 0.11372554 0.13725495]
#     [0.15294123 0.10588241 0.12941182]
#     [0.19215691 0.11372554 0.14509809]
#     ...
#     [0.2313726  0.23921573 0.28627455]
#     [0.23921573 0.23921573 0.2941177 ]
#     [0.26274514 0.23921573 0.2941177 ]]]
#
#
#   [[[0.38823533 0.34901965 0.3411765 ]
#     [0.38823533 0.34901965 0.3411765 ]
#     [0.37254906 0.33333337 0.32549024]
#     ...
#     [0.41176474 0.39607847 0.41176474]
#     [0.41960788 0.39607847 0.4039216 ]
#     [0.4039216  0.4039216  0.4039216 ]]
#
#    [[0.37254906 0.34901965 0.3411765 ]
#     [0.37254906 0.34901965 0.3411765 ]
#     [0.37254906 0.34901965 0.3411765 ]
#     ...
#     [0.4039216  0.38823533 0.4039216 ]
#     [0.41960788 0.39607847 0.4039216 ]
#     [0.4039216  0.4039216  0.4039216 ]]
#
#    [[0.35686278 0.35686278 0.35686278]
#     [0.35686278 0.35686278 0.35686278]
#     [0.36470592 0.34901965 0.35686278]
#     ...
#     [0.4039216  0.38823533 0.4039216 ]
#     [0.41960788 0.38823533 0.41176474]
#     [0.4039216  0.39607847 0.41176474]]
#
#    ...
#
#    [[0.15294123 0.14509809 0.16078436]
#     [0.15294123 0.14509809 0.16078436]
#     [0.15294123 0.14509809 0.16078436]
#     ...
#     [0.27843142 0.26274514 0.30196083]
#     [0.27843142 0.26274514 0.30196083]
#     [0.27843142 0.26274514 0.30196083]]
#
#    [[0.1686275  0.14509809 0.15294123]
#     [0.15294123 0.14509809 0.16078436]
#     [0.15294123 0.12941182 0.15294123]
#     ...
#     [0.24705887 0.254902   0.2941177 ]
#     [0.23921573 0.24705887 0.28627455]
#     [0.254902   0.26274514 0.30196083]]
#
#    [[0.1686275  0.14509809 0.15294123]
#     [0.13725495 0.12941182 0.14509809]
#     [0.13725495 0.13725495 0.14509809]
#     ...
#     [0.22352946 0.23921573 0.27843142]
#     [0.22352946 0.2313726  0.27843142]
#     [0.23921573 0.24705887 0.28627455]]]
#
#
#   [[[0.38823533 0.34901965 0.3411765 ]
#     [0.38823533 0.34901965 0.3411765 ]
#     [0.38823533 0.34901965 0.3411765 ]
#     ...
#     [0.427451   0.4039216  0.39607847]
#     [0.427451   0.4039216  0.39607847]
#     [0.427451   0.4039216  0.39607847]]
#
#    [[0.39607847 0.36470592 0.33333337]
#     [0.39607847 0.36470592 0.33333337]
#     [0.38823533 0.35686278 0.33333337]
#     ...
#     [0.427451   0.4039216  0.39607847]
#     [0.427451   0.4039216  0.39607847]
#     [0.427451   0.4039216  0.39607847]]
#
#    [[0.39607847 0.37254906 0.32549024]
#     [0.39607847 0.37254906 0.32549024]
#     [0.38823533 0.36470592 0.32549024]
#     ...
#     [0.427451   0.4039216  0.39607847]
#     [0.427451   0.4039216  0.39607847]
#     [0.427451   0.4039216  0.39607847]]
#
#    ...
#
#    [[0.1686275  0.14509809 0.15294123]
#     [0.1686275  0.14509809 0.15294123]
#     [0.1686275  0.14509809 0.16078436]
#     ...
#     [0.27058828 0.27058828 0.30980396]
#     [0.26274514 0.27843142 0.3176471 ]
#     [0.254902   0.27058828 0.30980396]]
#
#    [[0.18431377 0.13725495 0.16078436]
#     [0.19215691 0.12156868 0.15294123]
#     [0.1686275  0.13725495 0.15294123]
#     ...
#     [0.254902   0.27058828 0.30196083]
#     [0.254902   0.27058828 0.28627455]
#     [0.254902   0.27058828 0.28627455]]
#
#    [[0.17647064 0.12941182 0.15294123]
#     [0.18431377 0.11372554 0.14509809]
#     [0.16078436 0.12156868 0.13725495]
#     ...
#     [0.254902   0.27058828 0.30196083]
#     [0.254902   0.27058828 0.28627455]
#     [0.23921573 0.254902   0.27058828]]]
#
#
#   ...
#
#
#   [[[0.427451   0.37254906 0.34901965]
#     [0.427451   0.37254906 0.34901965]
#     [0.4431373  0.3803922  0.35686278]
#     ...
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41176474 0.43529415]]
#
#    [[0.427451   0.37254906 0.34901965]
#     [0.41960788 0.36470592 0.3411765 ]
#     [0.427451   0.37254906 0.3411765 ]
#     ...
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41176474 0.43529415]]
#
#    [[0.427451   0.36470592 0.3411765 ]
#     [0.427451   0.37254906 0.34901965]
#     [0.43529415 0.36470592 0.3411765 ]
#     ...
#     [0.45098042 0.41960788 0.43529415]
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41176474 0.43529415]]
#
#    ...
#
#    [[0.14509809 0.14509809 0.20000005]
#     [0.14509809 0.14509809 0.20000005]
#     [0.14509809 0.14509809 0.20000005]
#     ...
#     [0.24705887 0.26274514 0.35686278]
#     [0.2313726  0.254902   0.3411765 ]
#     [0.23921573 0.26274514 0.34901965]]
#
#    [[0.15294123 0.15294123 0.20000005]
#     [0.14509809 0.14509809 0.20000005]
#     [0.12941182 0.12941182 0.18431377]
#     ...
#     [0.22352946 0.26274514 0.33333337]
#     [0.23921573 0.27058828 0.3411765 ]
#     [0.254902   0.26274514 0.3411765 ]]
#
#    [[0.14509809 0.14509809 0.20000005]
#     [0.12941182 0.12941182 0.18431377]
#     [0.12941182 0.12941182 0.18431377]
#     ...
#     [0.22352946 0.26274514 0.33333337]
#     [0.2313726  0.26274514 0.33333337]
#     [0.254902   0.26274514 0.3411765 ]]]
#
#
#   [[[0.4431373  0.37254906 0.34901965]
#     [0.45098042 0.3803922  0.35686278]
#     [0.43529415 0.36470592 0.34901965]
#     ...
#     [0.43529415 0.4039216  0.427451  ]
#     [0.43529415 0.4039216  0.427451  ]
#     [0.4431373  0.41960788 0.427451  ]]
#
#    [[0.43529415 0.36470592 0.3411765 ]
#     [0.4431373  0.37254906 0.34901965]
#     [0.43529415 0.36470592 0.35686278]
#     ...
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41960788 0.427451  ]]
#
#    [[0.43529415 0.36470592 0.34901965]
#     [0.4431373  0.37254906 0.34901965]
#     [0.4431373  0.37254906 0.34901965]
#     ...
#     [0.45098042 0.41960788 0.43529415]
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41960788 0.427451  ]]
#
#    ...
#
#    [[0.15294123 0.15294123 0.20784318]
#     [0.14509809 0.14509809 0.20000005]
#     [0.14509809 0.14509809 0.20784318]
#     ...
#     [0.24705887 0.27843142 0.34901965]
#     [0.24705887 0.27843142 0.3411765 ]
#     [0.24705887 0.27843142 0.34901965]]
#
#    [[0.14509809 0.14509809 0.20000005]
#     [0.14509809 0.14509809 0.20000005]
#     [0.13725495 0.13725495 0.19215691]
#     ...
#     [0.23921573 0.26274514 0.3411765 ]
#     [0.23921573 0.26274514 0.34901965]
#     [0.22352946 0.26274514 0.34901965]]
#
#    [[0.12941182 0.12941182 0.18431377]
#     [0.12156868 0.12156868 0.17647064]
#     [0.12941182 0.12941182 0.19215691]
#     ...
#     [0.2313726  0.254902   0.33333337]
#     [0.22352946 0.24705887 0.33333337]
#     [0.22352946 0.26274514 0.34901965]]]
#
#
#   [[[0.427451   0.37254906 0.34901965]
#     [0.4039216  0.36470592 0.35686278]
#     [0.427451   0.36470592 0.35686278]
#     ...
#     [0.45098042 0.41960788 0.43529415]
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41176474 0.43529415]]
#
#    [[0.4431373  0.36470592 0.3803922 ]
#     [0.4431373  0.36470592 0.36470592]
#     [0.4431373  0.37254906 0.35686278]
#     ...
#     [0.45882356 0.41960788 0.43529415]
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41176474 0.43529415]]
#
#    [[0.4431373  0.3803922  0.3803922 ]
#     [0.4431373  0.36470592 0.36470592]
#     [0.4431373  0.37254906 0.35686278]
#     ...
#     [0.45882356 0.41960788 0.43529415]
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41176474 0.43529415]]
#
#    ...
#
#    [[0.1686275  0.14509809 0.20000005]
#     [0.15294123 0.15294123 0.20784318]
#     [0.14509809 0.14509809 0.20000005]
#     ...
#     [0.2313726  0.26274514 0.33333337]
#     [0.2313726  0.26274514 0.33333337]
#     [0.24705887 0.27843142 0.34901965]]
#
#    [[0.15294123 0.15294123 0.20784318]
#     [0.12941182 0.12156868 0.20000005]
#     [0.14509809 0.13725495 0.20784318]
#     ...
#     [0.22352946 0.254902   0.33333337]
#     [0.2313726  0.26274514 0.33333337]
#     [0.2313726  0.27058828 0.35686278]]
#
#    [[0.14509809 0.14509809 0.20000005]
#     [0.12941182 0.12156868 0.20000005]
#     [0.12156868 0.12156868 0.18431377]
#     ...
#     [0.2313726  0.254902   0.3411765 ]
#     [0.2313726  0.26274514 0.33333337]
#     [0.22352946 0.26274514 0.34901965]]]]
#
#
#
#  [[[[0.38823533 0.34901965 0.35686278]
#     [0.3803922  0.3411765  0.34901965]
#     [0.37254906 0.3411765  0.34901965]
#     ...
#     [0.41176474 0.41176474 0.41176474]
#     [0.39607847 0.39607847 0.39607847]
#     [0.41176474 0.41176474 0.41176474]]
#
#    [[0.3803922  0.3411765  0.34901965]
#     [0.3803922  0.3411765  0.34901965]
#     [0.3803922  0.34901965 0.35686278]
#     ...
#     [0.41176474 0.41176474 0.41176474]
#     [0.41960788 0.41960788 0.41960788]
#     [0.41176474 0.41176474 0.41176474]]
#
#    [[0.37254906 0.34901965 0.35686278]
#     [0.3803922  0.35686278 0.36470592]
#     [0.37254906 0.34901965 0.35686278]
#     ...
#     [0.41176474 0.41176474 0.41176474]
#     [0.41176474 0.41176474 0.41176474]
#     [0.41176474 0.41176474 0.41176474]]
#
#    ...
#
#    [[0.18431377 0.15294123 0.17647064]
#     [0.1686275  0.16078436 0.17647064]
#     [0.17647064 0.15294123 0.18431377]
#     ...
#     [0.2313726  0.26274514 0.30980396]
#     [0.24705887 0.26274514 0.3176471 ]
#     [0.24705887 0.26274514 0.3176471 ]]
#
#    [[0.14509809 0.12941182 0.1686275 ]
#     [0.16078436 0.12156868 0.1686275 ]
#     [0.16078436 0.12156868 0.17647064]
#     ...
#     [0.21568632 0.254902   0.2941177 ]
#     [0.2313726  0.27843142 0.30980396]
#     [0.26274514 0.26274514 0.3176471 ]]
#
#    [[0.14509809 0.12941182 0.1686275 ]
#     [0.16078436 0.12156868 0.1686275 ]
#     [0.1686275  0.12156868 0.1686275 ]
#     ...
#     [0.22352946 0.26274514 0.30196083]
#     [0.2313726  0.27843142 0.30980396]
#     [0.26274514 0.26274514 0.3176471 ]]]
#
#
#   [[[0.3803922  0.35686278 0.36470592]
#     [0.36470592 0.3411765  0.34901965]
#     [0.37254906 0.34901965 0.35686278]
#     ...
#     [0.427451   0.39607847 0.41176474]
#     [0.41960788 0.39607847 0.4039216 ]
#     [0.427451   0.4039216  0.41176474]]
#
#    [[0.3803922  0.35686278 0.36470592]
#     [0.3803922  0.35686278 0.36470592]
#     [0.37254906 0.34901965 0.35686278]
#     ...
#     [0.427451   0.39607847 0.41176474]
#     [0.41960788 0.39607847 0.4039216 ]
#     [0.427451   0.4039216  0.41176474]]
#
#    [[0.37254906 0.34901965 0.35686278]
#     [0.37254906 0.34901965 0.35686278]
#     [0.37254906 0.34901965 0.35686278]
#     ...
#     [0.41176474 0.4039216  0.41176474]
#     [0.4039216  0.39607847 0.41176474]
#     [0.41176474 0.4039216  0.41960788]]
#
#    ...
#
#    [[0.14509809 0.13725495 0.1686275 ]
#     [0.18431377 0.14509809 0.19215691]
#     [0.16078436 0.13725495 0.17647064]
#     ...
#     [0.23921573 0.254902   0.30980396]
#     [0.27058828 0.27058828 0.32549024]
#     [0.2313726  0.26274514 0.30980396]]
#
#    [[0.12941182 0.13725495 0.17647064]
#     [0.12941182 0.13725495 0.17647064]
#     [0.16078436 0.14509809 0.20784318]
#     ...
#     [0.22352946 0.22352946 0.2941177 ]
#     [0.254902   0.254902   0.30980396]
#     [0.254902   0.254902   0.30980396]]
#
#    [[0.12156868 0.12941182 0.1686275 ]
#     [0.12941182 0.13725495 0.17647064]
#     [0.1686275  0.15294123 0.20784318]
#     ...
#     [0.22352946 0.22352946 0.2941177 ]
#     [0.23921573 0.23921573 0.2941177 ]
#     [0.23921573 0.23921573 0.2941177 ]]]
#
#
#   [[[0.36470592 0.36470592 0.34901965]
#     [0.36470592 0.36470592 0.34901965]
#     [0.3803922  0.35686278 0.34901965]
#     ...
#     [0.427451   0.41176474 0.41960788]
#     [0.41176474 0.4039216  0.41960788]
#     [0.41176474 0.4039216  0.41960788]]
#
#    [[0.36470592 0.36470592 0.34901965]
#     [0.36470592 0.36470592 0.34901965]
#     [0.3803922  0.35686278 0.34901965]
#     ...
#     [0.41960788 0.4039216  0.41176474]
#     [0.41176474 0.4039216  0.41960788]
#     [0.41176474 0.4039216  0.41960788]]
#
#    [[0.3803922  0.35686278 0.34901965]
#     [0.3803922  0.35686278 0.34901965]
#     [0.3803922  0.35686278 0.34901965]
#     ...
#     [0.427451   0.41176474 0.41960788]
#     [0.41960788 0.41176474 0.427451  ]
#     [0.41960788 0.41176474 0.427451  ]]
#
#    ...
#
#    [[0.14509809 0.13725495 0.17647064]
#     [0.1686275  0.15294123 0.19215691]
#     [0.15294123 0.13725495 0.17647064]
#     ...
#     [0.24705887 0.26274514 0.3176471 ]
#     [0.24705887 0.26274514 0.3176471 ]
#     [0.24705887 0.26274514 0.3176471 ]]
#
#    [[0.12941182 0.14509809 0.16078436]
#     [0.12941182 0.14509809 0.16078436]
#     [0.12156868 0.13725495 0.15294123]
#     ...
#     [0.23921573 0.24705887 0.30196083]
#     [0.26274514 0.26274514 0.3176471 ]
#     [0.26274514 0.26274514 0.3176471 ]]
#
#    [[0.12941182 0.14509809 0.16078436]
#     [0.12941182 0.14509809 0.16078436]
#     [0.12156868 0.13725495 0.15294123]
#     ...
#     [0.2313726  0.23921573 0.2941177 ]
#     [0.24705887 0.24705887 0.30196083]
#     [0.23921573 0.23921573 0.2941177 ]]]
#
#
#   ...
#
#
#   [[[0.3803922  0.3803922  0.3803922 ]
#     [0.3803922  0.35686278 0.36470592]
#     [0.3803922  0.35686278 0.35686278]
#     ...
#     [0.427451   0.4039216  0.427451  ]
#     [0.41176474 0.4039216  0.41960788]
#     [0.41960788 0.41176474 0.427451  ]]
#
#    [[0.37254906 0.34901965 0.3411765 ]
#     [0.37254906 0.34901965 0.35686278]
#     [0.3803922  0.35686278 0.35686278]
#     ...
#     [0.41960788 0.39607847 0.41960788]
#     [0.41176474 0.4039216  0.41960788]
#     [0.38823533 0.4039216  0.41960788]]
#
#    [[0.37254906 0.35686278 0.35686278]
#     [0.38823533 0.34901965 0.35686278]
#     [0.3803922  0.35686278 0.34901965]
#     ...
#     [0.41176474 0.4039216  0.427451  ]
#     [0.41176474 0.4039216  0.41960788]
#     [0.41176474 0.4039216  0.41960788]]
#
#    ...
#
#    [[0.17647064 0.16078436 0.20000005]
#     [0.16078436 0.14509809 0.18431377]
#     [0.13725495 0.13725495 0.17647064]
#     ...
#     [0.254902   0.254902   0.32549024]
#     [0.26274514 0.26274514 0.3176471 ]
#     [0.26274514 0.26274514 0.3176471 ]]
#
#    [[0.12941182 0.13725495 0.17647064]
#     [0.12941182 0.13725495 0.17647064]
#     [0.12941182 0.13725495 0.17647064]
#     ...
#     [0.23921573 0.254902   0.3176471 ]
#     [0.23921573 0.24705887 0.32549024]
#     [0.23921573 0.24705887 0.32549024]]
#
#    [[0.12156868 0.12941182 0.1686275 ]
#     [0.11372554 0.12156868 0.16078436]
#     [0.11372554 0.12156868 0.16078436]
#     ...
#     [0.24705887 0.254902   0.32549024]
#     [0.23921573 0.24705887 0.32549024]
#     [0.23921573 0.24705887 0.32549024]]]
#
#
#   [[[0.3803922  0.35686278 0.34901965]
#     [0.38823533 0.34901965 0.3411765 ]
#     [0.36470592 0.35686278 0.3411765 ]
#     ...
#     [0.38823533 0.39607847 0.41176474]
#     [0.39607847 0.41176474 0.427451  ]
#     [0.427451   0.41960788 0.43529415]]
#
#    [[0.37254906 0.34901965 0.3411765 ]
#     [0.36470592 0.36470592 0.34901965]
#     [0.3803922  0.36470592 0.35686278]
#     ...
#     [0.39607847 0.4039216  0.41960788]
#     [0.38823533 0.4039216  0.41960788]
#     [0.41176474 0.4039216  0.41960788]]
#
#    [[0.37254906 0.35686278 0.35686278]
#     [0.37254906 0.34901965 0.35686278]
#     [0.3803922  0.35686278 0.36470592]
#     ...
#     [0.427451   0.4039216  0.427451  ]
#     [0.38823533 0.39607847 0.41176474]
#     [0.41176474 0.4039216  0.41960788]]
#
#    ...
#
#    [[0.16078436 0.14509809 0.18431377]
#     [0.15294123 0.13725495 0.17647064]
#     [0.14509809 0.12941182 0.1686275 ]
#     ...
#     [0.24705887 0.254902   0.30980396]
#     [0.26274514 0.26274514 0.3176471 ]
#     [0.26274514 0.26274514 0.3176471 ]]
#
#    [[0.14509809 0.15294123 0.19215691]
#     [0.12941182 0.13725495 0.17647064]
#     [0.12156868 0.12156868 0.17647064]
#     ...
#     [0.24705887 0.254902   0.30196083]
#     [0.254902   0.254902   0.30980396]
#     [0.2941177  0.27058828 0.32549024]]
#
#    [[0.12156868 0.12941182 0.1686275 ]
#     [0.12156868 0.12941182 0.1686275 ]
#     [0.11372554 0.11372554 0.1686275 ]
#     ...
#     [0.254902   0.254902   0.30196083]
#     [0.254902   0.254902   0.30980396]
#     [0.23921573 0.23921573 0.2941177 ]]]
#
#
#   [[[0.3803922  0.3411765  0.34901965]
#     [0.39607847 0.35686278 0.36470592]
#     [0.3803922  0.37254906 0.3803922 ]
#     ...
#     [0.427451   0.38823533 0.41176474]
#     [0.4039216  0.39607847 0.41176474]
#     [0.427451   0.41960788 0.43529415]]
#
#    [[0.37254906 0.34901965 0.35686278]
#     [0.36470592 0.36470592 0.36470592]
#     [0.3803922  0.34901965 0.37254906]
#     ...
#     [0.427451   0.4039216  0.427451  ]
#     [0.38823533 0.4039216  0.41960788]
#     [0.38823533 0.4039216  0.41960788]]
#
#    [[0.37254906 0.35686278 0.35686278]
#     [0.37254906 0.34901965 0.35686278]
#     [0.3803922  0.35686278 0.36470592]
#     ...
#     [0.41176474 0.4039216  0.41960788]
#     [0.4039216  0.39607847 0.41176474]
#     [0.41176474 0.4039216  0.41960788]]
#
#    ...
#
#    [[0.1686275  0.15294123 0.19215691]
#     [0.15294123 0.13725495 0.17647064]
#     [0.16078436 0.13725495 0.17647064]
#     ...
#     [0.254902   0.24705887 0.32549024]
#     [0.26274514 0.254902   0.33333337]
#     [0.24705887 0.254902   0.33333337]]
#
#    [[0.1686275  0.12941182 0.17647064]
#     [0.18431377 0.13725495 0.20000005]
#     [0.17647064 0.12156868 0.17647064]
#     ...
#     [0.23921573 0.24705887 0.32549024]
#     [0.23921573 0.24705887 0.32549024]
#     [0.27058828 0.26274514 0.3411765 ]]
#
#    [[0.1686275  0.12941182 0.17647064]
#     [0.15294123 0.10588241 0.1686275 ]
#     [0.1686275  0.10588241 0.1686275 ]
#     ...
#     [0.23921573 0.24705887 0.32549024]
#     [0.23921573 0.24705887 0.32549024]
#     [0.24705887 0.254902   0.33333337]]]]
#
#
#
#  [[[[0.35686278 0.33333337 0.32549024]
#     [0.36470592 0.36470592 0.34901965]
#     [0.3803922  0.35686278 0.35686278]
#     ...
#     [0.4039216  0.39607847 0.4039216 ]
#     [0.4039216  0.39607847 0.41176474]
#     [0.4039216  0.39607847 0.41176474]]
#
#    [[0.3803922  0.35686278 0.34901965]
#     [0.37254906 0.34901965 0.3411765 ]
#     [0.39607847 0.35686278 0.35686278]
#     ...
#     [0.39607847 0.38823533 0.39607847]
#     [0.4039216  0.39607847 0.41176474]
#     [0.4039216  0.39607847 0.41176474]]
#
#    [[0.3803922  0.34901965 0.3411765 ]
#     [0.39607847 0.33333337 0.33333337]
#     [0.3803922  0.3176471  0.32549024]
#     ...
#     [0.41960788 0.38823533 0.4039216 ]
#     [0.41176474 0.3803922  0.4039216 ]
#     [0.41176474 0.38823533 0.4039216 ]]
#
#    ...
#
#    [[0.14509809 0.13725495 0.18431377]
#     [0.16078436 0.14509809 0.20000005]
#     [0.13725495 0.12941182 0.17647064]
#     ...
#     [0.2313726  0.254902   0.30196083]
#     [0.24705887 0.27058828 0.30980396]
#     [0.254902   0.27058828 0.32549024]]
#
#    [[0.13725495 0.12156868 0.16078436]
#     [0.14509809 0.12156868 0.17647064]
#     [0.15294123 0.12941182 0.17647064]
#     ...
#     [0.23921573 0.254902   0.30980396]
#     [0.23921573 0.254902   0.30980396]
#     [0.254902   0.254902   0.30980396]]
#
#    [[0.14509809 0.12941182 0.1686275 ]
#     [0.12156868 0.09803927 0.15294123]
#     [0.13725495 0.11372554 0.16078436]
#     ...
#     [0.24705887 0.254902   0.32549024]
#     [0.2313726  0.23921573 0.3176471 ]
#     [0.26274514 0.23921573 0.2941177 ]]]
#
#
#   [[[0.37254906 0.34901965 0.3411765 ]
#     [0.36470592 0.3411765  0.33333337]
#     [0.3803922  0.34901965 0.3411765 ]
#     ...
#     [0.41176474 0.41176474 0.41176474]
#     [0.4039216  0.4039216  0.4039216 ]
#     [0.41176474 0.41176474 0.41176474]]
#
#    [[0.37254906 0.34901965 0.3411765 ]
#     [0.37254906 0.34901965 0.3411765 ]
#     [0.3803922  0.34901965 0.3411765 ]
#     ...
#     [0.41176474 0.4039216  0.4039216 ]
#     [0.427451   0.4039216  0.41176474]
#     [0.41960788 0.39607847 0.4039216 ]]
#
#    [[0.37254906 0.34901965 0.3411765 ]
#     [0.37254906 0.34901965 0.3411765 ]
#     [0.37254906 0.3411765  0.33333337]
#     ...
#     [0.41176474 0.4039216  0.4039216 ]
#     [0.427451   0.4039216  0.41176474]
#     [0.41960788 0.39607847 0.4039216 ]]
#
#    ...
#
#    [[0.15294123 0.13725495 0.17647064]
#     [0.15294123 0.13725495 0.17647064]
#     [0.14509809 0.12941182 0.1686275 ]
#     ...
#     [0.254902   0.254902   0.30196083]
#     [0.26274514 0.27058828 0.30980396]
#     [0.27058828 0.27058828 0.32549024]]
#
#    [[0.14509809 0.12941182 0.1686275 ]
#     [0.14509809 0.12941182 0.1686275 ]
#     [0.14509809 0.12941182 0.15294123]
#     ...
#     [0.23921573 0.23921573 0.28627455]
#     [0.254902   0.254902   0.30980396]
#     [0.22352946 0.23921573 0.2941177 ]]
#
#    [[0.15294123 0.13725495 0.17647064]
#     [0.12941182 0.11372554 0.15294123]
#     [0.13725495 0.12156868 0.15294123]
#     ...
#     [0.23921573 0.23921573 0.28627455]
#     [0.23921573 0.23921573 0.2941177 ]
#     [0.21568632 0.2313726  0.28627455]]]
#
#
#   [[[0.37254906 0.34901965 0.3411765 ]
#     [0.36470592 0.3411765  0.33333337]
#     [0.38823533 0.34901965 0.3411765 ]
#     ...
#     [0.41176474 0.41176474 0.41176474]
#     [0.41176474 0.41176474 0.41176474]
#     [0.41176474 0.41176474 0.41176474]]
#
#    [[0.37254906 0.34901965 0.3411765 ]
#     [0.37254906 0.34901965 0.3411765 ]
#     [0.38823533 0.34901965 0.3411765 ]
#     ...
#     [0.41176474 0.41176474 0.41176474]
#     [0.41176474 0.41176474 0.41176474]
#     [0.41176474 0.41176474 0.41176474]]
#
#    [[0.37254906 0.34901965 0.3411765 ]
#     [0.37254906 0.34901965 0.3411765 ]
#     [0.36470592 0.3411765  0.33333337]
#     ...
#     [0.41176474 0.41176474 0.41176474]
#     [0.41176474 0.41176474 0.41176474]
#     [0.41176474 0.41176474 0.41176474]]
#
#    ...
#
#    [[0.14509809 0.12941182 0.1686275 ]
#     [0.15294123 0.13725495 0.17647064]
#     [0.14509809 0.12941182 0.1686275 ]
#     ...
#     [0.26274514 0.254902   0.30196083]
#     [0.27058828 0.24705887 0.30196083]
#     [0.254902   0.254902   0.30980396]]
#
#    [[0.13725495 0.12941182 0.14509809]
#     [0.16078436 0.12941182 0.15294123]
#     [0.14509809 0.12156868 0.15294123]
#     ...
#     [0.2313726  0.23921573 0.3176471 ]
#     [0.27843142 0.24705887 0.32549024]
#     [0.23921573 0.2313726  0.30980396]]
#
#    [[0.15294123 0.14509809 0.16078436]
#     [0.14509809 0.11372554 0.13725495]
#     [0.14509809 0.12156868 0.15294123]
#     ...
#     [0.22352946 0.2313726  0.30980396]
#     [0.26274514 0.2313726  0.30980396]
#     [0.23921573 0.2313726  0.30980396]]]
#
#
#   ...
#
#
#   [[[0.35686278 0.3803922  0.3803922 ]
#     [0.37254906 0.37254906 0.37254906]
#     [0.39607847 0.35686278 0.36470592]
#     ...
#     [0.41960788 0.41176474 0.427451  ]
#     [0.4039216  0.39607847 0.41176474]
#     [0.41176474 0.4039216  0.41960788]]
#
#    [[0.3803922  0.3803922  0.3803922 ]
#     [0.3803922  0.35686278 0.36470592]
#     [0.39607847 0.35686278 0.36470592]
#     ...
#     [0.41176474 0.4039216  0.41960788]
#     [0.4039216  0.39607847 0.41176474]
#     [0.41176474 0.4039216  0.41960788]]
#
#    [[0.38823533 0.35686278 0.35686278]
#     [0.39607847 0.35686278 0.36470592]
#     [0.39607847 0.35686278 0.36470592]
#     ...
#     [0.41176474 0.4039216  0.41960788]
#     [0.41176474 0.4039216  0.41960788]
#     [0.41176474 0.4039216  0.41960788]]
#
#    ...
#
#    [[0.14509809 0.15294123 0.19215691]
#     [0.14509809 0.15294123 0.19215691]
#     [0.13725495 0.12941182 0.1686275 ]
#     ...
#     [0.27058828 0.26274514 0.33333337]
#     [0.27058828 0.26274514 0.3411765 ]
#     [0.26274514 0.254902   0.33333337]]
#
#    [[0.14509809 0.15294123 0.19215691]
#     [0.12941182 0.15294123 0.19215691]
#     [0.13725495 0.12941182 0.18431377]
#     ...
#     [0.24705887 0.254902   0.3176471 ]
#     [0.254902   0.24705887 0.32549024]
#     [0.26274514 0.26274514 0.3176471 ]]
#
#    [[0.12941182 0.13725495 0.17647064]
#     [0.12156868 0.12941182 0.1686275 ]
#     [0.11372554 0.10588241 0.15294123]
#     ...
#     [0.254902   0.254902   0.32549024]
#     [0.254902   0.24705887 0.32549024]
#     [0.254902   0.254902   0.30980396]]]
#
#
#   [[[0.38823533 0.36470592 0.37254906]
#     [0.3803922  0.35686278 0.36470592]
#     [0.38823533 0.35686278 0.34901965]
#     ...
#     [0.4039216  0.4039216  0.41960788]
#     [0.38823533 0.4039216  0.41960788]
#     [0.4039216  0.39607847 0.41176474]]
#
#    [[0.38823533 0.36470592 0.37254906]
#     [0.37254906 0.34901965 0.35686278]
#     [0.38823533 0.35686278 0.35686278]
#     ...
#     [0.41960788 0.4039216  0.427451  ]
#     [0.43529415 0.4039216  0.427451  ]
#     [0.4039216  0.39607847 0.4039216 ]]
#
#    [[0.3803922  0.35686278 0.36470592]
#     [0.3803922  0.35686278 0.36470592]
#     [0.38823533 0.34901965 0.34901965]
#     ...
#     [0.41960788 0.41176474 0.427451  ]
#     [0.41960788 0.41176474 0.427451  ]
#     [0.427451   0.41176474 0.427451  ]]
#
#    ...
#
#    [[0.1686275  0.15294123 0.19215691]
#     [0.15294123 0.13725495 0.17647064]
#     [0.13725495 0.12156868 0.16078436]
#     ...
#     [0.254902   0.26274514 0.3176471 ]
#     [0.254902   0.254902   0.3176471 ]
#     [0.254902   0.254902   0.3176471 ]]
#
#    [[0.14509809 0.12941182 0.1686275 ]
#     [0.15294123 0.13725495 0.17647064]
#     [0.12941182 0.12941182 0.1686275 ]
#     ...
#     [0.254902   0.24705887 0.3176471 ]
#     [0.254902   0.24705887 0.32549024]
#     [0.254902   0.254902   0.30980396]]
#
#    [[0.15294123 0.13725495 0.17647064]
#     [0.14509809 0.12941182 0.1686275 ]
#     [0.12941182 0.12941182 0.1686275 ]
#     ...
#     [0.26274514 0.26274514 0.32549024]
#     [0.254902   0.24705887 0.32549024]
#     [0.254902   0.254902   0.30980396]]]
#
#
#   [[[0.39607847 0.35686278 0.36470592]
#     [0.38823533 0.34901965 0.35686278]
#     [0.38823533 0.34901965 0.35686278]
#     ...
#     [0.41176474 0.4039216  0.41960788]
#     [0.41176474 0.4039216  0.41960788]
#     [0.41176474 0.4039216  0.41960788]]
#
#    [[0.39607847 0.35686278 0.36470592]
#     [0.3803922  0.35686278 0.36470592]
#     [0.38823533 0.35686278 0.36470592]
#     ...
#     [0.41960788 0.4039216  0.427451  ]
#     [0.41176474 0.4039216  0.41960788]
#     [0.41960788 0.4039216  0.427451  ]]
#
#    [[0.39607847 0.35686278 0.36470592]
#     [0.39607847 0.35686278 0.36470592]
#     [0.39607847 0.35686278 0.36470592]
#     ...
#     [0.41960788 0.41176474 0.427451  ]
#     [0.41960788 0.41176474 0.427451  ]
#     [0.41960788 0.41176474 0.427451  ]]
#
#    ...
#
#    [[0.16078436 0.14509809 0.18431377]
#     [0.14509809 0.13725495 0.1686275 ]
#     [0.14509809 0.12941182 0.1686275 ]
#     ...
#     [0.27058828 0.26274514 0.33333337]
#     [0.27058828 0.26274514 0.3411765 ]
#     [0.26274514 0.254902   0.33333337]]
#
#    [[0.16078436 0.14509809 0.18431377]
#     [0.15294123 0.13725495 0.17647064]
#     [0.14509809 0.12941182 0.1686275 ]
#     ...
#     [0.26274514 0.254902   0.32549024]
#     [0.26274514 0.26274514 0.3176471 ]
#     [0.254902   0.254902   0.30980396]]
#
#    [[0.15294123 0.13725495 0.17647064]
#     [0.13725495 0.12941182 0.16078436]
#     [0.14509809 0.12941182 0.1686275 ]
#     ...
#     [0.254902   0.24705887 0.3176471 ]
#     [0.254902   0.254902   0.30980396]
#     [0.26274514 0.26274514 0.30980396]]]]
#
#
#
#  ...
#
#
#
#  [[[[0.69411767 0.69411767 0.6784314 ]
#     [0.69411767 0.69411767 0.6784314 ]
#     [0.69411767 0.69411767 0.6784314 ]
#     ...
#     [0.7019608  0.7176471  0.7254902 ]
#     [0.7019608  0.7176471  0.73333335]
#     [0.7019608  0.7176471  0.73333335]]
#
#    [[0.69411767 0.69411767 0.6784314 ]
#     [0.69411767 0.69411767 0.6784314 ]
#     [0.69411767 0.69411767 0.6784314 ]
#     ...
#     [0.7019608  0.7176471  0.7254902 ]
#     [0.7019608  0.7176471  0.73333335]
#     [0.7019608  0.7176471  0.73333335]]
#
#    [[0.69411767 0.69411767 0.6784314 ]
#     [0.69411767 0.69411767 0.6784314 ]
#     [0.69411767 0.69411767 0.6784314 ]
#     ...
#     [0.7019608  0.7176471  0.7254902 ]
#     [0.7019608  0.7176471  0.73333335]
#     [0.7019608  0.7176471  0.73333335]]
#
#    ...
#
#    [[0.33333337 0.35686278 0.36470592]
#     [0.3411765  0.35686278 0.37254906]
#     [0.3411765  0.35686278 0.37254906]
#     ...
#     [0.5058824  0.52156866 0.5372549 ]
#     [0.5058824  0.52156866 0.5372549 ]
#     [0.5058824  0.52156866 0.5372549 ]]
#
#    [[0.32549024 0.33333337 0.37254906]
#     [0.32549024 0.33333337 0.37254906]
#     [0.32549024 0.3411765  0.36470592]
#     ...
#     [0.49803925 0.5058824  0.5372549 ]
#     [0.49803925 0.5137255  0.5294118 ]
#     [0.49803925 0.5137255  0.5294118 ]]
#
#    [[0.3176471  0.32549024 0.36470592]
#     [0.3176471  0.32549024 0.36470592]
#     [0.32549024 0.33333337 0.36470592]
#     ...
#     [0.4901961  0.49803925 0.5294118 ]
#     [0.49803925 0.5137255  0.5294118 ]
#     [0.4901961  0.5058824  0.52156866]]]
#
#
#   [[[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6784314  0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6784314  0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    ...
#
#    [[0.2941177  0.30196083 0.3411765 ]
#     [0.2941177  0.30196083 0.3411765 ]
#     [0.2941177  0.30196083 0.33333337]
#     ...
#     [0.47450984 0.4901961  0.5058824 ]
#     [0.47450984 0.4901961  0.5058824 ]
#     [0.47450984 0.4901961  0.5058824 ]]
#
#    [[0.27843142 0.2941177  0.30980396]
#     [0.2941177  0.30196083 0.3411765 ]
#     [0.28627455 0.2941177  0.33333337]
#     ...
#     [0.45882356 0.4666667  0.5058824 ]
#     [0.45882356 0.4666667  0.5058824 ]
#     [0.45882356 0.47450984 0.4901961 ]]
#
#    [[0.27843142 0.2941177  0.30980396]
#     [0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.28627455 0.32549024]
#     ...
#     [0.45098042 0.45882356 0.49803925]
#     [0.45882356 0.4666667  0.5058824 ]
#     [0.45882356 0.47450984 0.4901961 ]]]
#
#
#   [[[0.6784314  0.6784314  0.6784314 ]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6784314  0.69411767]
#     [0.6627451  0.6784314  0.69411767]
#     [0.6784314  0.7019608  0.7019608 ]]
#
#    [[0.6784314  0.6784314  0.6784314 ]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6862745  0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.6784314  0.6784314  0.6627451 ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.69411767 0.6862745  0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.6862745  0.7019608 ]]
#
#    ...
#
#    [[0.2941177  0.30980396 0.34901965]
#     [0.2941177  0.30196083 0.3411765 ]
#     [0.2941177  0.30980396 0.34901965]
#     ...
#     [0.47450984 0.47450984 0.5058824 ]
#     [0.48235297 0.4901961  0.5294118 ]
#     [0.48235297 0.4901961  0.5294118 ]]
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.28627455 0.2941177  0.33333337]
#     [0.2941177  0.30196083 0.3411765 ]
#     ...
#     [0.47450984 0.47450984 0.5058824 ]
#     [0.4666667  0.4901961  0.4901961 ]
#     [0.45882356 0.4666667  0.5058824 ]]
#
#    [[0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.28627455 0.32549024]
#     ...
#     [0.45098042 0.45882356 0.49803925]
#     [0.45882356 0.4666667  0.48235297]
#     [0.45882356 0.4666667  0.5058824 ]]]
#
#
#   ...
#
#
#   [[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6627451  0.69411767 0.69411767]
#     [0.6862745  0.6862745  0.6862745 ]
#     [0.6862745  0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6862745  0.6862745  0.6862745 ]
#     [0.6862745  0.6862745  0.6862745 ]
#     [0.69411767 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.69411767 0.69411767 0.69411767]
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.2941177  0.30196083 0.3411765 ]
#     [0.30196083 0.30980396 0.34901965]
#     [0.30980396 0.32549024 0.34901965]
#     ...
#     [0.47450984 0.47450984 0.5058824 ]
#     [0.5058824  0.4901961  0.5294118 ]
#     [0.49803925 0.48235297 0.52156866]]
#
#    [[0.30980396 0.30196083 0.3176471 ]
#     [0.30196083 0.28627455 0.32549024]
#     [0.30980396 0.30196083 0.32549024]
#     ...
#     [0.47450984 0.47450984 0.4901961 ]
#     [0.48235297 0.47450984 0.4901961 ]
#     [0.48235297 0.47450984 0.4901961 ]]
#
#    [[0.254902   0.30980396 0.3176471 ]
#     [0.27843142 0.30196083 0.30980396]
#     [0.2941177  0.30196083 0.3176471 ]
#     ...
#     [0.45882356 0.45882356 0.47450984]
#     [0.47450984 0.4666667  0.48235297]
#     [0.45882356 0.47450984 0.4901961 ]]]
#
#
#   [[[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.69411767 0.69411767]
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.6627451  0.6862745  0.6862745 ]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6862745  0.6862745  0.6862745 ]
#     [0.6862745  0.6862745  0.6862745 ]
#     [0.69411767 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.2941177  0.30196083 0.3411765 ]
#     [0.30980396 0.3176471  0.34901965]
#     ...
#     [0.4666667  0.48235297 0.49803925]
#     [0.48235297 0.49803925 0.5137255 ]
#     [0.48235297 0.49803925 0.5137255 ]]
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.3176471  0.30980396 0.32549024]
#     [0.2941177  0.2941177  0.33333337]
#     ...
#     [0.45882356 0.48235297 0.4901961 ]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.4666667  0.47450984 0.5137255 ]]
#
#    [[0.27843142 0.28627455 0.32549024]
#     [0.30196083 0.28627455 0.32549024]
#     [0.28627455 0.28627455 0.32549024]
#     ...
#     [0.45098042 0.47450984 0.48235297]
#     [0.45098042 0.4666667  0.48235297]
#     [0.45098042 0.45882356 0.49803925]]]
#
#
#   [[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]]
#
#    [[0.6784314  0.6784314  0.6627451 ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.69411767 0.69411767 0.69411767]
#     [0.6862745  0.6862745  0.6862745 ]
#     [0.69411767 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.3176471  0.30196083 0.3411765 ]
#     [0.30196083 0.3176471  0.33333337]
#     [0.30980396 0.3176471  0.34901965]
#     ...
#     [0.4666667  0.47450984 0.5058824 ]
#     [0.48235297 0.4901961  0.5294118 ]
#     [0.48235297 0.4901961  0.5294118 ]]
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.28627455 0.30196083 0.3176471 ]
#     [0.27843142 0.30196083 0.33333337]
#     ...
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.48235297 0.47450984 0.4901961 ]]
#
#    [[0.30196083 0.2941177  0.33333337]
#     [0.27843142 0.28627455 0.32549024]
#     [0.27058828 0.28627455 0.3176471 ]
#     ...
#     [0.45098042 0.47450984 0.48235297]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.47450984 0.4666667  0.48235297]]]]
#
#
#
#  [[[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.6627451  0.6862745  0.6862745 ]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.6627451  0.6862745  0.6862745 ]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.28627455 0.30196083 0.3176471 ]
#     [0.30196083 0.3176471  0.33333337]
#     [0.30980396 0.32549024 0.3411765 ]
#     ...
#     [0.47450984 0.4901961  0.5058824 ]
#     [0.48235297 0.49803925 0.5137255 ]
#     [0.47450984 0.4901961  0.5058824 ]]
#
#    [[0.28627455 0.30196083 0.3176471 ]
#     [0.28627455 0.30196083 0.3176471 ]
#     [0.2941177  0.30196083 0.33333337]
#     ...
#     [0.4431373  0.47450984 0.5058824 ]
#     [0.4431373  0.47450984 0.4901961 ]
#     [0.4431373  0.47450984 0.4901961 ]]
#
#    [[0.27843142 0.2941177  0.30980396]
#     [0.28627455 0.30196083 0.3176471 ]
#     [0.28627455 0.2941177  0.32549024]
#     ...
#     [0.43529415 0.4666667  0.49803925]
#     [0.43529415 0.4666667  0.48235297]
#     [0.43529415 0.4666667  0.48235297]]]
#
#
#   [[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6627451  0.6862745  0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.67058825 0.6862745  0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    ...
#
#    [[0.2941177  0.30980396 0.32549024]
#     [0.30196083 0.3176471  0.33333337]
#     [0.30980396 0.32549024 0.3411765 ]
#     ...
#     [0.48235297 0.48235297 0.49803925]
#     [0.49803925 0.4901961  0.5058824 ]
#     [0.4901961  0.48235297 0.49803925]]
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.28627455 0.2941177  0.33333337]
#     [0.2941177  0.30196083 0.3411765 ]
#     ...
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.45882356 0.4666667  0.5058824 ]
#     [0.45882356 0.4666667  0.5058824 ]]
#
#    [[0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.28627455 0.32549024]
#     ...
#     [0.45098042 0.4666667  0.48235297]
#     [0.45098042 0.45882356 0.49803925]
#     [0.45098042 0.45882356 0.49803925]]]
#
#
#   [[[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6862745  0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.6784314  0.69411767 0.70980394]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6784314  0.69411767 0.69411767]
#     [0.6784314  0.67058825 0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.6784314  0.6784314  0.6784314 ]
#     [0.6784314  0.6784314  0.6784314 ]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6862745  0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.69411767 0.6862745  0.7019608 ]]
#
#    ...
#
#    [[0.30196083 0.3176471  0.33333337]
#     [0.30980396 0.3176471  0.35686278]
#     [0.30980396 0.32549024 0.34901965]
#     ...
#     [0.47450984 0.48235297 0.5137255 ]
#     [0.47450984 0.4901961  0.5058824 ]
#     [0.47450984 0.4901961  0.5058824 ]]
#
#    [[0.26274514 0.2941177  0.30980396]
#     [0.2941177  0.30980396 0.32549024]
#     [0.28627455 0.2941177  0.33333337]
#     ...
#     [0.4666667  0.47450984 0.4901961 ]
#     [0.45882356 0.4666667  0.5058824 ]
#     [0.45882356 0.47450984 0.5137255 ]]
#
#    [[0.27843142 0.2941177  0.30980396]
#     [0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.2941177  0.32549024]
#     ...
#     [0.45098042 0.4666667  0.48235297]
#     [0.43529415 0.45882356 0.49803925]
#     [0.43529415 0.45882356 0.49803925]]]
#
#
#   ...
#
#
#   [[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.6784314  0.6784314  0.6784314 ]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.3176471  0.30196083 0.3411765 ]
#     [0.3176471  0.30196083 0.3411765 ]
#     [0.3176471  0.30196083 0.3411765 ]
#     ...
#     [0.47450984 0.48235297 0.49803925]
#     [0.4901961  0.48235297 0.49803925]
#     [0.49803925 0.4901961  0.5058824 ]]
#
#    [[0.28627455 0.30196083 0.3176471 ]
#     [0.28627455 0.30196083 0.3176471 ]
#     [0.2941177  0.30196083 0.32549024]
#     ...
#     [0.4666667  0.47450984 0.5058824 ]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.4901961  0.48235297 0.49803925]]
#
#    [[0.27843142 0.2941177  0.30980396]
#     [0.27843142 0.2941177  0.30980396]
#     [0.28627455 0.30196083 0.3176471 ]
#     ...
#     [0.45098042 0.4666667  0.49803925]
#     [0.45098042 0.4666667  0.48235297]
#     [0.47450984 0.4666667  0.48235297]]]
#
#
#   [[[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.2941177  0.30980396 0.32549024]
#     [0.28627455 0.30196083 0.3176471 ]
#     [0.30196083 0.30980396 0.33333337]
#     ...
#     [0.4666667  0.48235297 0.49803925]
#     [0.48235297 0.49803925 0.5137255 ]
#     [0.47450984 0.4901961  0.5058824 ]]
#
#    [[0.30980396 0.2941177  0.33333337]
#     [0.30196083 0.2941177  0.30980396]
#     [0.30980396 0.30196083 0.32549024]
#     ...
#     [0.48235297 0.48235297 0.4901961 ]
#     [0.48235297 0.47450984 0.4901961 ]
#     [0.4666667  0.48235297 0.49803925]]
#
#    [[0.30980396 0.2941177  0.33333337]
#     [0.30196083 0.2941177  0.30980396]
#     [0.30980396 0.30196083 0.3176471 ]
#     ...
#     [0.47450984 0.47450984 0.48235297]
#     [0.48235297 0.47450984 0.4901961 ]
#     [0.45098042 0.4666667  0.48235297]]]
#
#
#   [[[0.654902   0.654902   0.654902  ]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.64705884 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.3176471  0.30980396 0.32549024]
#     [0.3176471  0.30980396 0.32549024]
#     [0.30980396 0.30980396 0.3411765 ]
#     ...
#     [0.47450984 0.48235297 0.49803925]
#     [0.4901961  0.48235297 0.49803925]
#     [0.4901961  0.48235297 0.49803925]]
#
#    [[0.30980396 0.30196083 0.33333337]
#     [0.30980396 0.30196083 0.3176471 ]
#     [0.3176471  0.30980396 0.33333337]
#     ...
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.49803925 0.4666667  0.4901961 ]]
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.30980396 0.2941177  0.3176471 ]
#     [0.30980396 0.30196083 0.32549024]
#     ...
#     [0.45098042 0.4666667  0.48235297]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.45882356 0.47450984 0.4901961 ]]]]
#
#
#
#  [[[[0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.6862745 ]
#     ...
#     [0.7019608  0.7254902  0.7254902 ]
#     [0.7019608  0.7254902  0.7254902 ]
#     [0.7019608  0.7254902  0.7254902 ]]
#
#    [[0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.6862745 ]
#     ...
#     [0.7019608  0.7254902  0.7254902 ]
#     [0.7019608  0.7254902  0.7254902 ]
#     [0.7019608  0.7254902  0.7254902 ]]
#
#    [[0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.6862745 ]
#     ...
#     [0.7019608  0.7254902  0.7254902 ]
#     [0.7019608  0.7254902  0.7254902 ]
#     [0.7019608  0.7254902  0.7254902 ]]
#
#    ...
#
#    [[0.33333337 0.3411765  0.3803922 ]
#     [0.33333337 0.3411765  0.3803922 ]
#     [0.33333337 0.3411765  0.37254906]
#     ...
#     [0.5137255  0.5294118  0.54509807]
#     [0.5137255  0.5294118  0.54509807]
#     [0.5137255  0.5294118  0.54509807]]
#
#    [[0.3176471  0.33333337 0.34901965]
#     [0.3176471  0.33333337 0.34901965]
#     [0.3176471  0.33333337 0.34901965]
#     ...
#     [0.49803925 0.5058824  0.54509807]
#     [0.49803925 0.5058824  0.54509807]
#     [0.49803925 0.5137255  0.5294118 ]]
#
#    [[0.3176471  0.33333337 0.34901965]
#     [0.3176471  0.33333337 0.34901965]
#     [0.3176471  0.33333337 0.34901965]
#     ...
#     [0.4901961  0.49803925 0.5372549 ]
#     [0.4901961  0.49803925 0.5372549 ]
#     [0.4901961  0.5058824  0.52156866]]]
#
#
#   [[[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.6627451  0.6862745  0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.67058825 0.6862745  0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    ...
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.28627455 0.2941177  0.33333337]
#     [0.30196083 0.30980396 0.34901965]
#     ...
#     [0.49803925 0.47450984 0.5137255 ]
#     [0.5058824  0.4901961  0.5294118 ]
#     [0.5058824  0.4901961  0.5294118 ]]
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.2941177  0.30196083 0.3411765 ]
#     [0.28627455 0.2941177  0.33333337]
#     ...
#     [0.4666667  0.47450984 0.4901961 ]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.45882356 0.47450984 0.4901961 ]]
#
#    [[0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.28627455 0.32549024]
#     [0.28627455 0.2941177  0.33333337]
#     ...
#     [0.45882356 0.4666667  0.48235297]
#     [0.45098042 0.4666667  0.48235297]
#     [0.45098042 0.4666667  0.48235297]]]
#
#
#   [[[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.6627451  0.6862745  0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    [[0.6784314  0.6784314  0.6784314 ]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    ...
#
#    [[0.2941177  0.30196083 0.3411765 ]
#     [0.2941177  0.30196083 0.3411765 ]
#     [0.2941177  0.30196083 0.3411765 ]
#     ...
#     [0.48235297 0.47450984 0.5137255 ]
#     [0.49803925 0.48235297 0.52156866]
#     [0.4901961  0.47450984 0.5137255 ]]
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.27843142 0.28627455 0.32549024]
#     [0.2941177  0.30196083 0.33333337]
#     ...
#     [0.48235297 0.45882356 0.5058824 ]
#     [0.4666667  0.47450984 0.5137255 ]
#     [0.48235297 0.4666667  0.5058824 ]]
#
#    [[0.27843142 0.28627455 0.32549024]
#     [0.27058828 0.27843142 0.3176471 ]
#     [0.28627455 0.2941177  0.33333337]
#     ...
#     [0.47450984 0.45882356 0.4901961 ]
#     [0.47450984 0.45882356 0.49803925]
#     [0.47450984 0.45882356 0.49803925]]]
#
#
#   ...
#
#
#   [[[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6784314  0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6784314  0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6784314  0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.30980396 0.3176471  0.35686278]
#     [0.28627455 0.2941177  0.33333337]
#     [0.30196083 0.32549024 0.34901965]
#     ...
#     [0.48235297 0.4901961  0.49803925]
#     [0.4901961  0.4901961  0.4901961 ]
#     [0.48235297 0.47450984 0.4901961 ]]
#
#    [[0.27843142 0.30196083 0.33333337]
#     [0.28627455 0.30196083 0.3176471 ]
#     [0.28627455 0.30196083 0.3176471 ]
#     ...
#     [0.4666667  0.4666667  0.48235297]
#     [0.48235297 0.4666667  0.5058824 ]
#     [0.45882356 0.4666667  0.5058824 ]]
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.27843142 0.2941177  0.30980396]
#     [0.27843142 0.2941177  0.30980396]
#     ...
#     [0.45882356 0.4666667  0.48235297]
#     [0.47450984 0.45882356 0.49803925]
#     [0.45098042 0.45882356 0.49803925]]]
#
#
#   [[[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.69411767 0.69411767]
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6862745  0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.30196083 0.3176471  0.35686278]
#     [0.2941177  0.30196083 0.3411765 ]
#     [0.30196083 0.32549024 0.34901965]
#     ...
#     [0.4666667  0.48235297 0.49803925]
#     [0.47450984 0.4901961  0.5137255 ]
#     [0.4666667  0.47450984 0.5137255 ]]
#
#    [[0.2941177  0.30196083 0.3176471 ]
#     [0.2941177  0.30196083 0.33333337]
#     [0.27843142 0.30196083 0.32549024]
#     ...
#     [0.4901961  0.47450984 0.5137255 ]
#     [0.47450984 0.4666667  0.48235297]
#     [0.45882356 0.4666667  0.5058824 ]]
#
#    [[0.27843142 0.2941177  0.30980396]
#     [0.27843142 0.28627455 0.32549024]
#     [0.27058828 0.2941177  0.3176471 ]
#     ...
#     [0.47450984 0.45882356 0.49803925]
#     [0.47450984 0.4666667  0.48235297]
#     [0.45098042 0.45882356 0.49803925]]]
#
#
#   [[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.3176471  0.32549024 0.36470592]
#     [0.30196083 0.3176471  0.33333337]
#     [0.30196083 0.33333337 0.3411765 ]
#     ...
#     [0.4666667  0.48235297 0.49803925]
#     [0.4666667  0.48235297 0.49803925]
#     [0.47450984 0.4901961  0.5058824 ]]
#
#    [[0.27843142 0.30980396 0.32549024]
#     [0.28627455 0.30196083 0.3176471 ]
#     [0.27843142 0.30196083 0.3176471 ]
#     ...
#     [0.4666667  0.4666667  0.4901961 ]
#     [0.45882356 0.4666667  0.5058824 ]
#     [0.45882356 0.47450984 0.4901961 ]]
#
#    [[0.28627455 0.30196083 0.3176471 ]
#     [0.27843142 0.2941177  0.30980396]
#     [0.27843142 0.30196083 0.3176471 ]
#     ...
#     [0.45098042 0.4666667  0.4901961 ]
#     [0.45098042 0.45882356 0.49803925]
#     [0.45098042 0.4666667  0.48235297]]]]]

# %%
#load y_labels_segments_30.npy
y = np.load('y_labels_segments_30.npy')

# %%
# labels
print("Labels (y) shape:", y.shape)
# Out:
# Labels (y) shape: (1351,)

# %%
print(y)
# Out:
# [1 1 1 ... 0 0 0]

# %%
SEED = 42
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Split data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=0.3,
    stratify=y,      # ensures class balance in splits
    random_state=SEED
)

# %%
print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
print("y_train shape:", y_train.shape)
print("y_val shape:", y_val.shape)
# Out:
# X_train shape: (945, 30, 224, 224, 3)
# X_val shape: (406, 30, 224, 224, 3)
# y_train shape: (945,)
# y_val shape: (406,)

# %%
# ONE-HOT ENCODING
# Since model output is 2 neurons + sigmoid(for binary), labels must be one-hot encoded
num_classes = 2
y_train_oh = to_categorical(y_train, num_classes=num_classes)
y_val_oh   = to_categorical(y_val, num_classes=num_classes)

print("y_train one-hot shape:", y_train_oh.shape)
print("y_val one-hot shape:", y_val_oh.shape)
# Out:
# y_train one-hot shape: (945, 2)
# y_val one-hot shape: (406, 2)

# %%
# FEATURE EXTRACTION USING InceptionV3
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.models import Model

base_model = InceptionV3(
    weights="imagenet",
    include_top=False,
    input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3)
)

# %%
# FEATURE EXTRACTION USING InceptionV3
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.models import Model

base_model = InceptionV3(
    weights="imagenet",
    include_top=False,
    input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3)
)

# Apply global average pooling to reduce feature maps to a vector
global_avg_layer = GlobalAveragePooling2D()
feature_extractor = Model(inputs=base_model.input, outputs=global_avg_layer(base_model.output))

# %%
# GRU-BASED MODEL DEFINITION
from tensorflow.keras.layers import Input, GRU, TimeDistributed, Dropout, Dense

# Define input layer for video sequences (NUM_FRAMES, HEIGHT, WIDTH, 3)
input_layer = Input(shape=(NUM_FRAMES, IMAGE_HEIGHT, IMAGE_WIDTH, 3))

# Extract frame-wise features using CNN (InceptionV3) applied to each frame
inception = TimeDistributed(feature_extractor)(input_layer)

# First GRU layer with 1024 units, returning sequences
gru_1 = GRU(1024, return_sequences=True)(inception)
dropout_1 = Dropout(0.5)(gru_1)

# Second GRU layer with 512 units
gru_2 = GRU(512)(dropout_1)
dropout_2 = Dropout(0.5)(gru_2)

# SINGLE DENSE LAYER (512 UNITS)-Fully connected dense layer
dense_1 = Dense(512, activation="relu")(dropout_2)
dropout_3 = Dropout(0.5)(dense_1)

# Output layer for binary classification-one-hot  (2 neurons + sigmoid)
output_layer = Dense(num_classes, activation="sigmoid")(dropout_3)

# Define/Build the model
model = Model(inputs=input_layer, outputs=output_layer)

# %%
# COMPILE MODEL
optimizer = Nadam(learning_rate=1e-4) #try1e-5
model.compile(
    loss="categorical_crossentropy",
    optimizer=optimizer,
    metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 30, 224, 224,   │             0 │
# │                                 │ 3)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 30, 2048)       │    21,802,784 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 30, 1024)       │     9,443,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 30, 1024)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 512)            │     2,362,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │         1,026 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,872,162 (129.21 MB)
#  Trainable params: 33,837,730 (129.08 MB)
#  Non-trainable params: 34,432 (134.50 KB)

# %%
# EARLY STOPPING
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor="val_loss",    # Monitor validation loss
    patience=5,            # Stop if no improvement after 5 epochs
    restore_best_weights=True  # Restore best model weights
)

# %%
# CALCULATE CLASS WEIGHTS
from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
w0 = class_weights[0]
w1 = class_weights[1]

# %%
# MODEL TRAINING
history = model.fit(
    X_train,
    y_train_oh,           # Use one-hot labels here
    epochs= 5, #10, #5#10, #10 #5, #10,
    batch_size=5,
    class_weight={0: w0, 1: w1},
    callbacks=[early_stopping],
    validation_data=(X_val, y_val_oh)  # Validation labels also one-hot
)
# Out:
# Epoch 1/5
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 984s 2s/step - accuracy: 0.6025 - loss: 0.7160 - val_accuracy: 0.7340 - val_loss: 0.5838
# Epoch 2/5
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.7620 - loss: 0.5340 - val_accuracy: 0.8276 - val_loss: 0.4445
# Epoch 3/5
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.8325 - loss: 0.4245 - val_accuracy: 0.8916 - val_loss: 0.2612
# Epoch 4/5
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.9103 - loss: 0.2512 - val_accuracy: 0.8645 - val_loss: 0.4321
# Epoch 5/5
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.9096 - loss: 0.2403 - val_accuracy: 0.8941 - val_loss: 0.2369

# %%
# MODEL EVALUATION
loss, accuracy = model.evaluate(X_val, y_val_oh)
print(f"Validation Loss: {loss:.4f}")
print(f"Validation Accuracy: {accuracy:.4f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 566ms/step - accuracy: 0.8830 - loss: 0.2531
# Validation Loss: 0.2375
# Validation Accuracy: 0.8941

# %%
# CONFUSION MATRIX
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# Predict probabilities
y_pred_prob = model.predict(X_val)

# Convert softmax probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)
y_true = np.argmax(y_val_oh, axis=1)

cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:\n", cm)
print("Classification Report:\n", classification_report(y_true, y_pred))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 151s 6s/step
# Confusion Matrix:
#  [[172  31]
#  [ 12 191]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89       203
#            1       0.86      0.94      0.90       203
#
#     accuracy                           0.89       406
#    macro avg       0.90      0.89      0.89       406
# weighted avg       0.90      0.89      0.89       406

# %%
# Plot confusion matrix
import matplotlib.pyplot as plt
plt.figure()
plt.imshow(cm, interpolation='nearest', cmap='Blues')
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted label')
plt.ylabel('True label')
ticks = np.arange(2)
plt.xticks(ticks, ['Negative','Positive'])
plt.yticks(ticks, ['Negative','Positive'])
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, cm[i, j], ha='center', va='center')
plt.tight_layout()
plt.savefig(f"confusion_matrix_segments_30.png") #save figure
plt.show()

# %%
# ACCURACY VS VALIDATION ACCURACY
accuracy     = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs       = range(1, len(accuracy) + 1)

plt.figure()
plt.plot(epochs, accuracy, label='Training Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
plt.title('Accuracy vs. Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.savefig(f"accuracy_plot_segments_30.png") ##save figure
plt.show()

# %%
# LOSS VS VALIDATION LOSS
loss      = history.history['loss']
val_loss  = history.history['val_loss']

plt.figure()
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Loss vs. Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig(f"loss_plot_segments_30.png") ##save figure
plt.show()

# %%
# ROC CURVE
from sklearn.metrics import roc_curve, auc

# Compute ROC curve for positive class
fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob[:,1])
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], linestyle='--', label='Chance level')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.tight_layout()
plt.savefig(f"roc_curve_segments_30.png") ##save figure
plt.show()

# %%
# PRECISION-RECALL CURVE
from sklearn.metrics import precision_recall_curve

precision, recall, _ = precision_recall_curve(y_true, y_pred_prob[:,1])

plt.figure()
plt.plot(recall, precision, label='Precision-Recall curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision vs. Recall')
plt.legend()
plt.tight_layout()
plt.savefig(f"precision_recall_curve_segments_30.png") ##save figure
plt.show()

# %%
# SAVE MODEL & WEIGHTS
model.save("InceptionV3_model_30.keras")
model.save("InceptionV3_model_30.h5")
print("Model saved successfully!")
model.save_weights("InceptionV3_30.weights.h5")
print("Model weights saved!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!
# Model weights saved!

# %%
# EXPERIMENT RESULTS TABLE FOR CURRENT SEGMENT CONFIGURATION
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Calculate evaluation metrics
precision_val = precision_score(y_true, y_pred)
recall_val = recall_score(y_true, y_pred)
f1_val = f1_score(y_true, y_pred)
accuracy_val = accuracy_score(y_true, y_pred)

# Create results table
results_table = pd.DataFrame({
    "Segments": [NUM_FRAMES],
    "Accuracy": [accuracy_val],
    #"Validation Accuracy": [accuracy],
    #"Validation Loss": [loss],
    "Precision": [precision_val],
    "Recall": [recall_val],
    "F1 Score": [f1_val],
    "ROC AUC": [roc_auc]
})

# Display table
print(f"\nExperiment Results Table: {NUM_FRAMES} Segments")
display(results_table)
# Out:
# Experiment Results Table: 30 Segments
#    Segments  Accuracy  Precision    Recall  F1 Score   ROC AUC
# 0        30  0.894089    0.86036  0.940887  0.898824  0.973307

# %%
import psutil

ram = psutil.virtual_memory()
print(f"Total RAM: {ram.total / (1024**3):.2f} GB")
print(f"Available RAM: {ram.available / (1024**3):.2f} GB")
# Out:
# Total RAM: 172.95 GB
# Available RAM: 169.83 GB

# %%
# install requirements for v6 Tpu
# !pip install opencv-python
# !pip install tensorflow
# !pip install openpyxl
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Downloading opencv_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl (72.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 56.3 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: keras>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.46.3-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl (572.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 MB 5.8 MB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 6.2 MB/s eta 0:00:00
# Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 139.3 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 170.2 MB/s eta 0:00:00
# Downloading wheel-0.46.3-py3-none-any.whl (30 kB)
# Installing collected packages: libclang, flatbuffers, wheel, h5py, google_pasta, astunparse, tensorflow
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.16.0
#     Uninstalling h5py-3.16.0:
#       Successfully uninstalled h5py-3.16.0
# Successfully installed astunparse-1.6.3 flatbuffers-25.12.19 google_pasta-0.2.0 h5py-3.14.0 libclang-18.1.1 tensorflow-2.21.0 wheel-0.46.3
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 10.7 MB/s eta 0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import zipfile
import os
import cv2
import numpy as np
import pandas as pd
import random
import tensorflow as tf
from skimage.metrics import structural_similarity as ssim
from tensorflow.keras.applications import Xception
from tensorflow.keras.layers import Dense, Dropout, TimeDistributed, GlobalAveragePooling2D, GRU, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Nadam
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_recall_curve, f1_score
# Out:
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:86: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(

# %%
# GLOBAL CONSTANTS
NUM_FRAMES = 40
#MIN_FRAMES = 120
#max_frames = 120
IMAGE_HEIGHT, IMAGE_WIDTH = 224, 224
#SSIM_THRESHOLD = 0.80
# NUM_SHUFFLES = 6 #2 #6
SEED = 42

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

import numpy as np

# Load X_prep_segments_40.npy from Drive #features
X = np.load('/content/drive/My Drive/Colab Notebooks_videoAnalytics/optimal_seg/X_prep_segments_40.npy')

# Print shape of X
print("Shape of X_prep:", X.shape)

# Load y_labels_segments_40.npy from Drive
y = np.load('/content/drive/My Drive/Colab Notebooks_videoAnalytics/optimal_seg/y_labels_segments_40.npy')

# Print shape of y
print("Shape of y_labels:", y.shape)
# Out:
# Mounted at /content/drive
# Shape of X_prep: (1351, 40, 224, 224, 3)
# Shape of y_labels: (1351,)

# %%
print(X)
# Out:
# [[[[[0.33333337 0.33333337 0.33333337]
#     [0.3411765  0.3411765  0.3411765 ]
#     [0.33333337 0.33333337 0.33333337]
#     ...
#     [0.38823533 0.36470592 0.38823533]
#     [0.35686278 0.37254906 0.38823533]
#     [0.35686278 0.37254906 0.38823533]]
#
#    [[0.3411765  0.3411765  0.3411765 ]
#     [0.3411765  0.3411765  0.3411765 ]
#     [0.34901965 0.34901965 0.34901965]
#     ...
#     [0.38823533 0.38823533 0.4039216 ]
#     [0.3803922  0.39607847 0.4039216 ]
#     [0.35686278 0.37254906 0.38823533]]
#
#    [[0.33333337 0.32549024 0.3411765 ]
#     [0.3411765  0.33333337 0.34901965]
#     [0.3411765  0.33333337 0.34901965]
#     ...
#     [0.37254906 0.39607847 0.39607847]
#     [0.37254906 0.39607847 0.39607847]
#     [0.36470592 0.38823533 0.38823533]]
#
#    ...
#
#    [[0.1686275  0.13725495 0.15294123]
#     [0.16078436 0.12941182 0.15294123]
#     [0.1686275  0.12941182 0.15294123]
#     ...
#     [0.2313726  0.24705887 0.28627455]
#     [0.23921573 0.24705887 0.28627455]
#     [0.22352946 0.2313726  0.27058828]]
#
#    [[0.13725495 0.12156868 0.16078436]
#     [0.14509809 0.10588241 0.15294123]
#     [0.16078436 0.12156868 0.16078436]
#     ...
#     [0.20000005 0.2313726  0.27058828]
#     [0.22352946 0.24705887 0.28627455]
#     [0.27843142 0.28627455 0.3176471 ]]
#
#    [[0.13725495 0.12156868 0.16078436]
#     [0.14509809 0.10588241 0.15294123]
#     [0.14509809 0.11372554 0.14509809]
#     ...
#     [0.20784318 0.23921573 0.27843142]
#     [0.21568632 0.23921573 0.27843142]
#     [0.23921573 0.24705887 0.28627455]]]
#
#
#   [[[0.30980396 0.34901965 0.33333337]
#     [0.32549024 0.35686278 0.33333337]
#     [0.32549024 0.34901965 0.33333337]
#     ...
#     [0.41176474 0.39607847 0.41176474]
#     [0.39607847 0.37254906 0.3803922 ]
#     [0.3803922  0.4039216  0.4039216 ]]
#
#    [[0.36470592 0.3411765  0.33333337]
#     [0.35686278 0.35686278 0.3411765 ]
#     [0.34901965 0.34901965 0.33333337]
#     ...
#     [0.4039216  0.38823533 0.4039216 ]
#     [0.41960788 0.39607847 0.4039216 ]
#     [0.41176474 0.38823533 0.39607847]]
#
#    [[0.36470592 0.3411765  0.34901965]
#     [0.37254906 0.3411765  0.35686278]
#     [0.36470592 0.3411765  0.34901965]
#     ...
#     [0.41176474 0.39607847 0.4039216 ]
#     [0.41176474 0.38823533 0.4039216 ]
#     [0.3803922  0.37254906 0.38823533]]
#
#    ...
#
#    [[0.14509809 0.1686275  0.1686275 ]
#     [0.13725495 0.16078436 0.16078436]
#     [0.13725495 0.16078436 0.17647064]
#     ...
#     [0.27058828 0.254902   0.30196083]
#     [0.26274514 0.22352946 0.27058828]
#     [0.26274514 0.254902   0.2941177 ]]
#
#    [[0.1686275  0.13725495 0.16078436]
#     [0.1686275  0.13725495 0.16078436]
#     [0.13725495 0.12941182 0.15294123]
#     ...
#     [0.26274514 0.24705887 0.3176471 ]
#     [0.26274514 0.2313726  0.30980396]
#     [0.254902   0.24705887 0.32549024]]
#
#    [[0.14509809 0.11372554 0.13725495]
#     [0.15294123 0.10588241 0.12941182]
#     [0.17647064 0.12156868 0.14509809]
#     ...
#     [0.23921573 0.2313726  0.30196083]
#     [0.23921573 0.2313726  0.30980396]
#     [0.23921573 0.2313726  0.30980396]]]
#
#
#   [[[0.4039216  0.34901965 0.32549024]
#     [0.4039216  0.34901965 0.32549024]
#     [0.4039216  0.3411765  0.3176471 ]
#     ...
#     [0.41176474 0.4039216  0.41176474]
#     [0.41960788 0.39607847 0.4039216 ]
#     [0.4039216  0.4039216  0.4039216 ]]
#
#    [[0.38823533 0.35686278 0.32549024]
#     [0.38823533 0.35686278 0.32549024]
#     [0.3803922  0.35686278 0.32549024]
#     ...
#     [0.41176474 0.4039216  0.4039216 ]
#     [0.41960788 0.39607847 0.4039216 ]
#     [0.4039216  0.4039216  0.4039216 ]]
#
#    [[0.37254906 0.34901965 0.3411765 ]
#     [0.37254906 0.34901965 0.3411765 ]
#     [0.37254906 0.34901965 0.3411765 ]
#     ...
#     [0.41176474 0.39607847 0.41176474]
#     [0.41960788 0.38823533 0.41176474]
#     [0.4039216  0.39607847 0.41176474]]
#
#    ...
#
#    [[0.1686275  0.13725495 0.16078436]
#     [0.1686275  0.13725495 0.16078436]
#     [0.16078436 0.13725495 0.16078436]
#     ...
#     [0.27843142 0.26274514 0.30196083]
#     [0.27843142 0.26274514 0.30196083]
#     [0.27843142 0.26274514 0.30196083]]
#
#    [[0.1686275  0.14509809 0.15294123]
#     [0.15294123 0.14509809 0.16078436]
#     [0.13725495 0.13725495 0.15294123]
#     ...
#     [0.24705887 0.254902   0.2941177 ]
#     [0.26274514 0.27058828 0.30980396]
#     [0.254902   0.26274514 0.30196083]]
#
#    [[0.1686275  0.14509809 0.15294123]
#     [0.13725495 0.12941182 0.14509809]
#     [0.12941182 0.13725495 0.15294123]
#     ...
#     [0.22352946 0.24705887 0.28627455]
#     [0.24705887 0.27058828 0.30980396]
#     [0.254902   0.26274514 0.30196083]]]
#
#
#   ...
#
#
#   [[[0.427451   0.37254906 0.34901965]
#     [0.43529415 0.3803922  0.35686278]
#     [0.43529415 0.3803922  0.35686278]
#     ...
#     [0.4431373  0.4039216  0.41960788]
#     [0.45882356 0.41960788 0.427451  ]
#     [0.4431373  0.41960788 0.427451  ]]
#
#    [[0.41960788 0.36470592 0.3411765 ]
#     [0.427451   0.37254906 0.34901965]
#     [0.427451   0.37254906 0.34901965]
#     ...
#     [0.45098042 0.41176474 0.427451  ]
#     [0.45882356 0.41960788 0.427451  ]
#     [0.4431373  0.41960788 0.427451  ]]
#
#    [[0.427451   0.36470592 0.34901965]
#     [0.427451   0.37254906 0.34901965]
#     [0.427451   0.37254906 0.34901965]
#     ...
#     [0.45882356 0.427451   0.43529415]
#     [0.4666667  0.427451   0.427451  ]
#     [0.45098042 0.41960788 0.427451  ]]
#
#    ...
#
#    [[0.14509809 0.14509809 0.20000005]
#     [0.14509809 0.14509809 0.20000005]
#     [0.13725495 0.14509809 0.20784318]
#     ...
#     [0.24705887 0.27843142 0.34901965]
#     [0.2313726  0.26274514 0.33333337]
#     [0.24705887 0.27843142 0.34901965]]
#
#    [[0.14509809 0.14509809 0.20000005]
#     [0.14509809 0.13725495 0.21568632]
#     [0.13725495 0.13725495 0.20784318]
#     ...
#     [0.23921573 0.27058828 0.33333337]
#     [0.23921573 0.27058828 0.3411765 ]
#     [0.23921573 0.27058828 0.3411765 ]]
#
#    [[0.14509809 0.14509809 0.20000005]
#     [0.12156868 0.11372554 0.19215691]
#     [0.12941182 0.13725495 0.20784318]
#     ...
#     [0.2313726  0.26274514 0.33333337]
#     [0.2313726  0.26274514 0.33333337]
#     [0.23921573 0.27058828 0.3411765 ]]]
#
#
#   [[[0.427451   0.37254906 0.34901965]
#     [0.43529415 0.3803922  0.35686278]
#     [0.427451   0.36470592 0.3411765 ]
#     ...
#     [0.4431373  0.41176474 0.427451  ]
#     [0.43529415 0.4039216  0.427451  ]
#     [0.4431373  0.41960788 0.427451  ]]
#
#    [[0.41960788 0.36470592 0.3411765 ]
#     [0.427451   0.37254906 0.34901965]
#     [0.427451   0.36470592 0.3411765 ]
#     ...
#     [0.4431373  0.41960788 0.43529415]
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41960788 0.427451  ]]
#
#    [[0.43529415 0.36470592 0.34901965]
#     [0.4431373  0.37254906 0.34901965]
#     [0.4431373  0.3803922  0.35686278]
#     ...
#     [0.4431373  0.41960788 0.43529415]
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41960788 0.427451  ]]
#
#    ...
#
#    [[0.15294123 0.15294123 0.20784318]
#     [0.14509809 0.14509809 0.20000005]
#     [0.14509809 0.14509809 0.20784318]
#     ...
#     [0.23921573 0.27058828 0.3411765 ]
#     [0.24705887 0.27843142 0.3411765 ]
#     [0.24705887 0.27843142 0.34901965]]
#
#    [[0.1686275  0.14509809 0.20000005]
#     [0.15294123 0.12156868 0.20000005]
#     [0.13725495 0.12156868 0.19215691]
#     ...
#     [0.2313726  0.254902   0.3411765 ]
#     [0.2313726  0.254902   0.3411765 ]
#     [0.22352946 0.26274514 0.34901965]]
#
#    [[0.1686275  0.14509809 0.20000005]
#     [0.15294123 0.12156868 0.20000005]
#     [0.13725495 0.12156868 0.18431377]
#     ...
#     [0.2313726  0.24705887 0.3411765 ]
#     [0.20000005 0.22352946 0.32549024]
#     [0.22352946 0.24705887 0.33333337]]]
#
#
#   [[[0.427451   0.37254906 0.34901965]
#     [0.4039216  0.36470592 0.35686278]
#     [0.427451   0.36470592 0.35686278]
#     ...
#     [0.45098042 0.41960788 0.43529415]
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41176474 0.43529415]]
#
#    [[0.4431373  0.36470592 0.3803922 ]
#     [0.4431373  0.36470592 0.36470592]
#     [0.4431373  0.37254906 0.35686278]
#     ...
#     [0.45882356 0.41960788 0.43529415]
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41176474 0.43529415]]
#
#    [[0.4431373  0.3803922  0.3803922 ]
#     [0.4431373  0.36470592 0.36470592]
#     [0.4431373  0.37254906 0.35686278]
#     ...
#     [0.45882356 0.41960788 0.43529415]
#     [0.4431373  0.41176474 0.43529415]
#     [0.4431373  0.41176474 0.43529415]]
#
#    ...
#
#    [[0.1686275  0.14509809 0.20000005]
#     [0.15294123 0.15294123 0.20784318]
#     [0.14509809 0.14509809 0.20000005]
#     ...
#     [0.2313726  0.26274514 0.33333337]
#     [0.2313726  0.26274514 0.33333337]
#     [0.24705887 0.27843142 0.34901965]]
#
#    [[0.15294123 0.15294123 0.20784318]
#     [0.12941182 0.12156868 0.20000005]
#     [0.14509809 0.13725495 0.20784318]
#     ...
#     [0.22352946 0.254902   0.33333337]
#     [0.2313726  0.26274514 0.33333337]
#     [0.2313726  0.27058828 0.35686278]]
#
#    [[0.14509809 0.14509809 0.20000005]
#     [0.12941182 0.12156868 0.20000005]
#     [0.12156868 0.12156868 0.18431377]
#     ...
#     [0.2313726  0.254902   0.3411765 ]
#     [0.2313726  0.26274514 0.33333337]
#     [0.22352946 0.26274514 0.34901965]]]]
#
#
#
#  [[[[0.38823533 0.34901965 0.35686278]
#     [0.3803922  0.3411765  0.34901965]
#     [0.37254906 0.3411765  0.34901965]
#     ...
#     [0.41176474 0.41176474 0.41176474]
#     [0.39607847 0.39607847 0.39607847]
#     [0.41176474 0.41176474 0.41176474]]
#
#    [[0.3803922  0.3411765  0.34901965]
#     [0.3803922  0.3411765  0.34901965]
#     [0.3803922  0.34901965 0.35686278]
#     ...
#     [0.41176474 0.41176474 0.41176474]
#     [0.41960788 0.41960788 0.41960788]
#     [0.41176474 0.41176474 0.41176474]]
#
#    [[0.37254906 0.34901965 0.35686278]
#     [0.3803922  0.35686278 0.36470592]
#     [0.37254906 0.34901965 0.35686278]
#     ...
#     [0.41176474 0.41176474 0.41176474]
#     [0.41176474 0.41176474 0.41176474]
#     [0.41176474 0.41176474 0.41176474]]
#
#    ...
#
#    [[0.18431377 0.15294123 0.17647064]
#     [0.1686275  0.16078436 0.17647064]
#     [0.17647064 0.15294123 0.18431377]
#     ...
#     [0.2313726  0.26274514 0.30980396]
#     [0.24705887 0.26274514 0.3176471 ]
#     [0.24705887 0.26274514 0.3176471 ]]
#
#    [[0.14509809 0.12941182 0.1686275 ]
#     [0.16078436 0.12156868 0.1686275 ]
#     [0.16078436 0.12156868 0.17647064]
#     ...
#     [0.21568632 0.254902   0.2941177 ]
#     [0.2313726  0.27843142 0.30980396]
#     [0.26274514 0.26274514 0.3176471 ]]
#
#    [[0.14509809 0.12941182 0.1686275 ]
#     [0.16078436 0.12156868 0.1686275 ]
#     [0.1686275  0.12156868 0.1686275 ]
#     ...
#     [0.22352946 0.26274514 0.30196083]
#     [0.2313726  0.27843142 0.30980396]
#     [0.26274514 0.26274514 0.3176471 ]]]
#
#
#   [[[0.39607847 0.34901965 0.37254906]
#     [0.37254906 0.32549024 0.34901965]
#     [0.3803922  0.33333337 0.34901965]
#     ...
#     [0.41176474 0.41176474 0.41176474]
#     [0.39607847 0.38823533 0.4039216 ]
#     [0.41176474 0.4039216  0.41960788]]
#
#    [[0.37254906 0.3411765  0.36470592]
#     [0.37254906 0.3411765  0.36470592]
#     [0.37254906 0.3411765  0.35686278]
#     ...
#     [0.41176474 0.4039216  0.41176474]
#     [0.4039216  0.4039216  0.41960788]
#     [0.41960788 0.4039216  0.427451  ]]
#
#    [[0.35686278 0.32549024 0.34901965]
#     [0.36470592 0.3411765  0.35686278]
#     [0.3803922  0.35686278 0.37254906]
#     ...
#     [0.41960788 0.41176474 0.41960788]
#     [0.4039216  0.39607847 0.41176474]
#     [0.4039216  0.39607847 0.41176474]]
#
#    ...
#
#    [[0.14509809 0.13725495 0.1686275 ]
#     [0.14509809 0.15294123 0.19215691]
#     [0.14509809 0.15294123 0.19215691]
#     ...
#     [0.24705887 0.24705887 0.30980396]
#     [0.2941177  0.27058828 0.32549024]
#     [0.24705887 0.254902   0.30980396]]
#
#    [[0.12941182 0.13725495 0.17647064]
#     [0.12941182 0.13725495 0.17647064]
#     [0.16078436 0.14509809 0.19215691]
#     ...
#     [0.2313726  0.23921573 0.2941177 ]
#     [0.254902   0.254902   0.30980396]
#     [0.254902   0.254902   0.30980396]]
#
#    [[0.12156868 0.12941182 0.1686275 ]
#     [0.12941182 0.13725495 0.17647064]
#     [0.1686275  0.1686275  0.19215691]
#     ...
#     [0.22352946 0.2313726  0.28627455]
#     [0.23921573 0.23921573 0.2941177 ]
#     [0.23921573 0.23921573 0.2941177 ]]]
#
#
#   [[[0.37254906 0.34901965 0.35686278]
#     [0.37254906 0.34901965 0.35686278]
#     [0.37254906 0.34901965 0.34901965]
#     ...
#     [0.41960788 0.4039216  0.41176474]
#     [0.41176474 0.41176474 0.41176474]
#     [0.41176474 0.41176474 0.41176474]]
#
#    [[0.3803922  0.35686278 0.36470592]
#     [0.3803922  0.35686278 0.36470592]
#     [0.37254906 0.35686278 0.34901965]
#     ...
#     [0.41960788 0.4039216  0.41176474]
#     [0.41176474 0.41176474 0.41176474]
#     [0.41176474 0.41176474 0.41176474]]
#
#    [[0.37254906 0.34901965 0.35686278]
#     [0.37254906 0.34901965 0.35686278]
#     [0.3803922  0.35686278 0.35686278]
#     ...
#     [0.427451   0.41176474 0.41960788]
#     [0.41960788 0.41960788 0.41960788]
#     [0.41960788 0.41960788 0.41960788]]
#
#    ...
#
#    [[0.15294123 0.13725495 0.17647064]
#     [0.15294123 0.16078436 0.20000005]
#     [0.13725495 0.14509809 0.18431377]
#     ...
#     [0.24705887 0.26274514 0.3176471 ]
#     [0.24705887 0.26274514 0.3176471 ]
#     [0.24705887 0.26274514 0.3176471 ]]
#
#    [[0.15294123 0.14509809 0.16078436]
#     [0.15294123 0.14509809 0.16078436]
#     [0.15294123 0.13725495 0.1686275 ]
#     ...
#     [0.23921573 0.254902   0.30196083]
#     [0.22352946 0.27058828 0.30196083]
#     [0.23921573 0.254902   0.30980396]]
#
#    [[0.14509809 0.13725495 0.15294123]
#     [0.15294123 0.14509809 0.16078436]
#     [0.16078436 0.14509809 0.19215691]
#     ...
#     [0.2313726  0.24705887 0.2941177 ]
#     [0.20784318 0.254902   0.28627455]
#     [0.22352946 0.23921573 0.2941177 ]]]
#
#
#   ...
#
#
#   [[[0.35686278 0.3803922  0.36470592]
#     [0.36470592 0.36470592 0.34901965]
#     [0.37254906 0.36470592 0.35686278]
#     ...
#     [0.41960788 0.39607847 0.41960788]
#     [0.38823533 0.4039216  0.41960788]
#     [0.41176474 0.4039216  0.41960788]]
#
#    [[0.35686278 0.35686278 0.3411765 ]
#     [0.34901965 0.34901965 0.33333337]
#     [0.37254906 0.35686278 0.35686278]
#     ...
#     [0.41960788 0.39607847 0.41960788]
#     [0.3803922  0.39607847 0.41176474]
#     [0.41176474 0.4039216  0.41960788]]
#
#    [[0.35686278 0.35686278 0.3411765 ]
#     [0.37254906 0.34901965 0.3411765 ]
#     [0.3803922  0.35686278 0.35686278]
#     ...
#     [0.41960788 0.4039216  0.427451  ]
#     [0.3803922  0.39607847 0.41176474]
#     [0.41176474 0.4039216  0.41960788]]
#
#    ...
#
#    [[0.16078436 0.14509809 0.18431377]
#     [0.15294123 0.13725495 0.17647064]
#     [0.14509809 0.12156868 0.16078436]
#     ...
#     [0.254902   0.254902   0.33333337]
#     [0.26274514 0.254902   0.33333337]
#     [0.26274514 0.254902   0.33333337]]
#
#    [[0.1686275  0.15294123 0.19215691]
#     [0.14509809 0.12941182 0.1686275 ]
#     [0.13725495 0.12941182 0.18431377]
#     ...
#     [0.24705887 0.24705887 0.32549024]
#     [0.23921573 0.24705887 0.32549024]
#     [0.23921573 0.24705887 0.32549024]]
#
#    [[0.16078436 0.14509809 0.18431377]
#     [0.14509809 0.12941182 0.1686275 ]
#     [0.12941182 0.12156868 0.1686275 ]
#     ...
#     [0.23921573 0.23921573 0.3176471 ]
#     [0.23921573 0.24705887 0.32549024]
#     [0.23921573 0.24705887 0.32549024]]]
#
#
#   [[[0.38823533 0.34901965 0.3411765 ]
#     [0.38823533 0.34901965 0.3411765 ]
#     [0.37254906 0.36470592 0.34901965]
#     ...
#     [0.41176474 0.39607847 0.41176474]
#     [0.41960788 0.41960788 0.41960788]
#     [0.41176474 0.43529415 0.43529415]]
#
#    [[0.37254906 0.34901965 0.3411765 ]
#     [0.36470592 0.36470592 0.34901965]
#     [0.3803922  0.35686278 0.36470592]
#     ...
#     [0.41960788 0.4039216  0.41176474]
#     [0.4039216  0.4039216  0.4039216 ]
#     [0.38823533 0.41176474 0.41176474]]
#
#    [[0.37254906 0.35686278 0.35686278]
#     [0.37254906 0.34901965 0.35686278]
#     [0.3803922  0.35686278 0.36470592]
#     ...
#     [0.41960788 0.4039216  0.41960788]
#     [0.4039216  0.4039216  0.4039216 ]
#     [0.38823533 0.41176474 0.41176474]]
#
#    ...
#
#    [[0.16078436 0.14509809 0.18431377]
#     [0.15294123 0.13725495 0.17647064]
#     [0.16078436 0.13725495 0.17647064]
#     ...
#     [0.254902   0.254902   0.3176471 ]
#     [0.26274514 0.254902   0.33333337]
#     [0.26274514 0.254902   0.33333337]]
#
#    [[0.1686275  0.15294123 0.19215691]
#     [0.15294123 0.13725495 0.17647064]
#     [0.14509809 0.12941182 0.17647064]
#     ...
#     [0.23921573 0.24705887 0.32549024]
#     [0.23921573 0.24705887 0.32549024]
#     [0.27058828 0.26274514 0.3411765 ]]
#
#    [[0.14509809 0.12941182 0.1686275 ]
#     [0.14509809 0.12941182 0.1686275 ]
#     [0.13725495 0.11372554 0.1686275 ]
#     ...
#     [0.23921573 0.24705887 0.32549024]
#     [0.23921573 0.24705887 0.32549024]
#     [0.22352946 0.2313726  0.30980396]]]
#
#
#   [[[0.3803922  0.3411765  0.34901965]
#     [0.39607847 0.35686278 0.36470592]
#     [0.3803922  0.37254906 0.3803922 ]
#     ...
#     [0.427451   0.38823533 0.41176474]
#     [0.4039216  0.39607847 0.41176474]
#     [0.427451   0.41960788 0.43529415]]
#
#    [[0.37254906 0.34901965 0.35686278]
#     [0.36470592 0.36470592 0.36470592]
#     [0.3803922  0.34901965 0.37254906]
#     ...
#     [0.427451   0.4039216  0.427451  ]
#     [0.38823533 0.4039216  0.41960788]
#     [0.38823533 0.4039216  0.41960788]]
#
#    [[0.37254906 0.35686278 0.35686278]
#     [0.37254906 0.34901965 0.35686278]
#     [0.3803922  0.35686278 0.36470592]
#     ...
#     [0.41176474 0.4039216  0.41960788]
#     [0.4039216  0.39607847 0.41176474]
#     [0.41176474 0.4039216  0.41960788]]
#
#    ...
#
#    [[0.1686275  0.15294123 0.19215691]
#     [0.15294123 0.13725495 0.17647064]
#     [0.16078436 0.13725495 0.17647064]
#     ...
#     [0.254902   0.24705887 0.32549024]
#     [0.26274514 0.254902   0.33333337]
#     [0.24705887 0.254902   0.33333337]]
#
#    [[0.1686275  0.12941182 0.17647064]
#     [0.18431377 0.13725495 0.20000005]
#     [0.17647064 0.12156868 0.17647064]
#     ...
#     [0.23921573 0.24705887 0.32549024]
#     [0.23921573 0.24705887 0.32549024]
#     [0.27058828 0.26274514 0.3411765 ]]
#
#    [[0.1686275  0.12941182 0.17647064]
#     [0.15294123 0.10588241 0.1686275 ]
#     [0.1686275  0.10588241 0.1686275 ]
#     ...
#     [0.23921573 0.24705887 0.32549024]
#     [0.23921573 0.24705887 0.32549024]
#     [0.24705887 0.254902   0.33333337]]]]
#
#
#
#  [[[[0.4039216  0.3411765  0.3411765 ]
#     [0.4039216  0.3411765  0.3411765 ]
#     [0.39607847 0.3411765  0.3411765 ]
#     ...
#     [0.41960788 0.4039216  0.41176474]
#     [0.4039216  0.4039216  0.4039216 ]
#     [0.4039216  0.4039216  0.4039216 ]]
#
#    [[0.4039216  0.3411765  0.3411765 ]
#     [0.4039216  0.3411765  0.3411765 ]
#     [0.39607847 0.3411765  0.3411765 ]
#     ...
#     [0.41176474 0.4039216  0.4039216 ]
#     [0.4039216  0.4039216  0.4039216 ]
#     [0.4039216  0.4039216  0.4039216 ]]
#
#    [[0.38823533 0.34901965 0.3411765 ]
#     [0.38823533 0.34901965 0.3411765 ]
#     [0.3803922  0.35686278 0.3411765 ]
#     ...
#     [0.43529415 0.39607847 0.4039216 ]
#     [0.41960788 0.39607847 0.4039216 ]
#     [0.41960788 0.39607847 0.4039216 ]]
#
#    ...
#
#    [[0.1686275  0.12941182 0.17647064]
#     [0.17647064 0.12941182 0.18431377]
#     [0.16078436 0.13725495 0.17647064]
#     ...
#     [0.24705887 0.24705887 0.30196083]
#     [0.26274514 0.26274514 0.3176471 ]
#     [0.26274514 0.26274514 0.3176471 ]]
#
#    [[0.16078436 0.12156868 0.1686275 ]
#     [0.1686275  0.12941182 0.17647064]
#     [0.1686275  0.13725495 0.18431377]
#     ...
#     [0.24705887 0.24705887 0.3176471 ]
#     [0.254902   0.24705887 0.32549024]
#     [0.26274514 0.254902   0.33333337]]
#
#    [[0.16078436 0.12156868 0.1686275 ]
#     [0.16078436 0.12156868 0.1686275 ]
#     [0.15294123 0.12941182 0.1686275 ]
#     ...
#     [0.2313726  0.2313726  0.30196083]
#     [0.23921573 0.2313726  0.30980396]
#     [0.254902   0.24705887 0.32549024]]]
#
#
#   [[[0.35686278 0.33333337 0.32549024]
#     [0.36470592 0.36470592 0.34901965]
#     [0.3803922  0.35686278 0.35686278]
#     ...
#     [0.4039216  0.39607847 0.4039216 ]
#     [0.4039216  0.39607847 0.41176474]
#     [0.4039216  0.39607847 0.41176474]]
#
#    [[0.3803922  0.35686278 0.34901965]
#     [0.37254906 0.34901965 0.3411765 ]
#     [0.39607847 0.35686278 0.35686278]
#     ...
#     [0.39607847 0.38823533 0.39607847]
#     [0.4039216  0.39607847 0.41176474]
#     [0.4039216  0.39607847 0.41176474]]
#
#    [[0.3803922  0.34901965 0.3411765 ]
#     [0.39607847 0.33333337 0.33333337]
#     [0.3803922  0.3176471  0.32549024]
#     ...
#     [0.41960788 0.38823533 0.4039216 ]
#     [0.41176474 0.3803922  0.4039216 ]
#     [0.41176474 0.38823533 0.4039216 ]]
#
#    ...
#
#    [[0.14509809 0.13725495 0.18431377]
#     [0.16078436 0.14509809 0.20000005]
#     [0.13725495 0.12941182 0.17647064]
#     ...
#     [0.2313726  0.254902   0.30196083]
#     [0.24705887 0.27058828 0.30980396]
#     [0.254902   0.27058828 0.32549024]]
#
#    [[0.13725495 0.12156868 0.16078436]
#     [0.14509809 0.12156868 0.17647064]
#     [0.15294123 0.12941182 0.17647064]
#     ...
#     [0.23921573 0.254902   0.30980396]
#     [0.23921573 0.254902   0.30980396]
#     [0.254902   0.254902   0.30980396]]
#
#    [[0.14509809 0.12941182 0.1686275 ]
#     [0.12156868 0.09803927 0.15294123]
#     [0.13725495 0.11372554 0.16078436]
#     ...
#     [0.24705887 0.254902   0.32549024]
#     [0.2313726  0.23921573 0.3176471 ]
#     [0.26274514 0.23921573 0.2941177 ]]]
#
#
#   [[[0.37254906 0.34901965 0.3411765 ]
#     [0.36470592 0.3411765  0.33333337]
#     [0.3803922  0.34901965 0.3411765 ]
#     ...
#     [0.41176474 0.41176474 0.41176474]
#     [0.4039216  0.4039216  0.4039216 ]
#     [0.41176474 0.41176474 0.41176474]]
#
#    [[0.37254906 0.34901965 0.3411765 ]
#     [0.37254906 0.34901965 0.3411765 ]
#     [0.3803922  0.34901965 0.3411765 ]
#     ...
#     [0.41176474 0.4039216  0.4039216 ]
#     [0.427451   0.4039216  0.41176474]
#     [0.41960788 0.39607847 0.4039216 ]]
#
#    [[0.37254906 0.34901965 0.3411765 ]
#     [0.37254906 0.34901965 0.3411765 ]
#     [0.37254906 0.3411765  0.33333337]
#     ...
#     [0.41176474 0.4039216  0.4039216 ]
#     [0.427451   0.4039216  0.41176474]
#     [0.41960788 0.39607847 0.4039216 ]]
#
#    ...
#
#    [[0.15294123 0.13725495 0.17647064]
#     [0.15294123 0.13725495 0.17647064]
#     [0.14509809 0.12941182 0.1686275 ]
#     ...
#     [0.26274514 0.27058828 0.3176471 ]
#     [0.26274514 0.27058828 0.30980396]
#     [0.27058828 0.27058828 0.32549024]]
#
#    [[0.14509809 0.12941182 0.1686275 ]
#     [0.14509809 0.12941182 0.1686275 ]
#     [0.14509809 0.13725495 0.15294123]
#     ...
#     [0.24705887 0.254902   0.2941177 ]
#     [0.24705887 0.254902   0.2941177 ]
#     [0.254902   0.26274514 0.30196083]]
#
#    [[0.15294123 0.13725495 0.17647064]
#     [0.12941182 0.11372554 0.15294123]
#     [0.13725495 0.12941182 0.14509809]
#     ...
#     [0.2313726  0.23921573 0.27843142]
#     [0.23921573 0.24705887 0.28627455]
#     [0.254902   0.26274514 0.30196083]]]
#
#
#   ...
#
#
#   [[[0.4039216  0.3411765  0.3411765 ]
#     [0.4039216  0.3411765  0.3411765 ]
#     [0.4039216  0.34901965 0.35686278]
#     ...
#     [0.41176474 0.4039216  0.41960788]
#     [0.39607847 0.38823533 0.4039216 ]
#     [0.41176474 0.4039216  0.41960788]]
#
#    [[0.41176474 0.34901965 0.34901965]
#     [0.41176474 0.34901965 0.34901965]
#     [0.4039216  0.35686278 0.35686278]
#     ...
#     [0.41176474 0.4039216  0.41960788]
#     [0.4039216  0.39607847 0.41960788]
#     [0.41176474 0.4039216  0.41960788]]
#
#    [[0.38823533 0.34901965 0.3411765 ]
#     [0.39607847 0.35686278 0.34901965]
#     [0.38823533 0.34901965 0.35686278]
#     ...
#     [0.41176474 0.4039216  0.427451  ]
#     [0.41176474 0.4039216  0.41960788]
#     [0.41176474 0.4039216  0.41960788]]
#
#    ...
#
#    [[0.14509809 0.15294123 0.19215691]
#     [0.13725495 0.14509809 0.18431377]
#     [0.14509809 0.13725495 0.17647064]
#     ...
#     [0.254902   0.26274514 0.3176471 ]
#     [0.27058828 0.27058828 0.32549024]
#     [0.26274514 0.26274514 0.3176471 ]]
#
#    [[0.14509809 0.15294123 0.19215691]
#     [0.12156868 0.14509809 0.18431377]
#     [0.12156868 0.12941182 0.17647064]
#     ...
#     [0.24705887 0.254902   0.32549024]
#     [0.23921573 0.24705887 0.32549024]
#     [0.24705887 0.26274514 0.3176471 ]]
#
#    [[0.12941182 0.13725495 0.17647064]
#     [0.12156868 0.12941182 0.1686275 ]
#     [0.11372554 0.11372554 0.16078436]
#     ...
#     [0.24705887 0.254902   0.32549024]
#     [0.2313726  0.23921573 0.3176471 ]
#     [0.23921573 0.254902   0.30980396]]]
#
#
#   [[[0.3803922  0.35686278 0.36470592]
#     [0.3803922  0.35686278 0.37254906]
#     [0.38823533 0.34901965 0.34901965]
#     ...
#     [0.4039216  0.4039216  0.41960788]
#     [0.38823533 0.4039216  0.41960788]
#     [0.4039216  0.39607847 0.41176474]]
#
#    [[0.3803922  0.35686278 0.36470592]
#     [0.37254906 0.34901965 0.35686278]
#     [0.38823533 0.35686278 0.35686278]
#     ...
#     [0.41960788 0.4039216  0.427451  ]
#     [0.43529415 0.4039216  0.427451  ]
#     [0.4039216  0.39607847 0.41176474]]
#
#    [[0.3803922  0.35686278 0.36470592]
#     [0.3803922  0.35686278 0.36470592]
#     [0.38823533 0.35686278 0.35686278]
#     ...
#     [0.41960788 0.41176474 0.427451  ]
#     [0.41960788 0.41176474 0.427451  ]
#     [0.41176474 0.4039216  0.427451  ]]
#
#    ...
#
#    [[0.16078436 0.14509809 0.18431377]
#     [0.15294123 0.13725495 0.17647064]
#     [0.13725495 0.12156868 0.16078436]
#     ...
#     [0.26274514 0.254902   0.33333337]
#     [0.26274514 0.254902   0.33333337]
#     [0.254902   0.24705887 0.32549024]]
#
#    [[0.12156868 0.12941182 0.1686275 ]
#     [0.15294123 0.13725495 0.17647064]
#     [0.12941182 0.12941182 0.1686275 ]
#     ...
#     [0.23921573 0.24705887 0.3176471 ]
#     [0.23921573 0.24705887 0.32549024]
#     [0.23921573 0.254902   0.30980396]]
#
#    [[0.12941182 0.13725495 0.17647064]
#     [0.14509809 0.12941182 0.1686275 ]
#     [0.13725495 0.12941182 0.1686275 ]
#     ...
#     [0.24705887 0.26274514 0.32549024]
#     [0.23921573 0.24705887 0.32549024]
#     [0.23921573 0.254902   0.30980396]]]
#
#
#   [[[0.39607847 0.35686278 0.36470592]
#     [0.38823533 0.34901965 0.35686278]
#     [0.38823533 0.34901965 0.35686278]
#     ...
#     [0.41176474 0.4039216  0.41960788]
#     [0.41176474 0.4039216  0.41960788]
#     [0.41176474 0.4039216  0.41960788]]
#
#    [[0.39607847 0.35686278 0.36470592]
#     [0.3803922  0.35686278 0.36470592]
#     [0.38823533 0.35686278 0.36470592]
#     ...
#     [0.41960788 0.4039216  0.427451  ]
#     [0.41176474 0.4039216  0.41960788]
#     [0.41960788 0.4039216  0.427451  ]]
#
#    [[0.39607847 0.35686278 0.36470592]
#     [0.39607847 0.35686278 0.36470592]
#     [0.39607847 0.35686278 0.36470592]
#     ...
#     [0.41960788 0.41176474 0.427451  ]
#     [0.41960788 0.41176474 0.427451  ]
#     [0.41960788 0.41176474 0.427451  ]]
#
#    ...
#
#    [[0.16078436 0.14509809 0.18431377]
#     [0.14509809 0.13725495 0.1686275 ]
#     [0.14509809 0.12941182 0.1686275 ]
#     ...
#     [0.27058828 0.26274514 0.33333337]
#     [0.27058828 0.26274514 0.3411765 ]
#     [0.26274514 0.254902   0.33333337]]
#
#    [[0.16078436 0.14509809 0.18431377]
#     [0.15294123 0.13725495 0.17647064]
#     [0.14509809 0.12941182 0.1686275 ]
#     ...
#     [0.26274514 0.254902   0.32549024]
#     [0.26274514 0.26274514 0.3176471 ]
#     [0.254902   0.254902   0.30980396]]
#
#    [[0.15294123 0.13725495 0.17647064]
#     [0.13725495 0.12941182 0.16078436]
#     [0.14509809 0.12941182 0.1686275 ]
#     ...
#     [0.254902   0.24705887 0.3176471 ]
#     [0.254902   0.254902   0.30980396]
#     [0.26274514 0.26274514 0.30980396]]]]
#
#
#
#  ...
#
#
#
#  [[[[0.69411767 0.69411767 0.6784314 ]
#     [0.69411767 0.69411767 0.6784314 ]
#     [0.69411767 0.69411767 0.6784314 ]
#     ...
#     [0.7019608  0.7176471  0.7254902 ]
#     [0.7019608  0.7176471  0.73333335]
#     [0.7019608  0.7176471  0.73333335]]
#
#    [[0.69411767 0.69411767 0.6784314 ]
#     [0.69411767 0.69411767 0.6784314 ]
#     [0.69411767 0.69411767 0.6784314 ]
#     ...
#     [0.7019608  0.7176471  0.7254902 ]
#     [0.7019608  0.7176471  0.73333335]
#     [0.7019608  0.7176471  0.73333335]]
#
#    [[0.69411767 0.69411767 0.6784314 ]
#     [0.69411767 0.69411767 0.6784314 ]
#     [0.69411767 0.69411767 0.6784314 ]
#     ...
#     [0.7019608  0.7176471  0.7254902 ]
#     [0.7019608  0.7176471  0.73333335]
#     [0.7019608  0.7176471  0.73333335]]
#
#    ...
#
#    [[0.33333337 0.35686278 0.36470592]
#     [0.3411765  0.35686278 0.37254906]
#     [0.3411765  0.35686278 0.37254906]
#     ...
#     [0.5058824  0.52156866 0.5372549 ]
#     [0.5058824  0.52156866 0.5372549 ]
#     [0.5058824  0.52156866 0.5372549 ]]
#
#    [[0.32549024 0.33333337 0.37254906]
#     [0.32549024 0.33333337 0.37254906]
#     [0.32549024 0.3411765  0.36470592]
#     ...
#     [0.49803925 0.5058824  0.5372549 ]
#     [0.49803925 0.5137255  0.5294118 ]
#     [0.49803925 0.5137255  0.5294118 ]]
#
#    [[0.3176471  0.32549024 0.36470592]
#     [0.3176471  0.32549024 0.36470592]
#     [0.32549024 0.33333337 0.36470592]
#     ...
#     [0.4901961  0.49803925 0.5294118 ]
#     [0.49803925 0.5137255  0.5294118 ]
#     [0.4901961  0.5058824  0.52156866]]]
#
#
#   [[[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6784314  0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6784314  0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    ...
#
#    [[0.2941177  0.30980396 0.32549024]
#     [0.2941177  0.30980396 0.32549024]
#     [0.2941177  0.30980396 0.32549024]
#     ...
#     [0.4901961  0.4901961  0.5137255 ]
#     [0.47450984 0.48235297 0.52156866]
#     [0.47450984 0.48235297 0.52156866]]
#
#    [[0.26274514 0.28627455 0.32549024]
#     [0.27843142 0.2941177  0.34901965]
#     [0.28627455 0.2941177  0.3411765 ]
#     ...
#     [0.45098042 0.4666667  0.49803925]
#     [0.4431373  0.4666667  0.5058824 ]
#     [0.4431373  0.4666667  0.5058824 ]]
#
#    [[0.26274514 0.28627455 0.32549024]
#     [0.26274514 0.27843142 0.33333337]
#     [0.27058828 0.27843142 0.32549024]
#     ...
#     [0.45098042 0.47450984 0.49803925]
#     [0.4431373  0.4666667  0.5058824 ]
#     [0.4431373  0.4666667  0.5058824 ]]]
#
#
#   [[[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.6627451  0.6784314  0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    ...
#
#    [[0.2941177  0.30196083 0.3411765 ]
#     [0.2941177  0.30196083 0.3411765 ]
#     [0.2941177  0.30980396 0.34901965]
#     ...
#     [0.4901961  0.47450984 0.5058824 ]
#     [0.48235297 0.4901961  0.5294118 ]
#     [0.48235297 0.4901961  0.5294118 ]]
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.2941177  0.30196083 0.3411765 ]
#     [0.2941177  0.30196083 0.33333337]
#     ...
#     [0.47450984 0.4666667  0.5058824 ]
#     [0.45882356 0.4666667  0.5058824 ]
#     [0.4666667  0.47450984 0.5137255 ]]
#
#    [[0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.28627455 0.32549024]
#     ...
#     [0.45098042 0.45882356 0.49803925]
#     [0.45882356 0.4666667  0.5058824 ]
#     [0.45098042 0.4666667  0.48235297]]]
#
#
#   ...
#
#
#   [[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6627451  0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.30196083 0.30980396 0.34901965]
#     [0.30980396 0.3176471  0.35686278]
#     ...
#     [0.4666667  0.48235297 0.49803925]
#     [0.48235297 0.49803925 0.5137255 ]
#     [0.48235297 0.49803925 0.5137255 ]]
#
#    [[0.30980396 0.30196083 0.3176471 ]
#     [0.30980396 0.30196083 0.3176471 ]
#     [0.2941177  0.30196083 0.3176471 ]
#     ...
#     [0.47450984 0.47450984 0.4901961 ]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.4666667  0.48235297 0.49803925]]
#
#    [[0.27843142 0.2941177  0.30980396]
#     [0.30980396 0.2941177  0.33333337]
#     [0.2941177  0.2941177  0.3176471 ]
#     ...
#     [0.4666667  0.45882356 0.47450984]
#     [0.47450984 0.4666667  0.48235297]
#     [0.48235297 0.47450984 0.4901961 ]]]
#
#
#   [[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6627451  0.69411767 0.69411767]
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6862745  0.6862745  0.6862745 ]
#     [0.6862745  0.6862745  0.6862745 ]
#     [0.69411767 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.2941177  0.30196083 0.3411765 ]
#     [0.30196083 0.30196083 0.3411765 ]
#     [0.30980396 0.3176471  0.35686278]
#     ...
#     [0.4666667  0.48235297 0.49803925]
#     [0.48235297 0.49803925 0.5137255 ]
#     [0.48235297 0.49803925 0.5137255 ]]
#
#    [[0.30980396 0.2941177  0.33333337]
#     [0.30980396 0.30196083 0.3176471 ]
#     [0.30196083 0.30196083 0.32549024]
#     ...
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.4666667  0.47450984 0.5137255 ]]
#
#    [[0.2941177  0.28627455 0.32549024]
#     [0.27843142 0.28627455 0.32549024]
#     [0.27058828 0.28627455 0.30980396]
#     ...
#     [0.45098042 0.4666667  0.48235297]
#     [0.45098042 0.4666667  0.48235297]
#     [0.45098042 0.45882356 0.49803925]]]
#
#
#   [[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]]
#
#    [[0.6784314  0.6784314  0.6627451 ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.69411767 0.69411767 0.69411767]
#     [0.6862745  0.6862745  0.6862745 ]
#     [0.69411767 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.3176471  0.30196083 0.3411765 ]
#     [0.30196083 0.3176471  0.33333337]
#     [0.30980396 0.3176471  0.34901965]
#     ...
#     [0.4666667  0.47450984 0.5058824 ]
#     [0.48235297 0.4901961  0.5294118 ]
#     [0.48235297 0.4901961  0.5294118 ]]
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.28627455 0.30196083 0.3176471 ]
#     [0.27843142 0.30196083 0.33333337]
#     ...
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.48235297 0.47450984 0.4901961 ]]
#
#    [[0.30196083 0.2941177  0.33333337]
#     [0.27843142 0.28627455 0.32549024]
#     [0.27058828 0.28627455 0.3176471 ]
#     ...
#     [0.45098042 0.47450984 0.48235297]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.47450984 0.4666667  0.48235297]]]]
#
#
#
#  [[[[0.70980394 0.70980394 0.70980394]
#     [0.70980394 0.70980394 0.70980394]
#     [0.70980394 0.70980394 0.70980394]
#     ...
#     [0.70980394 0.73333335 0.73333335]
#     [0.70980394 0.73333335 0.73333335]
#     [0.70980394 0.73333335 0.73333335]]
#
#    [[0.70980394 0.70980394 0.70980394]
#     [0.70980394 0.70980394 0.70980394]
#     [0.70980394 0.70980394 0.70980394]
#     ...
#     [0.70980394 0.73333335 0.73333335]
#     [0.70980394 0.73333335 0.73333335]
#     [0.70980394 0.73333335 0.73333335]]
#
#    [[0.70980394 0.70980394 0.70980394]
#     [0.70980394 0.70980394 0.70980394]
#     [0.70980394 0.70980394 0.70980394]
#     ...
#     [0.7176471  0.7411765  0.7411765 ]
#     [0.7176471  0.7411765  0.7411765 ]
#     [0.7176471  0.7411765  0.7411765 ]]
#
#    ...
#
#    [[0.33333337 0.36470592 0.3803922 ]
#     [0.33333337 0.36470592 0.3803922 ]
#     [0.3411765  0.36470592 0.3803922 ]
#     ...
#     [0.52156866 0.5372549  0.5529412 ]
#     [0.5137255  0.5372549  0.54509807]
#     [0.5137255  0.5372549  0.54509807]]
#
#    [[0.32549024 0.34901965 0.38823533]
#     [0.33333337 0.3411765  0.3803922 ]
#     [0.33333337 0.34901965 0.37254906]
#     ...
#     [0.5058824  0.5137255  0.5529412 ]
#     [0.5058824  0.5137255  0.5529412 ]
#     [0.5058824  0.52156866 0.5372549 ]]
#
#    [[0.32549024 0.34901965 0.38823533]
#     [0.33333337 0.3411765  0.3803922 ]
#     [0.33333337 0.3411765  0.37254906]
#     ...
#     [0.49803925 0.5058824  0.54509807]
#     [0.5058824  0.5137255  0.5529412 ]
#     [0.5058824  0.52156866 0.5372549 ]]]
#
#
#   [[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.6627451  0.6862745  0.6862745 ]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.6627451  0.6862745  0.6862745 ]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.28627455 0.30196083 0.3176471 ]
#     [0.30196083 0.3176471  0.33333337]
#     [0.30980396 0.32549024 0.3411765 ]
#     ...
#     [0.47450984 0.4901961  0.5058824 ]
#     [0.48235297 0.49803925 0.5137255 ]
#     [0.47450984 0.4901961  0.5058824 ]]
#
#    [[0.28627455 0.30196083 0.3176471 ]
#     [0.28627455 0.30196083 0.3176471 ]
#     [0.2941177  0.30196083 0.33333337]
#     ...
#     [0.4431373  0.47450984 0.5058824 ]
#     [0.4431373  0.47450984 0.4901961 ]
#     [0.4431373  0.47450984 0.4901961 ]]
#
#    [[0.27843142 0.2941177  0.30980396]
#     [0.28627455 0.30196083 0.3176471 ]
#     [0.28627455 0.2941177  0.32549024]
#     ...
#     [0.43529415 0.4666667  0.49803925]
#     [0.43529415 0.4666667  0.48235297]
#     [0.43529415 0.4666667  0.48235297]]]
#
#
#   [[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.7019608  0.6862745  0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6862745  0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.2941177  0.30980396 0.32549024]
#     [0.30196083 0.3176471  0.33333337]
#     [0.30980396 0.32549024 0.3411765 ]
#     ...
#     [0.48235297 0.48235297 0.49803925]
#     [0.49803925 0.4901961  0.5058824 ]
#     [0.4901961  0.48235297 0.49803925]]
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.28627455 0.2941177  0.33333337]
#     [0.2941177  0.30196083 0.3411765 ]
#     ...
#     [0.4666667  0.47450984 0.48235297]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.48235297 0.47450984 0.4901961 ]]
#
#    [[0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.28627455 0.32549024]
#     ...
#     [0.45098042 0.4666667  0.47450984]
#     [0.43529415 0.4666667  0.48235297]
#     [0.45098042 0.4666667  0.48235297]]]
#
#
#   ...
#
#
#   [[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.6784314  0.6784314  0.6784314 ]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.2941177  0.30196083 0.3411765 ]
#     [0.28627455 0.2941177  0.33333337]
#     [0.30196083 0.30980396 0.3411765 ]
#     ...
#     [0.49803925 0.48235297 0.5137255 ]
#     [0.4901961  0.47450984 0.5137255 ]
#     [0.49803925 0.4901961  0.5058824 ]]
#
#    [[0.30980396 0.2941177  0.33333337]
#     [0.30980396 0.30196083 0.3176471 ]
#     [0.30980396 0.30196083 0.32549024]
#     ...
#     [0.47450984 0.48235297 0.49803925]
#     [0.48235297 0.47450984 0.4901961 ]
#     [0.48235297 0.48235297 0.49803925]]
#
#    [[0.30196083 0.28627455 0.32549024]
#     [0.30980396 0.2941177  0.3176471 ]
#     [0.30980396 0.30196083 0.3176471 ]
#     ...
#     [0.45098042 0.4666667  0.48235297]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.47450984 0.4666667  0.48235297]]]
#
#
#   [[[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.6784314  0.6784314  0.6627451 ]
#     [0.6784314  0.6784314  0.6627451 ]
#     [0.6784314  0.6784314  0.67058825]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.3176471  0.30980396 0.32549024]
#     [0.3176471  0.30196083 0.3176471 ]
#     [0.30980396 0.30980396 0.33333337]
#     ...
#     [0.4666667  0.48235297 0.49803925]
#     [0.47450984 0.4901961  0.5058824 ]
#     [0.47450984 0.4901961  0.5058824 ]]
#
#    [[0.30980396 0.2941177  0.33333337]
#     [0.30980396 0.30196083 0.3176471 ]
#     [0.30196083 0.30196083 0.33333337]
#     ...
#     [0.45882356 0.48235297 0.4901961 ]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.4666667  0.48235297 0.49803925]]
#
#    [[0.30980396 0.2941177  0.33333337]
#     [0.30196083 0.2941177  0.30980396]
#     [0.2941177  0.30196083 0.3176471 ]
#     ...
#     [0.45882356 0.47450984 0.48235297]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.45098042 0.4666667  0.48235297]]]
#
#
#   [[[0.654902   0.654902   0.654902  ]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.64705884 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.3176471  0.30980396 0.32549024]
#     [0.3176471  0.30980396 0.32549024]
#     [0.30980396 0.30980396 0.3411765 ]
#     ...
#     [0.47450984 0.48235297 0.49803925]
#     [0.4901961  0.48235297 0.49803925]
#     [0.4901961  0.48235297 0.49803925]]
#
#    [[0.30980396 0.30196083 0.33333337]
#     [0.30980396 0.30196083 0.3176471 ]
#     [0.3176471  0.30980396 0.33333337]
#     ...
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.49803925 0.4666667  0.4901961 ]]
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.30980396 0.2941177  0.3176471 ]
#     [0.30980396 0.30196083 0.32549024]
#     ...
#     [0.45098042 0.4666667  0.48235297]
#     [0.45882356 0.47450984 0.4901961 ]
#     [0.45882356 0.47450984 0.4901961 ]]]]
#
#
#
#  [[[[0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.6862745 ]
#     ...
#     [0.7019608  0.7254902  0.7254902 ]
#     [0.7019608  0.7254902  0.7254902 ]
#     [0.7019608  0.7254902  0.7254902 ]]
#
#    [[0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.6862745 ]
#     ...
#     [0.7019608  0.7254902  0.7254902 ]
#     [0.7019608  0.7254902  0.7254902 ]
#     [0.7019608  0.7254902  0.7254902 ]]
#
#    [[0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.6862745 ]
#     ...
#     [0.7019608  0.7254902  0.7254902 ]
#     [0.7019608  0.7254902  0.7254902 ]
#     [0.7019608  0.7254902  0.7254902 ]]
#
#    ...
#
#    [[0.33333337 0.3411765  0.3803922 ]
#     [0.33333337 0.3411765  0.3803922 ]
#     [0.33333337 0.3411765  0.37254906]
#     ...
#     [0.5137255  0.5294118  0.54509807]
#     [0.5137255  0.5294118  0.54509807]
#     [0.5137255  0.5294118  0.54509807]]
#
#    [[0.3176471  0.33333337 0.34901965]
#     [0.3176471  0.33333337 0.34901965]
#     [0.3176471  0.33333337 0.34901965]
#     ...
#     [0.49803925 0.5058824  0.54509807]
#     [0.49803925 0.5058824  0.54509807]
#     [0.49803925 0.5137255  0.5294118 ]]
#
#    [[0.3176471  0.33333337 0.34901965]
#     [0.3176471  0.33333337 0.34901965]
#     [0.3176471  0.33333337 0.34901965]
#     ...
#     [0.4901961  0.49803925 0.5372549 ]
#     [0.4901961  0.49803925 0.5372549 ]
#     [0.4901961  0.5058824  0.52156866]]]
#
#
#   [[[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.6784314  0.6862745  0.69411767]
#     [0.69411767 0.6862745  0.7019608 ]
#     [0.69411767 0.6862745  0.7019608 ]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.6784314  0.6862745  0.69411767]
#     [0.69411767 0.6862745  0.7019608 ]
#     [0.69411767 0.6862745  0.7019608 ]]
#
#    [[0.6784314  0.6784314  0.6784314 ]
#     [0.6784314  0.6784314  0.6784314 ]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.6784314  0.6862745  0.69411767]
#     [0.69411767 0.6862745  0.7019608 ]
#     [0.69411767 0.6862745  0.7019608 ]]
#
#    ...
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.28627455 0.2941177  0.33333337]
#     [0.30196083 0.3176471  0.3411765 ]
#     ...
#     [0.49803925 0.4901961  0.5137255 ]
#     [0.5058824  0.4901961  0.5294118 ]
#     [0.5058824  0.4901961  0.5294118 ]]
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.28627455 0.2941177  0.33333337]
#     [0.28627455 0.2941177  0.33333337]
#     ...
#     [0.4666667  0.45882356 0.5137255 ]
#     [0.48235297 0.4666667  0.5058824 ]
#     [0.48235297 0.4666667  0.5058824 ]]
#
#    [[0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.28627455 0.32549024]
#     [0.28627455 0.2941177  0.33333337]
#     ...
#     [0.4666667  0.45882356 0.5058824 ]
#     [0.48235297 0.4666667  0.5058824 ]
#     [0.48235297 0.4666667  0.5058824 ]]]
#
#
#   [[[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.6627451  0.6862745  0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    [[0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     [0.67058825 0.67058825 0.67058825]
#     ...
#     [0.67058825 0.6862745  0.69411767]
#     [0.67058825 0.6862745  0.7019608 ]
#     [0.67058825 0.6862745  0.7019608 ]]
#
#    ...
#
#    [[0.2941177  0.30196083 0.3411765 ]
#     [0.2941177  0.30196083 0.3411765 ]
#     [0.2941177  0.30980396 0.33333337]
#     ...
#     [0.49803925 0.47450984 0.5137255 ]
#     [0.5058824  0.4901961  0.5294118 ]
#     [0.5058824  0.4901961  0.5294118 ]]
#
#    [[0.28627455 0.2941177  0.33333337]
#     [0.28627455 0.2941177  0.33333337]
#     [0.28627455 0.2941177  0.33333337]
#     ...
#     [0.48235297 0.4666667  0.49803925]
#     [0.4901961  0.47450984 0.5137255 ]
#     [0.4901961  0.47450984 0.5137255 ]]
#
#    [[0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.28627455 0.32549024]
#     [0.28627455 0.2941177  0.33333337]
#     ...
#     [0.45882356 0.4666667  0.48235297]
#     [0.45098042 0.4666667  0.48235297]
#     [0.45098042 0.4666667  0.48235297]]]
#
#
#   ...
#
#
#   [[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6784314  0.6862745  0.6862745 ]
#     [0.6862745  0.6862745  0.6862745 ]
#     [0.69411767 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6784314  0.69411767 0.69411767]
#     [0.6862745  0.6862745  0.6862745 ]
#     [0.69411767 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6862745  0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.30980396 0.3176471  0.35686278]
#     [0.2941177  0.30196083 0.3411765 ]
#     [0.30196083 0.32549024 0.34901965]
#     ...
#     [0.47450984 0.4901961  0.5058824 ]
#     [0.48235297 0.4901961  0.52156866]
#     [0.4666667  0.4666667  0.5058824 ]]
#
#    [[0.2941177  0.30196083 0.33333337]
#     [0.28627455 0.2941177  0.33333337]
#     [0.27843142 0.30196083 0.33333337]
#     ...
#     [0.4666667  0.47450984 0.49803925]
#     [0.48235297 0.47450984 0.4901961 ]
#     [0.45882356 0.4666667  0.5058824 ]]
#
#    [[0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.2941177  0.33333337]
#     ...
#     [0.45882356 0.45882356 0.4901961 ]
#     [0.4666667  0.45882356 0.47450984]
#     [0.45098042 0.45882356 0.49803925]]]
#
#
#   [[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.6862745  0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]
#     [0.69411767 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.30196083 0.3176471  0.35686278]
#     [0.2941177  0.30196083 0.3411765 ]
#     [0.30980396 0.32549024 0.34901965]
#     ...
#     [0.4901961  0.49803925 0.5058824 ]
#     [0.47450984 0.49803925 0.5058824 ]
#     [0.4666667  0.48235297 0.49803925]]
#
#    [[0.30980396 0.28627455 0.33333337]
#     [0.28627455 0.2941177  0.33333337]
#     [0.28627455 0.30196083 0.33333337]
#     ...
#     [0.48235297 0.47450984 0.49803925]
#     [0.47450984 0.4666667  0.48235297]
#     [0.45882356 0.4666667  0.5058824 ]]
#
#    [[0.30980396 0.28627455 0.3411765 ]
#     [0.27843142 0.28627455 0.32549024]
#     [0.27843142 0.30196083 0.32549024]
#     ...
#     [0.45882356 0.45882356 0.4901961 ]
#     [0.47450984 0.4666667  0.48235297]
#     [0.45098042 0.45882356 0.49803925]]]
#
#
#   [[[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.6627451 ]
#     ...
#     [0.6627451  0.6862745  0.6862745 ]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    [[0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     [0.67058825 0.67058825 0.654902  ]
#     ...
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]
#     [0.67058825 0.69411767 0.69411767]]
#
#    ...
#
#    [[0.3176471  0.32549024 0.36470592]
#     [0.30196083 0.3176471  0.33333337]
#     [0.30196083 0.33333337 0.3411765 ]
#     ...
#     [0.4666667  0.48235297 0.49803925]
#     [0.4666667  0.48235297 0.49803925]
#     [0.47450984 0.4901961  0.5058824 ]]
#
#    [[0.27843142 0.30980396 0.32549024]
#     [0.28627455 0.30196083 0.3176471 ]
#     [0.27843142 0.30196083 0.3176471 ]
#     ...
#     [0.4666667  0.4666667  0.4901961 ]
#     [0.45882356 0.4666667  0.5058824 ]
#     [0.45882356 0.47450984 0.4901961 ]]
#
#    [[0.28627455 0.30196083 0.3176471 ]
#     [0.27843142 0.2941177  0.30980396]
#     [0.27843142 0.30196083 0.3176471 ]
#     ...
#     [0.45098042 0.4666667  0.4901961 ]
#     [0.45098042 0.45882356 0.49803925]
#     [0.45098042 0.4666667  0.48235297]]]]]

# %%
# TRAIN-VALIDATION SPLIT
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=SEED
)

#encoding
num_classes = 2
y_train_oh = tf.keras.utils.to_categorical(y_train, num_classes)
y_val_oh = tf.keras.utils.to_categorical(y_val, num_classes)

# %%
print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
print("y_train shape:", y_train.shape)
print("y_val shape:", y_val.shape)
# Out:
# X_train shape: (945, 40, 224, 224, 3)
# X_val shape: (406, 40, 224, 224, 3)
# y_train shape: (945,)
# y_val shape: (406,)

# %%
# FEATURE EXTRACTOR: Xception
base_model = Xception(weights='imagenet', include_top=False,
                         input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
feature_extractor = Model(inputs=base_model.input,
                          outputs=GlobalAveragePooling2D()(base_model.output))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
# CLASS WEIGHTS
class_weights_arr = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights = {0: class_weights_arr[0], 1: class_weights_arr[1]}

# %%
# 3 DENSE LAYERS EXPERIMENT LOOP
dense_combinations = [(1024,512,256), (512,256,128), (256,128,64), (128,64,32)]
expt_names = ['Expt1', 'Expt2', 'Expt3', 'Expt4']
experiment_results = []

from sklearn.metrics import f1_score

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

best_score = -1
best_units = None
best_model = None

for i, (units1, units2, units3) in enumerate(dense_combinations):

    print(f"\n================= {expt_names[i]}: Dense{units1} x {units2} x {units3} =================")

    # Input layer
    input_layer = Input(shape=(NUM_FRAMES, IMAGE_HEIGHT, IMAGE_WIDTH, 3))

    # CNN feature extraction
    inception_td = TimeDistributed(feature_extractor)(input_layer)

    # GRU layers
    gru_1 = GRU(512, return_sequences=False)(inception_td)
    dropout_1 = Dropout(0.5)(gru_1)

    # First Dense layer
    dense_1 = Dense(units1, activation='relu')(dropout_1)
    dropout_2 = Dropout(0.5)(dense_1)

    # Second Dense layer
    dense_2 = Dense(units2, activation='relu')(dropout_2)
    dropout_3 = Dropout(0.5)(dense_2)

    # Third Dense layer
    dense_3 = Dense(units3, activation='relu')(dropout_3)
    dropout_4 = Dropout(0.5)(dense_3)

    # Output layer
    output_layer = Dense(num_classes, activation='sigmoid')(dropout_4)

    # Model
    model = Model(inputs=input_layer, outputs=output_layer)

    model.compile(loss='categorical_crossentropy', optimizer=Nadam(1e-4), metrics=['accuracy'])

    # Train
    history = model.fit(
        X_train, y_train_oh,
        validation_data=(X_val, y_val_oh),
        epochs=10, #try 15
        batch_size=3,
        class_weight=class_weights,
        callbacks=[early_stopping],
        verbose=1
    )

    # Evaluation
    loss, acc = model.evaluate(X_val, y_val_oh, verbose=0)

    y_pred_prob = model.predict(X_val)
    y_pred = np.argmax(y_pred_prob, axis=1)
    y_true = np.argmax(y_val_oh, axis=1)

    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    print(f"\n{expt_names[i]} Confusion Matrix:\n", cm)
    print(classification_report(y_true, y_pred))

    # Plot confusion matrix
    plt.figure(dpi=300)
    plt.imshow(cm, interpolation='nearest', cmap='Blues')
    plt.title(f'{expt_names[i]} Confusion Matrix')
    plt.colorbar()
    plt.xlabel('Predicted label')
    plt.ylabel('True label')

    ticks = np.arange(2)
    plt.xticks(ticks, ['Negative','Positive'])
    plt.yticks(ticks, ['Negative','Positive'])

    for i_cm in range(cm.shape[0]):
        for j_cm in range(cm.shape[1]):
            plt.text(j_cm, i_cm, cm[i_cm, j_cm], ha='center', va='center')

    plt.tight_layout()
    plt.show()

    # Training charts
    epochs_range = range(1, len(history.history['accuracy']) + 1)

    # Accuracy
    plt.figure()
    plt.plot(epochs_range, history.history['accuracy'], label='Training Accuracy')
    plt.plot(epochs_range, history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'{expt_names[i]} Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # Loss
    plt.figure()
    plt.plot(epochs_range, history.history['loss'], label='Training Loss')
    plt.plot(epochs_range, history.history['val_loss'], label='Validation Loss')
    plt.title(f'{expt_names[i]} Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # ROC curve
    fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:,1])
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.3f})')
    plt.plot([0,1],[0,1],'--', label='Chance')
    plt.title(f'{expt_names[i]} ROC Curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # Precision-Recall curve
    precision_vals, recall_vals, _ = precision_recall_curve(y_true, y_pred_prob[:,1])

    plt.figure()
    plt.plot(recall_vals, precision_vals, label='Precision-Recall curve')
    plt.title(f'{expt_names[i]} Precision-Recall Curve')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # Compute F1-score
    f1_val = f1_score(y_true, y_pred)

    # Combined score for best model selection
    combined_score = (f1_val + roc_auc + acc) / 3

    if combined_score > best_score:
        best_score = combined_score
        best_units = f"{units1}x{units2}x{units3}"
        best_model = model

    # Store experiment metrics
    experiment_results.append({
        'Experiment': expt_names[i],
        'Dense Layer 1': units1,
        'Dense Layer 2': units2,
        'Dense Layer 3': units3,
        'Val Loss': loss,
        'Val Accuracy': acc,
        'Accuracy': acc,
        'ROC AUC': roc_auc,
        'Precision (avg)': np.mean(precision_vals),
        'Recall (avg)': np.mean(recall_vals),
        'F1 Score': f1_val
    })
# Out:
# ================= Expt1: Dense1024 x 512 x 256 =================
# Epoch 1/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1270s 3s/step - accuracy: 0.5587 - loss: 0.6878 - val_accuracy: 0.6798 - val_loss: 0.5893
# Epoch 2/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1065s 3s/step - accuracy: 0.7175 - loss: 0.5986 - val_accuracy: 0.7759 - val_loss: 0.5428
# Epoch 3/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1062s 3s/step - accuracy: 0.7979 - loss: 0.4879 - val_accuracy: 0.8030 - val_loss: 0.4473
# Epoch 4/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1061s 3s/step - accuracy: 0.8635 - loss: 0.3713 - val_accuracy: 0.8621 - val_loss: 0.3489
# Epoch 5/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1061s 3s/step - accuracy: 0.9111 - loss: 0.2615 - val_accuracy: 0.8374 - val_loss: 0.4168
# Epoch 6/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1071s 3s/step - accuracy: 0.9323 - loss: 0.2051 - val_accuracy: 0.8424 - val_loss: 0.4543
# Epoch 7/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1081s 3s/step - accuracy: 0.9312 - loss: 0.2094 - val_accuracy: 0.8793 - val_loss: 0.3040
# Epoch 8/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1079s 3s/step - accuracy: 0.9630 - loss: 0.1136 - val_accuracy: 0.8276 - val_loss: 0.5123
# Epoch 9/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1081s 3s/step - accuracy: 0.9704 - loss: 0.0693 - val_accuracy: 0.8892 - val_loss: 0.3994
# Epoch 10/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1080s 3s/step - accuracy: 0.9651 - loss: 0.0743 - val_accuracy: 0.8966 - val_loss: 0.3306
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 126s 8s/step
#
# Expt1 Confusion Matrix:
#  [[163  40]
#  [  9 194]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.80      0.87       203
#            1       0.83      0.96      0.89       203
#
#     accuracy                           0.88       406
#    macro avg       0.89      0.88      0.88       406
# weighted avg       0.89      0.88      0.88       406
# ================= Expt2: Dense512 x 256 x 128 =================
# Epoch 1/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1289s 4s/step - accuracy: 0.9005 - loss: 0.3390 - val_accuracy: 0.8621 - val_loss: 0.6000
# Epoch 2/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1077s 3s/step - accuracy: 0.9471 - loss: 0.1917 - val_accuracy: 0.8916 - val_loss: 0.3459
# Epoch 3/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1065s 3s/step - accuracy: 0.9746 - loss: 0.0911 - val_accuracy: 0.8941 - val_loss: 0.3381
# Epoch 4/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1063s 3s/step - accuracy: 0.9556 - loss: 0.1537 - val_accuracy: 0.8941 - val_loss: 0.4393
# Epoch 5/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1066s 3s/step - accuracy: 0.9672 - loss: 0.1021 - val_accuracy: 0.8793 - val_loss: 0.3354
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 125s 8s/step
#
# Expt2 Confusion Matrix:
#  [[155  48]
#  [  8 195]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.76      0.85       203
#            1       0.80      0.96      0.87       203
#
#     accuracy                           0.86       406
#    macro avg       0.88      0.86      0.86       406
# weighted avg       0.88      0.86      0.86       406
# ================= Expt3: Dense256 x 128 x 64 =================
# Epoch 1/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1276s 3s/step - accuracy: 0.8646 - loss: 0.3809 - val_accuracy: 0.8793 - val_loss: 0.2696
# Epoch 2/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1115s 4s/step - accuracy: 0.9429 - loss: 0.2110 - val_accuracy: 0.8645 - val_loss: 0.3236
# Epoch 3/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1143s 4s/step - accuracy: 0.9460 - loss: 0.1704 - val_accuracy: 0.8892 - val_loss: 0.2885
# Epoch 4/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1136s 4s/step - accuracy: 0.9693 - loss: 0.0716 - val_accuracy: 0.8719 - val_loss: 0.3587
# Epoch 5/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1132s 4s/step - accuracy: 0.9312 - loss: 0.1987 - val_accuracy: 0.8941 - val_loss: 0.2931
# Epoch 6/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1129s 4s/step - accuracy: 0.9651 - loss: 0.0999 - val_accuracy: 0.8966 - val_loss: 0.2971
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 132s 9s/step
#
# Expt3 Confusion Matrix:
#  [[157  46]
#  [  3 200]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.77      0.87       203
#            1       0.81      0.99      0.89       203
#
#     accuracy                           0.88       406
#    macro avg       0.90      0.88      0.88       406
# weighted avg       0.90      0.88      0.88       406
# ================= Expt4: Dense128 x 64 x 32 =================
# Epoch 1/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1363s 4s/step - accuracy: 0.7799 - loss: 0.4236 - val_accuracy: 0.8744 - val_loss: 0.2835
# Epoch 2/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1145s 4s/step - accuracy: 0.9037 - loss: 0.2815 - val_accuracy: 0.8547 - val_loss: 0.4779
# Epoch 3/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1090s 3s/step - accuracy: 0.9185 - loss: 0.2364 - val_accuracy: 0.8793 - val_loss: 0.3909
# Epoch 4/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1112s 4s/step - accuracy: 0.9037 - loss: 0.2504 - val_accuracy: 0.8941 - val_loss: 0.2453
# Epoch 5/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1059s 3s/step - accuracy: 0.9312 - loss: 0.1882 - val_accuracy: 0.8867 - val_loss: 0.2285
# Epoch 6/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1065s 3s/step - accuracy: 0.9376 - loss: 0.1652 - val_accuracy: 0.9089 - val_loss: 0.2215
# Epoch 7/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1064s 3s/step - accuracy: 0.9619 - loss: 0.1125 - val_accuracy: 0.8990 - val_loss: 0.2578
# Epoch 8/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1065s 3s/step - accuracy: 0.9333 - loss: 0.2244 - val_accuracy: 0.8276 - val_loss: 0.3712
# Epoch 9/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1066s 3s/step - accuracy: 0.9280 - loss: 0.2018 - val_accuracy: 0.8941 - val_loss: 0.2675
# Epoch 10/10
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1069s 3s/step - accuracy: 0.9693 - loss: 0.0908 - val_accuracy: 0.9163 - val_loss: 0.2888
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 136s 8s/step
#
# Expt4 Confusion Matrix:
#  [[170  33]
#  [  4 199]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.84      0.90       203
#            1       0.86      0.98      0.91       203
#
#     accuracy                           0.91       406
#    macro avg       0.92      0.91      0.91       406
# weighted avg       0.92      0.91      0.91       406

# %%
# EXPERIMENT RESULTS TABLE
df_results = pd.DataFrame(experiment_results)

# Arrange experiments from highest dense units (1024) to lowest (64)
df_results = df_results.sort_values('Dense Layer 1', ascending=False)

# Reset index and remove index column
df_results = df_results.reset_index(drop=True)

# Round numeric columns for professional display
df_results = df_results.round({
    'Val Loss': 4,
    'Val Accuracy': 4,
    'Accuracy': 4,
    'ROC AUC': 4,
    'Precision (avg)': 4,
    'Recall (avg)': 4,
    'F1 Score': 4
})

# Display table with professional caption
styled_table = df_results.style.set_caption(
    "Table: Three Dense Layer Experiments (Units = 1024, 512, 256, 128, 64)"
).hide(axis='index')

display(styled_table)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f051a" class="dataframe">
#   <caption>Table: Three Dense Layer Experiments (Units = 1024, 512, 256, 128, 64)</caption>
#   <thead>
#     <tr>
#       <th id="T_f051a_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_f051a_level0_col1" class="col_heading level0 col1" >Dense Layer 1</th>
#       <th id="T_f051a_level0_col2" class="col_heading level0 col2" >Dense Layer 2</th>
#       <th id="T_f051a_level0_col3" class="col_heading level0 col3" >Dense Layer 3</th>
#       <th id="T_f051a_level0_col4" class="col_heading level0 col4" >Val Loss</th>
#       <th id="T_f051a_level0_col5" class="col_heading level0 col5" >Val Accuracy</th>
#       <th id="T_f051a_level0_col6" class="col_heading level0 col6" >Accuracy</th>
#       <th id="T_f051a_level0_col7" class="col_heading level0 col7" >ROC AUC</th>
#       <th id="T_f051a_level0_col8" class="col_heading level0 col8" >Precision (avg)</th>
#       <th id="T_f051a_level0_col9" class="col_heading level0 col9" >Recall (avg)</th>
#       <th id="T_f051a_level0_col10" class="col_heading level0 col10" >F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f051a_row0_col0" class="data row0 col0" >Expt1</td>
#       <td id="T_f051a_row0_col1" class="data row0 col1" >1024</td>
#       <td id="T_f051a_row0_col2" class="data row0 col2" >512</td>
#       <td id="T_f051a_row0_col3" class="data row0 col3" >256</td>
#       <td id="T_f051a_row0_col4" class="data row0 col4" >0.304000</td>
#       <td id="T_f051a_row0_col5" class="data row0 col5" >0.879300</td>
#       <td id="T_f051a_row0_col6" class="data row0 col6" >0.879300</td>
#       <td id="T_f051a_row0_col7" class="data row0 col7" >0.964800</td>
#       <td id="T_f051a_row0_col8" class="data row0 col8" >0.827400</td>
#       <td id="T_f051a_row0_col9" class="data row0 col9" >0.733000</td>
#       <td id="T_f051a_row0_col10" class="data row0 col10" >0.887900</td>
#     </tr>
#     <tr>
#       <td id="T_f051a_row1_col0" class="data row1 col0" >Expt2</td>
#       <td id="T_f051a_row1_col1" class="data row1 col1" >512</td>
#       <td id="T_f051a_row1_col2" class="data row1 col2" >256</td>
#       <td id="T_f051a_row1_col3" class="data row1 col3" >128</td>
#       <td id="T_f051a_row1_col4" class="data row1 col4" >0.600000</td>
#       <td id="T_f051a_row1_col5" class="data row1 col5" >0.862100</td>
#       <td id="T_f051a_row1_col6" class="data row1 col6" >0.862100</td>
#       <td id="T_f051a_row1_col7" class="data row1 col7" >0.903800</td>
#       <td id="T_f051a_row1_col8" class="data row1 col8" >0.783400</td>
#       <td id="T_f051a_row1_col9" class="data row1 col9" >0.701800</td>
#       <td id="T_f051a_row1_col10" class="data row1 col10" >0.874400</td>
#     </tr>
#     <tr>
#       <td id="T_f051a_row2_col0" class="data row2 col0" >Expt3</td>
#       <td id="T_f051a_row2_col1" class="data row2 col1" >256</td>
#       <td id="T_f051a_row2_col2" class="data row2 col2" >128</td>
#       <td id="T_f051a_row2_col3" class="data row2 col3" >64</td>
#       <td id="T_f051a_row2_col4" class="data row2 col4" >0.269600</td>
#       <td id="T_f051a_row2_col5" class="data row2 col5" >0.879300</td>
#       <td id="T_f051a_row2_col6" class="data row2 col6" >0.879300</td>
#       <td id="T_f051a_row2_col7" class="data row2 col7" >0.946200</td>
#       <td id="T_f051a_row2_col8" class="data row2 col8" >0.813300</td>
#       <td id="T_f051a_row2_col9" class="data row2 col9" >0.722600</td>
#       <td id="T_f051a_row2_col10" class="data row2 col10" >0.890900</td>
#     </tr>
#     <tr>
#       <td id="T_f051a_row3_col0" class="data row3 col0" >Expt4</td>
#       <td id="T_f051a_row3_col1" class="data row3 col1" >128</td>
#       <td id="T_f051a_row3_col2" class="data row3 col2" >64</td>
#       <td id="T_f051a_row3_col3" class="data row3 col3" >32</td>
#       <td id="T_f051a_row3_col4" class="data row3 col4" >0.221500</td>
#       <td id="T_f051a_row3_col5" class="data row3 col5" >0.908900</td>
#       <td id="T_f051a_row3_col6" class="data row3 col6" >0.908900</td>
#       <td id="T_f051a_row3_col7" class="data row3 col7" >0.979700</td>
#       <td id="T_f051a_row3_col8" class="data row3 col8" >0.835300</td>
#       <td id="T_f051a_row3_col9" class="data row3 col9" >0.739900</td>
#       <td id="T_f051a_row3_col10" class="data row3 col10" >0.914900</td>
#     </tr>
#   </tbody>
# </table>

# %%
# SAVE MODEL & WEIGHTS

print(f"\nBest Dense Units Based on ROC-AUC: {best_units}")

best_model.save(f"Xception _model_{best_units}.keras")
print("Model saved successfully!")

best_model.save(f"Xception _model_{best_units}.h5")
print("Model saved successfully!")

best_model.save_weights(f"Xception _{best_units}.weights.h5")
print("Model weights saved!")
# Out:
# Best Dense Units Based on ROC-AUC: 128x64x32
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!
# Model saved successfully!
# Model weights saved!

# %% [markdown]
# Saving/cpying weights to drive

# %%
# !cp /content/Xception\ _model_128x64x32.h5 "/content/drive/MyDrive/Colab Notebooks_videoAnalytics/Xception_Best_Model_Weights/three_dense_layers/"

# %%
# !cp /content/Xception\ _model_128x64x32.keras "/content/drive/MyDrive/Colab Notebooks_videoAnalytics/Xception_Best_Model_Weights/three_dense_layers/"

# %%
# !cp /content/Xception\ _128x64x32.weights.h5 "/content/drive/MyDrive/Colab Notebooks_videoAnalytics/Xception_Best_Model_Weights/three_dense_layers/"

# %%
#cjheck contents in the folder containing weights
# !ls "/content/drive/MyDrive/Colab Notebooks_videoAnalytics/Xception_Best_Model_Weights/three_dense_layers//"
# Out:
# 'Xception _128x64x32.weights.h5'  'Xception _model_128x64x32.keras'
# 'Xception _model_128x64x32.h5'
